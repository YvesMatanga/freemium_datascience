# %%
class cart_classifier():
    #CART classifier
    
    def __init__(self):
        self.X_d = [] 
        self.y_d = []
    
    def fit(self,X,y):
        self.X_d = X
        self.y_d = y
        
        return -1
    
    def gini_index(self,X,y,f_i): #get the gini score for the data
        Xi_d = X.iloc[:,[f_i]]  #get feature
        xi = X_id.iloc[:,0]
        
        if xi != 'float': #categorical data type
            uniq_vals = xi.unique() #get unique values in the categorical feature vector      
            print(uniq_vals)
            prob = []
            for field in uniq_vals:
                Xi_df = Xi_d[==field]
                
            return -1
        else: #numeric data tye
            return -1

# %%
import pandas as pd
df = pd.read_csv('../datasets/classification/golf_session_data.csv')
df.head()
X = df.iloc[:,0:len(df.columns)]
y = df.iloc[:,[len(df.columns)-1]]

# %%
ttype(1.2)
# Out:
# type

# %%
X.wind.tolist()
# Out:
# [False, True, False, False, False, False, False, False, True, True]

# %%
df.play.unique().tolist()
# Out:
# ['yes', 'no']

# %%
# Out:
# True

# %%
cart_model = cart_classifier()
cart_model.fit(X,y)
gini_val = cart_model.gini_index(cart_model.X_d, cart_model.y_d,0)
print(gini_val)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 3
#       1 cart_model = cart_classifier()
#       2 cart_model.fit(X,y)
# ----> 3 gini_val = cart_model.gini_index(cart_model.X_d, cart_model.y_d,0)
#       4 print(gini_val)
#
# Cell In[46], line 18, in cart_classifier.gini_index(self, X, y, f_i)
#      15 Xi_d = X.iloc[:,[f_i]]  #get feature
#      17 if Xi_d.iloc[:,0].dtype != 'float': #categorical data type
# ---> 18     uniq_vals = Xi_d.unique() #get unique values in the categorical feature vector
#      19     print(uniq_vals)
#      20     return -1
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
# ...
