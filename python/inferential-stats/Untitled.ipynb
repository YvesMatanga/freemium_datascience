# %%
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import pandas as pd

mu = 0
sigma = 1

x = -1.96
p_x = st.norm.cdf(x,loc=mu,scale=sigma)

print('P(X<x) = ',p_x)
# Out:
# P(X<x) =  0.024997895148220435
