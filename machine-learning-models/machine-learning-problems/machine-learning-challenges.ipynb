# %% [markdown]
# <h2>Cats and Dogs Classification</h2>

# %% [markdown]
# Using the Machine Learning Techniques, you have learnt so far to design a binary classifier that can identify
# cats and dogs from an image. Datasets-link: https://www.kaggle.com/datasets/samuelcortinhas/cats-and-dogs-image-classification/data

# %% [markdown]
# <b>Hint</b>: For Basic classification - Convert your RGB images into Grayscale and Resize all pictures to standard data size MxN, then convert your matrix into a vector to be used as a feature vector - <b>You may also used PCA for dimensionality reduction</b>

# %% [markdown]
# You may use the openCV library in the process to load an image and convert it to grayscale.

# %% [markdown]
# <h2>Handwritten Math Symbol Classification</h2><br/>
# Create a classifier that will identify handwritten Math symbols given a labelled dataset of handwritten digits and operators. Datasets-link: https://www.kaggle.com/datasets/sagyamthapa/handwritten-math-symbols

# %% [markdown]
# <h2>Credit Card Dataset for Clustering</h2><br/>
# You are given a dataset of 9000 active credit card holders containing 18 behavioral customer properties. Identify the existing customer group from this dataset. Making use of decision trees to build a tree that will explain the inherent relation in every cluster formed. Datasets-link: https://www.kaggle.com/datasets/arjunbhasin2013/ccdata

# %% [markdown]
# <h2>Laptop Price Prediction</h2><br/>
# You are given a dataset containing information on thousands of laptops with various peroperties: processor details, memory capacity, storage size, etc.
#
# (1) Perform filter-based feature selection and keep only the relavant features.
# (2) Fit and Compare the performance of a couple regression models you know.
#
# Datasets-link: https://www.kaggle.com/datasets/gyanprakashkushwaha/laptop-price-prediction-cleaned-dataset

# %% [markdown]
# <h2>Genetic Algorithms in Optimisation</h2><br/>
# Using GA, design a solution approach to minimise the following function:
#
# $$
#  f(x,y) = (x+2y-7)^2+(2x+y-5)^2, -10\leq x, y\leq 10
# $$

# %% [markdown]
# <h2>Spam Detection Algorithm</h2><br/>
# Given a dataset of postprocessed emails and build a Spam Detection algorithm. Ensure you are understand the fundamental used in the dataset below to discreminate between legit and spam emails.
# Datasets-link:
# https://www.kaggle.com/datasets/balaka18/email-spam-classification-dataset-csv
