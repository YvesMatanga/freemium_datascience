# %% [markdown]
# $$
# y = \beta_0 + \sum_{i=1}^{p}\beta_i(\frac{x_i-\mu_i}{\sigma_i})
# $$

# %% [markdown]
# $$
#  \alpha_i = \frac{\beta_i}\sigma_i
# $$
#
# $$
# \alpha_0 = \beta_0 -\sum_{i=1}^{p}\frac{\beta_i\mu_i}{\sigma_i}
# $$

# %% [markdown]
# $$
# y = \alpha_0 + \sum_{i=1}^{p}\alpha_ix_i
# $$
