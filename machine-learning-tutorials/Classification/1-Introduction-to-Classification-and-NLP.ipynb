# %% [markdown]
# <style>
#     h2{
#      color:red;
#     }
# </style>

# %% [markdown]
# <h1>Introduction to Classification and Natural Language Processing</h1>
#   <h3>Outline</h3>
#   <ol style="color:blue;">
#     <li><b>Introduction to Classification</b>:<br/><br/>
#       <ol>
#           <li> Classification: Concept</li>
#           <li> Geometric Illustration </li>
#           <li> Mathematical Formulation</li>
#           <li> Binary vs Multiclass Classification</li>
#           <li> Classification Methods</li>
#           <li> Model Building Workflow</li>
#         </ol>
#     </li><br/>
#     <li><b>Introduction to Natural Language Processing</b>:</li><br/>
#     <ol>
#           <li> How does the computer learn from data?</li>
#           <li> Text denoising: Regex</li>
#           <li> Tokenisatiom</li>
#           <li> Lemmatisation</li>
#           <li> Stemming</li>
#           <li> Stop words</li>
#         <li> N-grams</li>
#         <li> bag of words</li>
#         </ol>
#   </ol>

# %% [markdown]
# <h2>I. Introduction to Classification</h2>

# %% [markdown]
# Classification is a supervised learning approach that aims to identify to which class a datapoint belongs.<br/><br/>
#
# <figure>
#   <img src="Media/binary_classification_dog_vs_cat.png" width="300px"/>
#     <img src="Media/cancer_classification.png" width="300px"/>
#   <figcaption style="text-align:center">Fig.1 - Identify between dogs and cats [1], Skin Cancer Classification [3].</figcaption>
# </figure>
#
#
#
# <h3>1. Geometric Illustration of Classification</h3>
#
#
# <figure>
#  <img src="Media/regression-vs-classification-in-machine-learning.png" width="500px"/>
#   <figcaption style="text-align:center">Fig.2 - Classification vs Regression [2].</figcaption>
# </figure>
#
#
# <h3>2. Mathematical Formulation - Classification</h3>
# <h4>2.1. Functional/Discriminative Viewpoint </h4>
# $$
#   y = f(\theta,x), y \in \{o_1, o_2,...o_k\}
# $$
#
# Find the curve $f(\theta,x )$ that will help assign or discriminate datapoints <b>x</b> into <b>$o_i$ classes</b>.
#
# <h4>2.2. Probabilistic Viewpoint </h4>
#
# $$
#   p =  P(y = o_i|x) = f(\theta,x) , 0 \leq p \leq 1
# $$
#
#
# Determine the probability that a given datapoint belongs to a class $o_i$.
#
#
# <h3>3. Binary vs Multiclass classification</h3><br/>
# Binary classification consists of discriminating between two classes only: 1 or 0. It is a Yes/No classification scenario and the fondational classification approach. Multiclass classification aims to discriminate betweem more than two classes.
#
#
#
# <figure>
#  <img src="Media/binary_vs_multiclass.png" width="500px"/>
#   <figcaption style="text-align:center">Fig.3 - Binary vs Multi-class Classification [4].</figcaption>
# </figure>
#
# <h3> 4. Classification methods</h3><br/>
#
# There are several classification methods using either of the viewpoint of classification. Some methods of these models are <b>universal</b> and can be used for both classification and regression:
#
# <ul>
#     <li> <b style="color:blue;">Universal models:</b>
#         <ul>
#             <li> Decision Trees and Variants (Random Forest, Gradient Boosting Decision Trees, etc.)
#             </li>
#             <li> Support Vector Machines
#             </li>
#             <li> Neural Networks
#             </li>
#             <li> k-Nearest Neighbours
#             </li>
#         </ul>
#     </li>
# </ul>
#
# <ul>
#     <li> <b style="color:blue;">Classification only models:</b>
#         <ul>
#             <li> Logistic Regression
#             </li>
#             <li> Naive Bayes
#             </li>
#         </ul>
#     </li>
# </ul>
#
#
# <h3> 5. Classification Model - Model Building Workflow</h3><br/>
#
# Like regression, classification follows a very similar process of supervised learning model building:
#
# <ol>
#     <li> Data Sourcing
#     </li>
#     <li>Data cleaning/preprocessing</li>
#     <li>Feature Extraction</li>
#     <li style="color:blue;">Data class equalisation: Solving class imbalance</li>
#     <li>Feature Selection</li>
#     <li>Training (+ Validation set or Cross-validation) vs Test Split</li>
#     <li>Hyperparameter tuning</li>
#     <li>Final model building</li>
#     <li>Model Evaluation</li>
#     <li>Model Deployment</li>
# </ol>

# %% [markdown]
# <h2>II. Introduction to Natural Language Processing</h2>
#
# Natural language processing is a set of techniques for <b style="color:blue;">processing human language</b> including the following tasks:
#
# <ul style="color:blue;">
#     <li>Text Analysis</li>
#     <li>Sentiment analysis</li>
#     <li>Topic modelling</li>
#     <li>Machine translation</li>
#     <li>Speech recognition</li>
#     <li>Text generation</li>
#     <li>etc.</li>
# </ul>

# %% [markdown]
# <h3>1. How does the computer learn from textual data? </h3><br/><br/>
#
#
# <figure>
#  <img src="Media/textual_data.jpg" width="300px"/>
#   <figcaption style="text-align:center">Fig.5 - Learning from textual data [5].</figcaption>
# </figure>
#
#
# Similarly, to the process covered in supervised learning (regression, classification), the computer learns from data by <span style="color:blue;">computing a set of insighful relevant numerical features</span> to identify the inherent pattern in the dataset. However, textual data being unstructured requires a <span style="color:blue;">significant amount of text preprocessing or denoising</span> prior to any decent feature extraction.
#
# <b>Text Cleaning:</b>
# <ul style="color:blue">
#     <li>Removing Noise: Unwanted characters - Regular expressions</li>
#     <li>Tokenisation: Splitting the text into word terms.</li>
#     <li>Stemming: Transforming terms into a root form</li>
#     <li>Lemmatisation: Transforming words into a root word</li>
#     <li>Stop Words: Remove information impertinent terms.</li>
# </ul>
#
# <b>Feature Extraction:</b>
# <ul style="color:blue">
#     <li>n-grams</li>
#     <li>Bag of words</li>
#     <li>Term Frequency (TF) and Term Frequency Inverse Document Frequency (TF-IDF) features</li>
# </ul>

# %% [markdown]
# <h3>2. Text Denoising</h3>
#
# <h4>2.1 Removing Noising using Regular Expressions</h4><br/>
# Regular expressions, often abbreviated as "regex" or "regexp", are sequences of characters that define a search pattern  used for pattern matching and text processing tasks.

# %%
import re  #library for regular expression 

text = "The $#quick brown fox #jumps over the lazy dog!!!"
pattern = r'[^a-zA-Z\s]' #find unwanted characters (non-alphanumeric and non-whitespace)


clean_text = re.sub(pattern, '', text)#replace them with an empty string
print('initial text:', text)
print('\nafter cleaning:',clean_text)
# Out:
# initial text: The $#quick brown fox #jumps over the lazy dog!!!
#
# after cleaning: The quick brown fox jumps over the lazy dog

# %%
#NLTK <- 
#TextBlob <- (numpy for text analysis)

# %% [markdown]
# <h4>2.2 Tokenisation</h4><br/>
# Tokenisation is the process of diving text into a sequence of tokens, which roughly corresponds to "words"

# %%
from textblob import TextBlob

text = 'I see a beautiful city rising from this abyss. I see a brilliant people.'
blob = TextBlob(text)

word_list = blob.words #tokenisation 

for i in range(len(word_list)):
    print(word_list[i])
# Out:
# I
# see
# a
# beautiful
# city
# rising
# from
# this
# abyss
# I
# see
# a
# brilliant
# people

# %%
A programmer is someone who writes computer programs. Programming is a very important skill for software dev.
# Out:
#   Input In [4]
#     A programmer is someone who writes computer programs. Programming is a very important skill for software dev.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# <h4>2.3 Stemming</h4><br/>
# Stemming is the process of transforming words into a root term to minimise redundancies. The root term is not necessarily a word.

# %%
from nltk import SnowballStemmer, PorterStemmer, LancasterStemmer

words = 'caring cares cared caringly carefully'
# find the stem of each word in words
stemmer = SnowballStemmer('english')
for word in words.split():
    print(stemmer.stem(word))

# %%
from textblob import Word
my_word = Word('varieties')
print(my_word.stem())

# %% [markdown]
# <h4>2.4 Lemmatisation</h4><br/>
# A very similar operation to stemming is called lemmatization. Lemmatizing is the process of grouping words of similar meaning together

# %%
# good better well --> lemma (i.e goood)

# %%
import nltk 
nltk.download('wordnet')

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

print(lemmatizer.lemmatize("cats"))
print(lemmatizer.lemmatize("cacti"))
print(lemmatizer.lemmatize("geese"))
print(lemmatizer.lemmatize("rocks"))
print(lemmatizer.lemmatize("python"))
print(lemmatizer.lemmatize("better", pos="a"))
print(lemmatizer.lemmatize("best", pos="a"))
print(lemmatizer.lemmatize("run"))
print(lemmatizer.lemmatize("ran",'v'))

# %%
#from textblob import Word
#my_word = Word('caring')
#print(my_word.lemmatize())

# %% [markdown]
# <h4>2.5 Stop words</h4><br/>
# Stop words are words which do not contain important significance to be used in Search Queries. Usually these words are filtered out from search queries because they return a vast amount of unnecessary information

# %%
from nltk.corpus import stopwords
print(stopwords.words('english'))

# %% [markdown]
# <h3>4. Feature Extraction</h3>
#
# n-gram<br/>
# bag-of-words

# %% [markdown]
# A <b>bag of words</b> is the list of unique words in your text after removing your stop words.
#
# <b>Term Frequency</b>: The count of how many times each word is used in the text

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk

# Download stopwords from NLTK
nltk.download('stopwords')

# Example text
text = """Natural language processing (NLP) is a field of artificial """
"""intelligence that focuses on the interaction between computers and humans through natural language."""

# Preprocess the text
stop_words = set(stopwords.words('english'))
words = [word for word in text.split() if word.lower() not in stop_words]

# Join words to form the processed text
processed_text = ' '.join(words)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(processed_text)

# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\VMATANG\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <h4>References</h4>
#
# [1] Matthijs Hollemans,Getting Started with Image Classification [Accessed 06 Mar 2024]  source: https://www.kodeco.com/books/machine-learning-by-tutorials/v2.0/chapters/2-getting-started-with-image-classification
#
# [2] tutorialsforbeginner.com, Regression vs Classification in Machine Learning [Accessed 06 Mar 2024]  source: https://tutorialforbeginner.com/regression-vs-classification-in-machine-learning
#
# [3] Andrew Ng, Stanford CS 229: Machine Learning.[Accessed: 06 Mar 2024]  source: https://web.stanford.edu/~kalouche/cs229.html
#
# [4]
# Wadhwatanya, Multi-class Classification — One-vs-All & One-vs-One, www.medium.com [Accessed: 06 Mar 2024]source: https://wadhwatanya1234.medium.com/multi-class-classification-one-vs-all-one-vs-one-993dd23ae7ca
#
# [5] Susan Li, Sr.  A Complete Exploratory Data Analysis and Visualization for Text Data: Combine Visualization and NLP to Generate Insights, www.kdnuggets.com, [Accessed: 06 Mar 2024]source: https://www.kdnuggets.com/2019/05/complete-exploratory-data-analysis-visualization-text-data.html
