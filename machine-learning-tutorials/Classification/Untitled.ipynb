# %% [markdown]
#  class = [A, B, C]
#
#
#  x_1,x_2,x_3,..._xn    y
#  ..  ...............   a
#  ..  ...............   b
#  ..  ...............   c
#  ..  ...............   a
#  .. .................. b
#
#
#  classifier_1  (a and not a)
#
#  x_1,x_2,x_3,..._xn    y
#  ..  ...............   1
#  ..  ...............   0
#  ..  ...............   0
#  ..  ...............   1
#  .. .................. 0
#
#
#  classifier_2 (b and not b)
#  ..  ...............   0
#  ..  ...............   1
#  ..  ...............   0
#  ..  ...............   0
#  .. .................. 1
#
#
#  multi_class(x):
#    outcome = classifier_1(x)
#      if outcome is A:
#        report A
#      else:
#    outcome = classifier_2(x)
#      if outcome is B
#         report B
#      else
#          report C

# %%
 x_1,x_2,x_3,..._xn    y 
 ..  ...............   a
 ..  ...............   b
 ..  ...............   c
 ..  ...............   a
 .. .................. b


Number_datapoints (a) = Number_datapoins (b) = Number_datapoints (c)

# %%
I see a beautiful city rising from this abyss. I see a brilliant people

bag-of-words = [see beautiful city rising abyss brilliant people]

term-freq see 2
          city 1
         rising 1
        abyss 1
        brilliant 1
         people 1
            
n-gram: n= 2, see beautiful, beautiful city, city rising, rising abyss, abyss brilliant, brilliant people
    
    n=1
    
    n = [1,2,3]
