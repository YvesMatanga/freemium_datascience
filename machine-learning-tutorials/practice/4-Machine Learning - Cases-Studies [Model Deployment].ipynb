# %% [markdown]
# <h2>Model Building and Deployment - Case Studies</h2>

# %% [markdown]
# <h3>Case Study 1 - Online Medical Premium Calculator</h3>
#
# A US based Medical Insurance company would like to automate the process of premium allocation for new clients given the high demand. The company  has been profiling customers based on several attributes:
#
# <ul>
#     <li>age: age of primary beneficiary</li>
#     <li>sex: insurance contractor gender, female, male</li>
#     <li>bmi: Body mass index</li>
#     <li>smoker: Smoking</li>
# <li>region: the beneficiary's residential area in the US, northeast, southeast, southwest, northwest.</li>
#     <li>children: Number of children covered by health insurance / Number of dependents</li>
#
# </ul>
#
#
# As a Fullstack Web data scientist and Web developper, you are asked to design a data driven model on premium pricing and build a microwebservice (Front-end and Back-end) on localhost for now that will should help clients to enter their profile information and get an estimate premium price. You are provided with historical annual premium pricing data (<b>insurance.csv</b>). <b>Ensure that you built an accurate prediction model</b>.

# %%
import pandas as pd

insurance_df = pd.read_csv('db/insurance.csv')
insurance_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <b style="color:blue">Step 1 - Data Preprocessing & EDA </b>

# %% [markdown]
# <b style="color:blue">Step 2 - Feature Engineering and Selection</b>

# %% [markdown]
# <b style="color:blue">Step 3 - Model Building and Performance Evaluation</b>

# %% [markdown]
# <b style="color:blue">Step 4 - Model Deployment</b>
# <ul>
# <li>Serialise and save model in a pickle file</li>
# <li>Design the Website - Front end</li>
# <li>Implement the Website site <b>Flask-based back-end</b></li>
# <li>Service the Front-end form with the model prediction in user terms </li>
# </ul>

# %% [markdown]
# <h3>Case Study 2 - Online Laptop Price Estimation</h3>

# %% [markdown]
# An Indian laptop reseller has recently entered the tech business. The company aims to offer competitive pricing for its products by leveraging insights from the Indian market. To pursue this goal, they are considering the idea of developing a data-driven machine learning model that can predict the price of a laptop based on its features. You have been tasked with completing this project and ultimately creating a web-based front-end that can evaluate any laptop's value based on market knowledge. You are provided with historical data on laptop pricing in the Indian market ('<b>laptopPrice.csv</b>')

# %%
import pandas as pd

laptop_df = pd.read_csv('db/laptopPrice.csv')
laptop_df.head()
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0    ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2  Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3    ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4    ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
#
#       ssd      hdd       os  os_bit graphic_card_gb  weight     warranty  \
# 0    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 1    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 2    0 GB  1024 GB  Windows  64-bit            0 GB  Casual  No warranty
# 3  512 GB     0 GB  Windows  32-bit            2 GB  Casual  No warranty
# 4    0 GB   512 GB  Windows  64-bit            0 GB  Casual  No warranty
#
#   Touchscreen msoffice  Price   rating  Number of Ratings  Number of Reviews
# ...

# %% [markdown]
# <b style="color:blue">Step 1 - Data Preprocessing & EDA </b>

# %% [markdown]
# <b style="color:blue">Step 2 - Feature Engineering and Selection</b>

# %% [markdown]
# <b style="color:blue">Step 3 - Model Building and Performance Evaluation</b>

# %% [markdown]
# <b style="color:blue">Step 4 - Model Deployment</b>
# <ul>
# <li>Serialise and save model in a pickle file</li>
# <li>Design the Website - Front end</li>
# <li>Implement the Website site <b>Flask-based back-end</b></li>
# <li>Service the Front-end form with the model prediction in user terms </li>
# </ul>
