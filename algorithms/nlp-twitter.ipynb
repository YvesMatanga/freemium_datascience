# %%
from twitter_scraper_selenium import get_profile_details

twitter_username = "TwitterAPI"
filename = "twitter_api_data"
browser = "chrome"
headless = True
get_profile_details(twitter_username=twitter_username, filename=filename, browser=browser, headless=headless)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5 browser = "chrome"
#       6 headless = True
# ----> 7 get_profile_details(twitter_username=twitter_username, filename=filename, browser=browser, headless=headless)
#
# TypeError: get_profile_details() got an unexpected keyword argument 'browser'
