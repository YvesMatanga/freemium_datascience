# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql://root@localhost:3306/sales_db
# Out:
# Traceback (most recent call last):
#   File "C:\Users\VMATANG\AppData\Roaming\Python\Python39\site-packages\sql\connection.py", line 45, in __init__
#     engine = sqlalchemy.create_engine(
#   File "<string>", line 2, in create_engine
#   File "C:\Users\VMATANG\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\util\deprecations.py", line 281, in warned
#     return fn(*args, **kwargs)  # type: ignore[no-any-return]
#   File "C:\Users\VMATANG\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\engine\create.py", line 601, in create_engine
#     dbapi = dbapi_meth(**dbapi_args)
#   File "C:\Users\VMATANG\AppData\Roaming\Python\Python39\site-packages\sqlalchemy\dialects\mysql\mysqldb.py", line 152, in import_dbapi
#     return __import__("MySQLdb")
# ModuleNotFoundError: No module named 'MySQLdb'
#
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# ...

# %%
# %sql
SELECT * FROM sales_db.customer_list;
# Out:
#   Input In [6]
#     SELECT * FROM sales_db.customer_list;
#                   ^
# SyntaxError: invalid syntax
