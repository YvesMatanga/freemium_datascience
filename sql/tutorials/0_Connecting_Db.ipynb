# %% [markdown]
# <h2>Connecting to a MySQL Database</h2>

# %% [markdown]
# <b style="color:blue">Prerequisites</b>

# %%
# !pip install --force-reinstall "sqlalchemy<2.0.0"

# %%
# !pip install pymysql

# %%
# !pip install ipython-sql

# %% [markdown]
# <span style="color:blue">Step 1: Enable SQL magic extension </span>

# %%
# %load_ext sql

# %% [markdown]
# <span style="color:blue">Step 2: Connect to your Database </span>
#
#  mysql+pymysql://<span style="color:blue">USERNAME:PASSWORD@HOST_COMPUTER:PORT_NUMBER/DB_NAME</span>

# %%
# %sql mysql+pymysql://root:root@localhost:3306/world

# %% [markdown]
# <span style="color:blue">Step 3: View Existing Tables </span>

# %%
# %%sql
# SHOW TABLES;

# %% [markdown]
# <span style="color:blue">Step 4: Run Queries </span>

# %%
# %%sql
# SELECT * FROM country LIMIT 5

# %% [markdown]
# <h2>Connecting to a SQLite Database</h2>

# %% [markdown]
# <b style="color:blue">Prerequisites</b>

# %%
# !pip install sqlalchemy

# %%
# !pip install ipython-sql

# %% [markdown]
# <span style="color:blue">Step 1: Enable SQL magic extension </span>

# %%
# %load_ext sql

# %% [markdown]
# <span style="color:blue">Step 2: Connect to your Database </span>
#
#  sqlite:///<span style="color:blue">DB_NAME</span>

# %%
# %sql sqlite:///../databases/sales_db.db

# %% [markdown]
# <span style="color:blue">Step 3: View Existing Tables </span>

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE type='table' LIMIT 3

# %% [markdown]
# <span style="color:blue">Step 4: Run Queries </span>

# %%
# %%sql
# SELECT * FROM prd_list LIMIT 3
