# %% [markdown]
# <h1>Webinar 1 Practice - Tutorial</h1>

# %% [markdown]
# <h3>Outline</h3>
# <ul>
# <li>DDL Commands: CREATE Database and Table creation</li>
# <li>DML Commands: INSERT, UPDATE, DELETE</li>
# <li>DML Commands: SELECT & SELECT with Criteria </li>
# </ul>

# %% [markdown]
# <h2>[QS1] Question Set 1 - Database Creation - <span style="color:blue">School Exam Database</span></h2>

# %% [markdown]
# <img src="../../media/3NF_ERD.png" width="400px"/>

# %%
# %load_ext sql

# %% [markdown]
# <h4>Question QS1-1:  Create a database <b style="color:blue">school_exam_db</b></h4>
# <ul>
#     <li style="color:blue">Use SQLite to create the database</li>
#     <li style="color:blue">Create the INSTRUCTOR and STUDENT tables only</li>
#     <li>Create the INSTRUCTOR table then the STUDENT table for compatibility</li>
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
#     Db creation:
#         %%sql
#         sqlite:///school_exam_db.db
#
#     Table creation:
#         cell 1:
#         %%sql
#         CREATE TABLE instructor (
#           id INTEGER PRIMARY KEY AUTOINCREMENT,
#           name TEXT NOT NULL,
#           cell_num TEXT NOT NULL,
#           email TEXT NOT NULL
#         );
#
#         cell 2:
#         %%sql
#         PRAGMA foreign_keys = ON; -- enable foreign keys
#
#         cell 3:
#         %%sql
#         CREATE TABLE student (
#           id INTEGER PRIMARY KEY AUTOINCREMENT,
#           name TEXT NOT NULL,
#           birth_date DATE,
#           instructor_id INTEGER REFERENCES instructor(id)
#         );
#         cell 4:
#         %%sql
#         PRAGMA table_info(student)
#
#         cell 5:
#         %%sql
#         PRAGMA table_info(instructor)
#
# </details>

# %% [markdown]
# <h4>Question QS1-2:  Populate at least five records in each table (instructor, student)</h4>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    %%sql
# INSERT INTO instructor (name, cell_num, email) VALUES
# ('yves matanga','0613458741','yves.matanga@gmail.com'),
# ('patrick sithole','0735671231','p.sithole@yahoo.com'),
# ('adam smith','0647281831','smith_adam@live.com'),
# ('suraj singh','0123456781','s.singh@yahoo.com'),
# ('olivia coetzer','0657893419','ocoetzer@yahoo.be')
#
#   %%sql
# INSERT INTO student (name, birth_date, instructor_id) VALUES
# ('goodwell marwala','1991-05-25',1),
# ('sandiswa baloyi','2001-03-21',2),
# ('marco van zyl','1997-02-21',3),
# ('amitabh bachchan','1987-01-01',(SELECT id FROM instructor WHERE name = 'yves matanga' LIMIT 1)),
# ('samantha gobler','1990-01-10',2)
#
# </details>

# %% [markdown]
# <h4>Question QS1-3:  Display the content of the INSTRUCTOR and STUDENT table </h4>
# <ul>
#     <li>Sort the table results by NAME</li>
# </ul>

# %% [markdown]
# <h4>Question QS1-4:  Display the content STUDENT table including their corresponding instructors</h4>
# <ul>
#     <li>Display the student name, birth_date, instructor name and email</li>
#     <li>Display the records in ascending order of student ages.
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    %%sql
# SELECT student.name AS 'student name', birth_date AS 'birthdate', instructor.name AS 'instructor name',
# instructor.email AS 'instructor email' FROM student
# JOIN instructor ON instructor.id = student.instructor_id
# ORDER BY birthdate DESC
#
# </details>

# %% [markdown]
# <h4>Question QS1-5:  Update the cell number of an instructor of your choice</h4>
# <ul>
#     <li>Update the email address an instructor based on their email address</li>
#     <li>Display the content of the instructor table to verify whether the change has been made</li>
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#   %%sql
# UPDATE instructor SET cell_num = '0610000001' WHERE email = 'yves.matanga@gmail.com'
# </details>

# %% [markdown]
# <h4>Question QS1-6:  Display students name, birth_date and age</h4>
# <ul>
#     <li>Write a SELECT statement to display a student name, birthdate and age</li>
#     <li>Use a strftime function to convert extract time information:<b> strftime(format, date_value)</b></li>
#     <li>e.g. strftime('%Y', 'now') extract current year</li>
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#   %%sql
# SELECT
#     name,
#     birth_date,
#     (strftime('%Y', 'now') - strftime('%Y', birth_date)) -
#     (strftime('%m-%d', 'now') < strftime('%m-%d', birth_date)) AS age
# FROM student;
# </details>

# %% [markdown]
# <h4>Question QS1-7:  Delete the records of all students under 25</h4>
# <ul>
#     <li>Delete records of students whose age is below 25</li>
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#   %%sql
# DELETE FROM student
# WHERE (strftime('%Y', 'now') - strftime('%Y', birth_date)) -
#       (strftime('%m-%d', 'now') < strftime('%m-%d', birth_date)) < 25;
# </details>

# %% [markdown]
# <h4>Question QS1-8:  Delete the Student Table</h4>
# <ul>
#     <li>use the DROP Table function</li>
# </ul>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#   %%sql
# DROP TABLE IF EXISTS student;
# </details>
