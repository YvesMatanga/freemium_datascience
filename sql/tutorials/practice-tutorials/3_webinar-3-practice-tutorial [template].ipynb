# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h1>Normalisation</h1>

# %% [markdown]
# <h3 style="color:blue">Case Study 1 - Invoice System </h3>
#
# Create a normalised database from the Job Card Below
# <img src="../../media/job_normalisation.png"/>

# %% [markdown]
# <p>Hint: Use Job Number as PK</p>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#   **Answer:**
#    <img src="../../media/job_problem_answer_p1.png"/>
#    <img src="../../media/job_problem_answer_p2.png"/>
#    <img src="../../media/job_problem_answer_p3.png"/>
#
#
# </details>

# %% [markdown]
# <h3 style="color:blue">Case Study 2 - Library Database </h3>

# %% [markdown]
# <img src="../../media/library_problem.png"/>

# %% [markdown]
# <p>Hint: Use Book ID as PK</p>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#   **Answer:**
#    <img src="../../media/library_problem_answer_p1.png"/>
#    <img src="../../media/library_problem_answer_p2.png"/>
#    <img src="../../media/library_problem_answer_p3.png"/>
#
#
# </details>

# %% [markdown]
# <h3 style="color:blue">Case Study 3 - Booking Problem </h3>

# %% [markdown]
# <img src="../../media/booking_problem.png"/>

# %% [markdown]
# <p>Hint: Use Student Number as PK</p>

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#   **Answer:**
#    <img src="../../media/booking_problem_answer_p1.png"/>
#    <img src="../../media/booking_problem_answer_p2.png"/>
#    <img src="../../media/booking_problem_answer_p3.png"/>
#    <img src="../../media/booking_problem_answer_p4.png"/>
#
#
# </details>
