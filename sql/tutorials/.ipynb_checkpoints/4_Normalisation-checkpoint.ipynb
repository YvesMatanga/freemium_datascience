# %% [markdown]
# <h1>Normalisation and NoSQL Databases</h1>

# %% [markdown]
# <h2 style="color:green">1. Normalisation</h2><br/>
# Normalisation is a database technique for evaluting and reorganising table structures to <br/>
# <ul>
#     <li>Minimise redundancies </li>
#     <li>Improve data integrity</li>
# </ul>
#
# Normalisation can be segmented in stages based on how well redundancy is minimised:<br/>
# <ul>
#     <li>First Normal Form (<b>1NF</b>) </li>
#     <li>Second Normal Form (<b>2NF</b>)</li>
#     <li>Third Normal Form (<b>3NF</b>)</li>
#     <li>Boyce-Codd Normal Form (<b>BCNF</b>)</li>
#     <li>Fourth Normal Form (<b>4NF</b>)</li>
# </ul>

# %% [markdown]
# <b style="color:red"> Unnormalised database - Notice Redundancies!!!</b>
# <img src="../media/employee_records.png"/>

# %% [markdown]
# <h3 style="color:blue">Normalisation process</h3>
# <ul>
#     <li>List all the attributes/columns, <b>grouping related data</b> together: 0NF</li>
#     <li>Identify a Primary</li>
#     <li>Perform 1NF: Remove repeating groups/Identify many-to-many relationships</li>
#     <li>Perform 2NF: Remove part-key dependencies/Solve many-to-many relationships</li>
#     <li>Perform 3NF: Remove inter-data dependencies/Resolve one-to-many relationships</li>
# </ul>

# %% [markdown]
# <h3 style="color:blue">Case study 1 - School Exam Database</h3>
# <img src="../media/normalisation_school_problem.png"/>

# %% [markdown]
# <h3>0NF: List all attributes in the database/scenario per entity</h3>

# %% [markdown]
# <img src="../media/0NF_Scenario1.png"/>

# %% [markdown]
# <h3>1NF: Remove repeating groups</h3>

# %% [markdown]
# For a table to be in 1NF, it needs to have **no repeating groups**. Cells should not hold more than one piece of information.

# %% [markdown]
# <img src="../media/1NF_Scenario1.png"/>

# %% [markdown]
# <h3>2NF: Remove Partial redundancies</h3>

# %% [markdown]
# <img src="../media/2NF_Scenario1.png"/>

# %% [markdown]
# <h3>3NF: Remove Nonprimary-key dependent columns</h3>

# %% [markdown]
# <img src="../media/3NF_Scenario1.png"/>

# %% [markdown]
# <h3>Final ERD</h3>

# %% [markdown]
# <img src="../media/3NF_ERD.png"/>

# %% [markdown]
# <h3 style="color:blue">Case Study 2 - Invoice System </h3>
#
# Create a normalised database from the Job Card Below
# <img src="../media/job_normalisation.png"/>
