# %% [markdown]
# Please install the following first:

# %%
#pip install sqlalchemy

# %%
#pip install ipython-sql

# %% [markdown]
# <h1>SQL Practice Exercises</h1>

# %% [markdown]
# Given the sales_db database of a cellular device shop, you are requested to write SQL queries to extract
# data as per management requests.
#
# <img src="../media/sales_erd.png" width="500px"/>

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# sqlite:///sales_db.db

# %% [markdown]
# <b> Question 1</b><br/><br/>
# Write a SQLite command to view the list of tables in your database.
# Hint: SELECT name FROM sqlite_master WHERE type='table'

# %% [markdown]
# <b>Question 2</b><br/><br/>
# Write SQLite commands to view the structure of each table in the database. Hint: PRAGMA table_info(xxx)

# %% [markdown]
# <b>Question 3</b><br/><br/>
# Retrieve the names and prices of all products from the prd_list table.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    SELECT name,price FROM prd_list
# </details>

# %% [markdown]
# <b>Question 4</b><br/><br/>
# How many invoices are they in the database?

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#         SELECT COUNT(*) AS 'number of invoices' FROM invoice;
# </details>

# %% [markdown]
# <b>Question 5</b><br/><br/>
# List all invoices with their associated customer names.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#         SELECT invoice.invoice_id, customer_list.name, customer_list.surname
# FROM invoice JOIN customer_list ON invoice.cust_id = customer_list.id
# </details>

# %% [markdown]
# <b>Question 6</b><br/><br/>
# Find the customers (with no duplicates) who have made a purchase (appear in the invoice table).

# %%
# %%sql
#
# SELECT DISTINCT * FROM customer_list WHERE
# customer_list.id  IN (SELECT invoice.cust_id FROM invoice)
# Out:
#  * sqlite:///sales_db.db
# Done.
# [(1, 'Correna', 'Leilah', 'Alvina', '0743246571', 'Leilah_Alvina1@hotmail.com'),
#  (2, 'Tiertza', 'Trixi', 'Junina', '0122418097', 'Tiertza.Trixi@live.com'),
#  (3, 'Alethea', 'Germana', 'Robinia', '0611045869', 'Germana9@hotmail.com'),
#  (4, 'Sissie', 'Shayla', 'Georgianne', '0813498160', 'Shayla4@yahoo.com'),
#  (5, 'Michele', 'Jenelle', 'Florrie', '0619510647', 'Jenelle0@hotmail.com'),
#  (6, 'Sherill', 'Phillie', 'Remy', '0123249186', 'Sherill.Phillie@live.com'),
#  (7, 'Leta', 'Joly', 'Jenilee', '0128476395', 'Leta.Joly@live.com'),
#  (8, 'Atalanta', 'Eryn', 'Oneida', '0727631290', 'Atalanta_Eryn@yahoo.com'),
#  (9, 'Retha', 'Eliza', 'Desirae', '0815480196', 'Eliza2@yahoo.com'),
#  (10, 'Adriena', 'Sharla', 'Orella', '0721382954', 'Adriena_Sharla@yahoo.com'),
#  (11, 'Willamina', 'Valenka', 'Sile', '0748932641', 'Valenka_Sile7@hotmail.com'),
#  (12, 'Luelle', 'Jenine', 'Kinna', '0122910736', 'Luelle.Jenine@live.com'),
# ...

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#         SELECT DISTINCT c.* FROM customer_list AS c INNER JOIN invoice ON invoice.cust_id = c.id
#
#         SELECT DISTINCT * FROM customer_list WHERE
# customer_list.id  IN (SELECT invoice.cust_id FROM invoice)
#
# </details>

# %% [markdown]
# <b>Question 7</b><br/><br/>
# Retrieve the customer fullnames who have not made any purchase.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#         SELECT c.* FROM customer_list AS c WHERE c.id NOT IN (SELECT invoice_id FROM invoice)
#
#         [SELECT customer_list.name, customer_list.surname FROM customer_list
#
#             EXCEPT
#
#         SELECT customer_list.name, customer_list.surname FROM invoice
#         JOIN customer_list ON invoice.cust_id = customer_list.id]
#
# </details>

# %% [markdown]
# <b>Question 8</b><br/><br/>
# Find the total revenue generated from all invoices.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#         SELECT SUM(invoice_details.qty*prd_list.price) AS 'total revenue' FROM invoice_details JOIN prd_list ON invoice_details.prd_id = prd_list.id
# </details>

# %% [markdown]
# <b>Question 9</b><br/><br/>
# List the customers who made a purchase between June and July.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
# SELECT COUNT(*) FROM customer_list WHERE customer_list.id IN (SELECT invoice.cust_id FROM invoice WHERE date >= '2018-06-01'
#                                                       AND date <= '2018-07-31')
# </details>

# %% [markdown]
# <b>Question 10</b><br/><br/>
# Retrieve the product name, quantity, and total price for each invoice.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 11</b><br/><br/>
# List the customers along with the total number of invoices they have. Hint: GROUP BY

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 12</b><br/><br/>
# Find the products that have never been sold.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 13</b><br/><br/>
# Retrieve the customers who have purchased at least 3 products. HINT: GROUP BY, HAVING

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 14</b><br/><br/>
# Get the invoice details for the top 5 highest revenue-generating invoices.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 15</b><br/><br/>
# Get the details and sales amount for the top 5 highest revenue-generating products.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 16</b><br/><br/>
# Retrieve the names of customers who have not made a purchase using EXCEPT.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 17</b><br/><br/>
# List the products that have never been purchased and those with a price greater than R1000.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 18</b><br/><br/>
# Get the product names and prices for products with a price greater than the average price of all products.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 19</b><br/><br/>
# Retrieve the names of customers who made a purchase and have an email.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>

# %% [markdown]
# <b>Question 20</b><br/><br/>
# Get the fullnames of customers who have made a purchase of a product with a price greater than 2000.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# </details>
