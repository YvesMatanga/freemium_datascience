# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# <h1>Database 1: Sales_db</h1>
#
# <img src="../media/sales_erd.png" width="500px"/>

# %% [markdown]
# <h2>I. Join and Set Operators</h2>

# %% [markdown]
# <b>Question 1</b>
#
# Given the sales_db database of a cellular device shop, you are requested to write SQL queries to extract
# data as per management requests.
#
# 1. Load the SQL lite database and display all the tables within

# %%
# %%sql
# sqlite:///sales_db.db

# %%
# %%sql
# SELECT * FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('table', 'customer_list', 'customer_list', 2, 'CREATE TABLE `customer_list` (\n  `id` INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,\n  `name` TEXT NOT NULL,\n  `surname` TEXT NOT NULL,\n  `middle_name` TEXT NOT NULL,\n  `tel` TEXT NOT NULL,\n  `email` TEXT DEFAULT NULL\n)'),
#  ('table', 'sqlite_sequence', 'sqlite_sequence', 3, 'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table', 'prd_list', 'prd_list', 6, 'CREATE TABLE `prd_list` (\n  `id` INTEGER NOT NULL PRIMARY KEY,\n  `name` TEXT DEFAULT NULL,\n  `price` INTEGER NOT NULL,\n  `description` TEXT DEFAULT NULL\n)'),
#  ('table', 'invoice', 'invoice', 7, 'CREATE TABLE `invoice` (\n  `invoice_id` INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,\n  `cust_id` INTEGER NOT NULL,\n  `date` TEXT NOT NULL,\n  FOREIGN KEY (`cust_id`) REFERENCES `customer_list` (`id`) ON DELETE CASCADE ON UPDATE CASCADE\n)'),
#  ('table', 'invoice_details', 'invoice_details', 8, 'CREATE TABLE `invoice_details` (\n  `inv_id` INTEGER NOT NULL,\n  `prd_id` INTEGER NOT NULL,\n  `qty` INTEGER DEFAULT NULL,\n  PRIMARY KEY (`inv_id`, ... (54 characters truncated) ... ce` (`invoice_id`) ON DELETE CASCADE ON UPDATE CASCADE,\n  FOREIGN KEY (`prd_id`) REFERENCES `prd_list` (`id`) ON DELETE CASCADE ON UPDATE CASCADE\n)'),
#  ('table', 'Customer', 'Customer', 14, "CREATE TABLE Customer (\n    CustomerID INTEGER PRIMARY KEY AUTOINCREMENT,  -- Unique identifier for each customer\n    Name TEXT,                    ... (118 characters truncated) ... hone TEXT,                                     -- Customer's phone number\n    Email TEXT                                      -- Customer's email\n)"),
#  ('table', 'Product', 'Product', 15, 'CREATE TABLE Product (\n    ProductID INTEGER PRIMARY KEY AUTOINCREMENT,    -- Unique identifier for each product\n    ProductCode TEXT UNIQUE,\n     ... (168 characters truncated) ... L NOT NULL,                            -- Price of the product\n    StockQuantity INTEGER                           -- Quantity available in stock\n)'),
#  ('table', 'InvoiceDetails', 'InvoiceDetails', 17, 'CREATE TABLE InvoiceDetails (\n    InvoiceID INTEGER NOT NULL,                         -- Foreign key to Invoice table\n    ProductID INTEGER NOT NUL ... (300 characters truncated) ... eign key constraint\n    FOREIGN KEY (ProductID) REFERENCES Product(ProductID),   -- Foreign key constraint\n    PRIMARY KEY(InvoiceID, ProductID)\n)'),
#  ('table', 'Configuration', 'Configuration', 19, 'CREATE TABLE Configuration (\n    ConfigID INTEGER PRIMARY KEY AUTOINCREMENT,  -- Unique identifier for each configuration\n    ConfigKey TEXT NOT NU ... (54 characters truncated) ... etting (e.g., "TaxRate", "Currency")\n    ConfigValue TEXT NOT NULL                    -- Value of the configuration setting (e.g., "0.15", "USD")\n)')]

# %% [markdown]
# <b>Question 2</b><br/><br/>
# Retrieve a list of all customers along with their respective invoices.

# %%
# %%sql
# SELECT customer_list.name, customer_list.surname, invoice.invoice_id, invoice.date
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id;
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('Correna', 'Leilah', 1, '2018-02-18 00:00:00'),
#  ('Tiertza', 'Trixi', 2, '2018-09-21 00:00:00'),
#  ('Alethea', 'Germana', 3, '2018-01-08 00:00:00'),
#  ('Sissie', 'Shayla', 4, '2018-09-04 00:00:00'),
#  ('Michele', 'Jenelle', 5, '2018-06-01 00:00:00'),
#  ('Sherill', 'Phillie', 6, '2018-03-15 00:00:00'),
#  ('Leta', 'Joly', 7, '2018-08-13 00:00:00'),
#  ('Atalanta', 'Eryn', 8, '2018-03-06 00:00:00'),
#  ('Retha', 'Eliza', 9, '2018-11-01 00:00:00'),
#  ('Adriena', 'Sharla', 10, '2018-01-01 00:00:00'),
#  ('Willamina', 'Valenka', 11, '2018-06-21 00:00:00'),
#  ('Luelle', 'Jenine', 12, '2018-08-04 00:00:00'),
#  ('Morgan', 'Rubie', 13, '2018-06-25 00:00:00'),
#  ('Vivian', 'Daryl', 14, '2018-11-06 00:00:00'),
#  ('Joan', 'Gusella', 15, '2018-10-15 00:00:00'),
#  ('Bettye', 'Ashil', 16, '2018-10-17 00:00:00'),
#  ('Audra', 'Cynthia', 17, '2018-04-03 00:00:00'),
#  ('Etti', 'Stacy', 18, '2018-10-22 00:00:00'),
#  ('Charlean', 'Aundrea', 19, '2018-02-02 00:00:00'),
#  ('Jocelyne', 'Julee', 20, '2018-02-13 00:00:00'),
#  ('Karlotta', 'Jaymee', 21, '2018-02-11 00:00:00'),
#  ('Karee', 'Audre', 22, '2018-04-08 00:00:00'),
#  ('Davina', 'Arlina', 23, '2018-07-09 00:00:00'),
#  ('Danila', 'Maribel', 24, '2018-04-01 00:00:00'),
#  ('Jennee', 'Josey', 25, '2018-06-11 00:00:00'),
#  ('Florry', 'Nance', 26, '2018-07-18 00:00:00'),
#  ('Nissa', 'Paloma', 27, '2018-10-06 00:00:00'),
#  ('Harlie', 'Terrijo', 28, '2018-07-01 00:00:00'),
#  ('Karie', 'Alia', 29, '2018-01-11 00:00:00'),
#  ('Corliss', 'Teddie', 30, '2018-07-16 00:00:00'),
#  ('Kristen', 'Annalise', 31, '2018-01-21 00:00:00'),
#  ('Gilbertina', 'Letisha', 32, '2018-10-20 00:00:00'),
#  ('Carolina', 'Mireille', 33, '2018-08-02 00:00:00'),
#  ('Rebecka', 'Collete', 34, '2018-07-19 00:00:00'),
#  ('Ibby', 'Rosamond', 35, '2018-12-22 00:00:00'),
#  ('Rozanna', 'Joelie', 36, '2018-02-04 00:00:00'),
#  ('Maureene', 'Britney', 37, '2018-10-01 00:00:00'),
#  ('Avivah', 'Shayne', 38, '2018-12-21 00:00:00'),
#  ('Leanna', 'Blaire', 39, '2018-08-13 00:00:00'),
#  ('Odelle', 'Hannis', 40, '2018-07-20 00:00:00'),
#  ('Jolynn', 'Tana', 41, '2018-01-21 00:00:00'),
#  ('Maritsa', 'Dulcia', 42, '2018-04-15 00:00:00'),
#  ('Madelene', 'Camile', 43, '2018-12-20 00:00:00'),
#  ('Cyndie', 'Arlee', 44, '2018-11-10 00:00:00'),
#  ('Adi', 'Adey', 45, '2018-02-15 00:00:00'),
#  ('Lacey', 'Kaitlynn', 46, '2018-06-11 00:00:00'),
#  ('Kial', 'Orelia', 47, '2018-01-16 00:00:00'),
#  ('Petra', 'Dodie', 48, '2018-04-09 00:00:00'),
#  ('Fredrika', 'Devina', 49, '2018-02-19 00:00:00'),
#  ('Rosemary', 'Jen', 50, '2018-04-21 00:00:00'),
#  ('Madlen', 'Kania', 51, '2018-10-03 00:00:00'),
#  ('Brina', 'Brenna', 52, '2018-11-23 00:00:00'),
#  ('Lesya', 'Lavena', 53, '2018-04-18 00:00:00'),
#  ('Selma', 'Dierdre', 54, '2018-10-09 00:00:00'),
#  ('Michaelina', 'Tammi', 55, '2018-06-07 00:00:00'),
#  ('Laurena', 'Marcia', 56, '2018-06-08 00:00:00'),
#  ('Lotte', 'Rhianna', 57, '2018-12-03 00:00:00'),
#  ('Eada', 'Josefa', 58, '2018-05-21 00:00:00'),
#  ('Elsey', 'Vivianna', 59, '2018-03-17 00:00:00'),
#  ('Tandi', 'Maressa', 60, '2018-09-20 00:00:00'),
#  ('Kalinda', 'Tedra', 61, '2018-04-25 00:00:00'),
#  ('Zarla', 'Edythe', 62, '2018-11-04 00:00:00'),
#  ('Florencia', 'Claudie', 63, '2018-07-12 00:00:00'),
#  ('Jeannine', 'Damaris', 64, '2018-12-19 00:00:00'),
#  ('Cyndia', 'Zonnya', 65, '2018-05-18 00:00:00'),
#  ('Aileen', 'Luci', 66, '2018-04-19 00:00:00'),
#  ('Terrye', 'Kriste', 67, '2018-06-04 00:00:00'),
#  ('Diandra', 'Bernette', 68, '2018-11-16 00:00:00'),
#  ('Meryl', 'Hyacinthe', 69, '2018-11-07 00:00:00'),
#  ('Ardyce', 'Terrie', 70, '2018-10-26 00:00:00'),
#  ('Janina', 'Zenia', 71, '2018-07-25 00:00:00'),
#  ('Ida', 'Mahala', 72, '2018-12-22 00:00:00'),
#  ('Lenee', 'Alys', 73, '2018-08-14 00:00:00'),
#  ('Hollie', 'Camala', 74, '2018-05-26 00:00:00'),
#  ('Stefania', 'Karry', 75, '2018-12-21 00:00:00'),
#  ('Elaina', 'Vallie', 76, '2018-06-22 00:00:00'),
#  ('Tessi', 'Farrah', 77, '2018-01-18 00:00:00'),
#  ('Trisha', 'Sidonnie', 78, '2018-07-03 00:00:00'),
#  ('Willie', 'Chastity', 79, '2018-01-18 00:00:00'),
#  ('Allis', 'Dani', 80, '2018-09-17 00:00:00'),
#  ('Kira', 'Bobbye', 81, '2018-10-22 00:00:00'),
#  ('Ruthie', 'Susann', 82, '2018-07-06 00:00:00'),
#  ('Antonietta', 'Antonie', 83, '2018-12-17 00:00:00'),
#  ('Minnie', 'Hyacinth', 84, '2018-02-08 00:00:00'),
#  ('Benoite', 'Hettie', 85, '2018-01-10 00:00:00'),
#  ('Janeva', 'Jourdan', 86, '2018-01-26 00:00:00'),
#  ('Tobe', 'Dorelle', 87, '2018-04-11 00:00:00'),
#  ('Tomasina', 'Nichole', 88, '2018-08-18 00:00:00'),
#  ('Molly', 'Darice', 89, '2018-05-16 00:00:00'),
#  ('Melli', 'Alyssa', 90, '2018-09-21 00:00:00'),
#  ('Glory', 'Marieann', 91, '2018-02-04 00:00:00'),
#  ('Tania', 'Ediva', 92, '2018-04-19 00:00:00'),
#  ('Drusilla', 'Zahara', 93, '2018-04-09 00:00:00'),
#  ('Allianora', 'Dolorita', 94, '2018-04-13 00:00:00'),
#  ('Teriann', 'Valida', 95, '2018-12-18 00:00:00'),
#  ('Kissee', 'Evanne', 96, '2018-12-19 00:00:00'),
#  ('Renate', 'Monah', 97, '2018-11-23 00:00:00'),
#  ('Dixie', 'Christina', 98, '2018-12-16 00:00:00'),
#  ('Candie', 'Faina', 99, '2018-02-18 00:00:00'),
#  ('Val', 'Lauretta', 100, '2018-08-10 00:00:00')]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
# SELECT customer_list.name, customer_list.surname, invoice.invoice_id, invoice.date
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id;
#
#
# </details>

# %% [markdown]
# <b>Question 3 </b><br/>
# List all product names and quantities ordered in invoice

# %%
# %%sql
# SELECT prd_list.name, invoice_details.qty
# FROM prd_list
# INNER JOIN invoice_details ON prd_list.id = invoice_details.prd_id;
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('Sony Xperia J', 3),
#  ('Sony Xperia Go', 3),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Blackberry Playbook 64GB', 1),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Cat S50', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Blackberry Playbook 64GB', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Blackberry Playbook 64GB', 1),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Nokia E6', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Sony Xperia J', 1),
#  ('Sony Xperia Go', 1),
#  ('Blackberry Playbook 64GB', 3),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Sony Xperia Z5 32GB', 3),
#  ('Sony Ericsson Xperia Arc S', 1),
#  ('Blackberry Curve 9320', 1),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia Go', 1),
#  ('Huawei P8 Lite', 3),
#  ('Samsung Galaxy J5 8GB', 4),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Cat S50', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 4),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Sony Xperia J', 4),
#  ('Nokia Asha 302', 4),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('Huawei P8 Lite', 1),
#  ('Blackberry Playbook 64GB', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Huawei P8 Lite', 1),
#  ('Sony Xperia Go', 3),
#  ('Samsung Galaxy J5 8GB', 3),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Sony Xperia Z5 32GB', 3),
#  ('Huawei P8 Lite', 3),
#  ('Samsung Galaxy J5 8GB', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Samsung Galaxy A5 Duos', 3),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia J', 4),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Blackberry Curve 9320', 4),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Huawei P8 Lite', 4),
#  ('Nokia E6', 2),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Sony Xperia Go', 3),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Cat S50', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Cat S50', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia J', 2),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Cat S50', 4),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Nokia Asha 302', 4),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Sony Xperia J', 3),
#  ('Sony Xperia Go', 3),
#  ('Nokia Asha 302', 4),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Xperia J', 3),
#  ('Sony Xperia Go', 2),
#  ('Blackberry Playbook 64GB', 4),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Cat S50', 3),
#  ('Sony Xperia Z5 32GB', 2),
#  ('Sony Xperia Go', 3),
#  ('Samsung Galaxy J5 8GB', 4),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Xperia Go', 2),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Blackberry Playbook 64GB', 2),
#  ('Samsung Galaxy J5 8GB', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Cat S50', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia J', 3),
#  ('Blackberry Curve 9320', 1),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Huawei P8 Lite', 1),
#  ('Samsung Galaxy J5 8GB', 1),
#  ('Nokia Asha 302', 3),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Sony Xperia J', 1),
#  ('Sony Xperia Go', 2),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Huawei P8 Lite', 1),
#  ('Cat S50', 1),
#  ('Sony Ericsson Xperia Arc S', 1),
#  ('Nokia Asha 302', 1),
#  ('Sony Xperia Go', 3),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Playbook 64GB', 1),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Blackberry Playbook 64GB', 4),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Nokia Asha 302', 1),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Curve 9320', 4),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Cat S50', 1),
#  ('Sony Xperia J', 1),
#  ('Blackberry Playbook 64GB', 2),
#  ('Blackberry Curve 9320', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Sony Xperia J', 2),
#  ('Nokia Asha 302', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Blackberry Curve 9320', 1),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia Z5 32GB', 2),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Blackberry Playbook 64GB', 1),
#  ('Huawei P8 Lite', 3),
#  ('Nokia Asha 302', 1),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('Cat S50', 2),
#  ('Sony Xperia Go', 4),
#  ('Huawei P8 Lite', 4),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Sony Xperia J', 1),
#  ('Sony Xperia Go', 1),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Huawei P8 Lite', 2),
#  ('Samsung Galaxy J5 8GB', 3),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Sony Xperia J', 3),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Huawei P8 Lite', 2),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Sony Xperia Go', 4),
#  ('Blackberry Playbook 64GB', 1),
#  ('Huawei P8 Lite', 4),
#  ('Samsung Galaxy J5 8GB', 3),
#  ('Nokia E6', 3),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Cat S50', 1),
#  ('Sony Xperia J', 4),
#  ('Sony Xperia Go', 1),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Curve 9320', 1),
#  ('Nokia E6', 1),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Huawei P8 Lite', 3),
#  ('Nokia E6', 2),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Sony Xperia J', 1),
#  ('Blackberry Playbook 64GB', 1),
#  ('Sony Xperia Z5 32GB', 3),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Playbook 64GB', 4),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 3),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Cat S50', 3),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Xperia Go', 3),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('Blackberry Playbook 64GB', 3),
#  ('Nokia E6', 3),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Xperia J', 1),
#  ('Blackberry Curve 9320', 1),
#  ('Huawei P8 Lite', 4),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Cat S50', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia Go', 1),
#  ('Blackberry Playbook 64GB', 1),
#  ('Nokia E6', 4),
#  ('Blackberry Playbook 64GB', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Huawei P8 Lite', 3),
#  ('Samsung Galaxy J5 8GB', 4),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Xperia J', 3),
#  ('Sony Ericsson Xperia Arc S', 1),
#  ('Huawei P8 Lite', 2),
#  ('Nokia E6', 2),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Cat S50', 2),
#  ('Sony Xperia Z5 32GB', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Blackberry Playbook 64GB', 3),
#  ('Huawei P10 Lite ~ Pearl White', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Cat S50', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia J', 1),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Huawei P8 Lite', 3),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia J', 3),
#  ('Sony Xperia Go', 2),
#  ('Blackberry Playbook 64GB', 3),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Sony Xperia J', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Cat S50', 2),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Blackberry Playbook 64GB', 4),
#  ('Huawei P8 Lite', 2),
#  ('Nokia Asha 302', 4),
#  ('Samsung Galaxy A5 Duos', 3),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Cat S50', 2),
#  ('Sony Xperia Go', 4),
#  ('Blackberry Playbook 64GB', 3),
#  ('Sony Xperia Z5 32GB', 2),
#  ('Sony Xperia J', 4),
#  ('Blackberry Playbook 64GB', 2),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 1),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Blackberry Curve 9320', 1),
#  ('Sony Xperia Go', 2),
#  ('Blackberry Playbook 64GB', 2),
#  ('Huawei P8 Lite', 2),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Nokia Asha 302', 1),
#  ('Nokia E6', 1),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Sony Xperia Z5 32GB', 2),
#  ('Sony Ericsson Xperia Arc S', 3),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Xperia J', 1),
#  ('Sony Xperia Go', 1),
#  ('Blackberry Playbook 64GB', 2),
#  ('Huawei P8 Lite', 2),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Cat S50', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Sony Xperia Z5 32GB', 2),
#  ('Blackberry Curve 9320', 2),
#  ('Nokia Asha 302', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Cat S50', 4),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia J', 1),
#  ('Blackberry Curve 9320', 2),
#  ('Huawei P8 Lite', 4),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Samsung Galaxy A5 Duos', 3),
#  ('Cat S50', 2),
#  ('Huawei P8 Lite', 4),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Nokia Asha 302', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P10 Lite ~ Pearl White', 3),
#  ('Cat S50', 1),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Xperia J', 4),
#  ('Sony Xperia Go', 4),
#  ('Huawei P8 Lite', 2),
#  ('Blackberry Playbook 64GB', 2),
#  ('Nokia Asha 302', 3),
#  ('Nokia E6', 1),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Samsung Galaxy A5 Duos', 1),
#  ('Cat S50', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia J', 3),
#  ('Blackberry Playbook 64GB', 2),
#  ('Blackberry Curve 9320', 1),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('Cat S50', 2),
#  ('Blackberry Playbook 64GB', 1),
#  ('Nokia Asha 302', 1),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Sony Xperia J', 3),
#  ('Sony Xperia Go', 4),
#  ('Blackberry Curve 9320', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Cat S50', 2),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Cat S50', 4),
#  ('Sony Xperia J', 4),
#  ('Huawei P8 Lite', 2),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Nokia Asha 302', 3),
#  ('HTC Desire 600 Dual SIM', 1),
#  ('Huawei P10 Lite ~ Pearl White', 1),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Blackberry Playbook 64GB', 1),
#  ('Huawei P8 Lite', 3),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Sony Xperia J', 2),
#  ('Sony Ericsson Xperia Arc S', 2),
#  ('Nokia E6', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('Cat S50', 2),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Xperia J', 1),
#  ('Sony Xperia Go', 1),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Samsung Galaxy J5 8GB', 2),
#  ('Nokia Asha 302', 2),
#  ('Huawei P10 Lite ~ Pearl White', 4),
#  ('Cat S50', 1),
#  ('Sony Ericsson Xperia Arc S', 1),
#  ('Blackberry Curve 9320', 4),
#  ('Samsung Galaxy A5 Duos', 3),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Sony Xperia Go', 4),
#  ('Sony Ericsson Xperia Arc S', 4),
#  ('Blackberry Playbook 64GB', 4),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Cat S50', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia Z5 32GB', 1),
#  ('Sony Ericsson Xperia Arc S', 1),
#  ('Blackberry Curve 9320', 4),
#  ('Nokia E6', 2),
#  ('HTC Desire 600 Dual SIM', 3),
#  ('Samsung Galaxy A5 Duos', 4),
#  ('Cat S50', 1),
#  ('Sony Xperia Go', 3),
#  ('Blackberry Playbook 64GB', 3),
#  ('Blackberry Curve 9320', 2),
#  ('Samsung Galaxy A5 Duos', 2),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P10 Lite ~ Pearl White', 2),
#  ('Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Sony Xperia Z5 32GB', 3),
#  ('HTC Desire 600 Dual SIM', 2),
#  ('Huawei P8 Lite', 1),
#  ('Nokia E6', 1),
#  ('HTC Desire 600 Dual SIM', 4),
#  ('Cat S50', 1),
#  ('Sony Xperia Z5 32GB', 4),
#  ('Sony Xperia J', 1)]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
# SELECT prd_list.name, invoice_details.qty
# FROM prd_list
# INNER JOIN invoice_details ON prd_list.id = invoice_details.prd_id;
#
#
#
# </details>

# %% [markdown]
# <b>Question 4 </b><br/>
# Show customer names, product names, and quantities for all orders

# %%
# %%sql
# SELECT customer_list.name, prd_list.name AS product_name, invoice_details.qty
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id
# INNER JOIN invoice_details ON invoice.invoice_id = invoice_details.inv_id
# INNER JOIN prd_list ON prd_list.id = invoice_details.prd_id;
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('Correna', 'Sony Xperia J', 3),
#  ('Correna', 'Sony Xperia Go', 3),
#  ('Correna', 'Sony Ericsson Xperia Arc S', 4),
#  ('Correna', 'Blackberry Playbook 64GB', 1),
#  ('Correna', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Correna', 'Cat S50', 2),
#  ('Correna', 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Tiertza', 'Blackberry Playbook 64GB', 1),
#  ('Tiertza', 'HTC Desire 600 Dual SIM', 4),
#  ('Alethea', 'Sony Ericsson Xperia Arc S', 3),
#  ('Alethea', 'Blackberry Playbook 64GB', 1),
#  ('Alethea', 'HTC Desire 600 Dual SIM', 2),
#  ('Sissie', 'Blackberry Curve 9320', 4),
#  ('Michele', 'Samsung Galaxy A5 Duos', 1),
#  ('Sherill', 'Nokia E6', 4),
#  ('Sherill', 'HTC Desire 600 Dual SIM', 3),
#  ('Sherill', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Leta', 'Sony Xperia J', 1),
#  ('Leta', 'Sony Xperia Go', 1),
#  ('Leta', 'Blackberry Playbook 64GB', 3),
#  ('Leta', 'Blackberry Curve 9320', 4),
#  ('Leta', 'Nokia E6', 1),
#  ('Leta', 'HTC Desire 600 Dual SIM', 4),
#  ('Leta', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Leta', 'Sony Xperia Z5 32GB', 3),
#  ('Atalanta', 'Sony Ericsson Xperia Arc S', 1),
#  ('Atalanta', 'Blackberry Curve 9320', 1),
#  ('Atalanta', 'Samsung Galaxy J5 8GB', 2),
#  ('Atalanta', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Retha', 'Sony Xperia Go', 1),
#  ('Retha', 'Huawei P8 Lite', 3),
#  ('Retha', 'Samsung Galaxy J5 8GB', 4),
#  ('Retha', 'Samsung Galaxy A5 Duos', 1),
#  ('Retha', 'Cat S50', 4),
#  ('Retha', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Retha', 'Sony Xperia Z5 32GB', 1),
#  ('Adriena', 'Sony Ericsson Xperia Arc S', 4),
#  ('Adriena', 'Blackberry Curve 9320', 4),
#  ('Adriena', 'Nokia E6', 4),
#  ('Willamina', 'Sony Ericsson Xperia Arc S', 4),
#  ('Luelle', 'Sony Xperia J', 4),
#  ('Luelle', 'Nokia Asha 302', 4),
#  ('Luelle', 'Samsung Galaxy A5 Duos', 2),
#  ('Morgan', 'Huawei P8 Lite', 1),
#  ('Vivian', 'Blackberry Playbook 64GB', 2),
#  ('Vivian', 'Blackberry Curve 9320', 4),
#  ('Joan', 'Huawei P8 Lite', 1),
#  ('Bettye', 'Sony Xperia Go', 3),
#  ('Bettye', 'Samsung Galaxy J5 8GB', 3),
#  ('Bettye', 'Samsung Galaxy A5 Duos', 2),
#  ('Bettye', 'HTC Desire 600 Dual SIM', 2),
#  ('Bettye', 'Sony Xperia Z5 32GB', 3),
#  ('Audra', 'Huawei P8 Lite', 3),
#  ('Audra', 'Samsung Galaxy J5 8GB', 1),
#  ('Audra', 'HTC Desire 600 Dual SIM', 4),
#  ('Audra', 'Samsung Galaxy A5 Duos', 3),
#  ('Audra', 'HTC Desire 600 Dual SIM', 4),
#  ('Audra', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Audra', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Etti', 'Sony Xperia J', 4),
#  ('Etti', 'Sony Ericsson Xperia Arc S', 3),
#  ('Etti', 'Blackberry Curve 9320', 4),
#  ('Charlean', 'Sony Ericsson Xperia Arc S', 2),
#  ('Charlean', 'Blackberry Curve 9320', 4),
#  ('Charlean', 'Huawei P8 Lite', 4),
#  ('Charlean', 'Nokia E6', 2),
#  ('Charlean', 'Samsung Galaxy A5 Duos', 2),
#  ('Charlean', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Jocelyne', 'Sony Xperia Go', 3),
#  ('Jocelyne', 'Sony Ericsson Xperia Arc S', 2),
#  ('Jocelyne', 'HTC Desire 600 Dual SIM', 3),
#  ('Jocelyne', 'HTC Desire 600 Dual SIM', 4),
#  ('Jocelyne', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Jocelyne', 'Cat S50', 2),
#  ('Jocelyne', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Karlotta', 'Samsung Galaxy J5 8GB', 2),
#  ('Karlotta', 'Cat S50', 4),
#  ('Karlotta', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Karee', 'Sony Xperia J', 2),
#  ('Karee', 'Sony Ericsson Xperia Arc S', 4),
#  ('Karee', 'Cat S50', 4),
#  ('Davina', 'Nokia E6', 2),
#  ('Davina', 'HTC Desire 600 Dual SIM', 2),
#  ('Davina', 'HTC Desire 600 Dual SIM', 2),
#  ('Davina', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Danila', 'Nokia Asha 302', 4),
#  ('Danila', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Jennee', 'Sony Xperia J', 3),
#  ('Jennee', 'Sony Xperia Go', 3),
#  ('Jennee', 'Nokia Asha 302', 4),
#  ('Jennee', 'HTC Desire 600 Dual SIM', 4),
#  ('Jennee', 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Jennee', 'Sony Xperia Z5 32GB', 4),
#  ('Florry', 'Sony Xperia J', 3),
#  ('Florry', 'Sony Xperia Go', 2),
#  ('Florry', 'Blackberry Playbook 64GB', 4),
#  ('Florry', 'HTC Desire 600 Dual SIM', 4),
#  ('Florry', 'HTC Desire 600 Dual SIM', 3),
#  ('Florry', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Florry', 'Cat S50', 3),
#  ('Florry', 'Sony Xperia Z5 32GB', 2),
#  ('Nissa', 'Sony Xperia Go', 3),
#  ('Nissa', 'Samsung Galaxy J5 8GB', 4),
#  ('Nissa', 'Nokia E6', 2),
#  ('Nissa', 'HTC Desire 600 Dual SIM', 3),
#  ('Nissa', 'Samsung Galaxy A5 Duos', 4),
#  ('Nissa', 'HTC Desire 600 Dual SIM', 3),
#  ('Nissa', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Nissa', 'Sony Xperia Z5 32GB', 4),
#  ('Harlie', 'Sony Xperia Go', 2),
#  ('Harlie', 'Sony Ericsson Xperia Arc S', 3),
#  ('Harlie', 'Blackberry Playbook 64GB', 2),
#  ('Harlie', 'Samsung Galaxy J5 8GB', 1),
#  ('Harlie', 'HTC Desire 600 Dual SIM', 4),
#  ('Harlie', 'HTC Desire 600 Dual SIM', 4),
#  ('Harlie', 'Cat S50', 4),
#  ('Harlie', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Karie', 'Sony Xperia J', 3),
#  ('Karie', 'Blackberry Curve 9320', 1),
#  ('Corliss', 'Sony Ericsson Xperia Arc S', 4),
#  ('Corliss', 'Huawei P8 Lite', 1),
#  ('Corliss', 'Samsung Galaxy J5 8GB', 1),
#  ('Corliss', 'Nokia Asha 302', 3),
#  ('Corliss', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Corliss', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Kristen', 'Sony Xperia J', 1),
#  ('Kristen', 'Sony Xperia Go', 2),
#  ('Kristen', 'Sony Ericsson Xperia Arc S', 3),
#  ('Kristen', 'Huawei P8 Lite', 1),
#  ('Kristen', 'Cat S50', 1),
#  ('Gilbertina', 'Sony Ericsson Xperia Arc S', 1),
#  ('Gilbertina', 'Nokia Asha 302', 1),
#  ('Carolina', 'Sony Xperia Go', 3),
#  ('Carolina', 'Sony Ericsson Xperia Arc S', 2),
#  ('Carolina', 'Blackberry Playbook 64GB', 1),
#  ('Carolina', 'Blackberry Curve 9320', 4),
#  ('Carolina', 'Nokia E6', 2),
#  ('Carolina', 'HTC Desire 600 Dual SIM', 1),
#  ('Carolina', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Carolina', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Rebecka', 'Blackberry Playbook 64GB', 4),
#  ('Ibby', 'HTC Desire 600 Dual SIM', 1),
#  ('Ibby', 'HTC Desire 600 Dual SIM', 3),
#  ('Rozanna', 'Nokia Asha 302', 1),
#  ('Rozanna', 'Samsung Galaxy A5 Duos', 2),
#  ('Rozanna', 'HTC Desire 600 Dual SIM', 2),
#  ('Rozanna', 'Sony Xperia Z5 32GB', 1),
#  ('Maureene', 'Sony Ericsson Xperia Arc S', 2),
#  ('Maureene', 'Blackberry Curve 9320', 4),
#  ('Maureene', 'HTC Desire 600 Dual SIM', 2),
#  ('Maureene', 'Samsung Galaxy A5 Duos', 4),
#  ('Maureene', 'HTC Desire 600 Dual SIM', 3),
#  ('Maureene', 'Cat S50', 1),
#  ('Avivah', 'Sony Xperia J', 1),
#  ('Avivah', 'Blackberry Playbook 64GB', 2),
#  ('Avivah', 'Blackberry Curve 9320', 1),
#  ('Avivah', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Leanna', 'Sony Xperia J', 2),
#  ('Leanna', 'Nokia Asha 302', 4),
#  ('Leanna', 'HTC Desire 600 Dual SIM', 3),
#  ('Leanna', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Odelle', 'Sony Ericsson Xperia Arc S', 4),
#  ('Odelle', 'Blackberry Curve 9320', 1),
#  ('Odelle', 'HTC Desire 600 Dual SIM', 2),
#  ('Odelle', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Odelle', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Odelle', 'Sony Xperia Z5 32GB', 2),
#  ('Jolynn', 'Sony Ericsson Xperia Arc S', 3),
#  ('Jolynn', 'Blackberry Playbook 64GB', 1),
#  ('Jolynn', 'Huawei P8 Lite', 3),
#  ('Jolynn', 'Nokia Asha 302', 1),
#  ('Jolynn', 'Samsung Galaxy A5 Duos', 4),
#  ('Jolynn', 'Cat S50', 2),
#  ('Maritsa', 'Sony Xperia Go', 4),
#  ('Maritsa', 'Huawei P8 Lite', 4),
#  ('Madelene', 'Samsung Galaxy A5 Duos', 1),
#  ('Cyndie', 'Sony Xperia J', 1),
#  ('Cyndie', 'Sony Xperia Go', 1),
#  ('Cyndie', 'Sony Ericsson Xperia Arc S', 3),
#  ('Cyndie', 'Huawei P8 Lite', 2),
#  ('Cyndie', 'Samsung Galaxy J5 8GB', 3),
#  ('Cyndie', 'Nokia E6', 2),
#  ('Cyndie', 'HTC Desire 600 Dual SIM', 3),
#  ('Adi', 'Sony Xperia J', 3),
#  ('Adi', 'HTC Desire 600 Dual SIM', 1),
#  ('Adi', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Lacey', 'Huawei P8 Lite', 2),
#  ('Kial', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Petra', 'Sony Xperia Go', 4),
#  ('Petra', 'Blackberry Playbook 64GB', 1),
#  ('Petra', 'Huawei P8 Lite', 4),
#  ('Petra', 'Samsung Galaxy J5 8GB', 3),
#  ('Petra', 'Nokia E6', 3),
#  ('Petra', 'HTC Desire 600 Dual SIM', 1),
#  ('Petra', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Petra', 'Sony Xperia Z5 32GB', 1),
#  ('Fredrika', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Rosemary', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Madlen', 'HTC Desire 600 Dual SIM', 4),
#  ('Brina', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Brina', 'Cat S50', 1),
#  ('Lesya', 'Sony Xperia J', 4),
#  ('Lesya', 'Sony Xperia Go', 1),
#  ('Lesya', 'Samsung Galaxy J5 8GB', 2),
#  ('Lesya', 'HTC Desire 600 Dual SIM', 3),
#  ('Lesya', 'Samsung Galaxy A5 Duos', 1),
#  ('Lesya', 'Sony Xperia Z5 32GB', 1),
#  ('Selma', 'Sony Ericsson Xperia Arc S', 2),
#  ('Selma', 'Blackberry Curve 9320', 1),
#  ('Selma', 'Nokia E6', 1),
#  ('Selma', 'HTC Desire 600 Dual SIM', 3),
#  ('Michaelina', 'Huawei P8 Lite', 3),
#  ('Michaelina', 'Nokia E6', 2),
#  ('Michaelina', 'Samsung Galaxy A5 Duos', 4),
#  ('Michaelina', 'HTC Desire 600 Dual SIM', 2),
#  ('Michaelina', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Laurena', 'Sony Xperia J', 1),
#  ('Laurena', 'Blackberry Playbook 64GB', 1),
#  ('Laurena', 'Sony Xperia Z5 32GB', 3),
#  ('Lotte', 'Sony Ericsson Xperia Arc S', 2),
#  ('Lotte', 'Blackberry Playbook 64GB', 4),
#  ('Lotte', 'Blackberry Curve 9320', 4),
#  ('Lotte', 'Nokia E6', 3),
#  ('Lotte', 'HTC Desire 600 Dual SIM', 3),
#  ('Lotte', 'Cat S50', 3),
#  ('Eada', 'Sony Xperia Z5 32GB', 4),
#  ('Elsey', 'Sony Xperia Go', 3),
#  ('Elsey', 'Sony Ericsson Xperia Arc S', 3),
#  ('Elsey', 'Blackberry Playbook 64GB', 3),
#  ('Elsey', 'Nokia E6', 3),
#  ('Elsey', 'Samsung Galaxy A5 Duos', 4),
#  ('Elsey', 'HTC Desire 600 Dual SIM', 1),
#  ('Elsey', 'Sony Xperia Z5 32GB', 1),
#  ('Tandi', 'Sony Xperia J', 1),
#  ('Tandi', 'Blackberry Curve 9320', 1),
#  ('Tandi', 'Huawei P8 Lite', 4),
#  ('Tandi', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Tandi', 'Cat S50', 2),
#  ('Tandi', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Kalinda', 'Sony Xperia Go', 1),
#  ('Kalinda', 'Blackberry Playbook 64GB', 1),
#  ('Kalinda', 'Nokia E6', 4),
#  ('Zarla', 'Blackberry Playbook 64GB', 2),
#  ('Zarla', 'Blackberry Curve 9320', 4),
#  ('Zarla', 'Huawei P8 Lite', 3),
#  ('Zarla', 'Samsung Galaxy J5 8GB', 4),
#  ('Zarla', 'HTC Desire 600 Dual SIM', 4),
#  ('Zarla', 'HTC Desire 600 Dual SIM', 2),
#  ('Zarla', 'Sony Xperia Z5 32GB', 4),
#  ('Florencia', 'Sony Xperia J', 3),
#  ('Florencia', 'Sony Ericsson Xperia Arc S', 1),
#  ('Florencia', 'Huawei P8 Lite', 2),
#  ('Florencia', 'Nokia E6', 2),
#  ('Florencia', 'Samsung Galaxy A5 Duos', 4),
#  ('Florencia', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Jeannine', 'Cat S50', 2),
#  ('Jeannine', 'Sony Xperia Z5 32GB', 1),
#  ('Cyndia', 'HTC Desire 600 Dual SIM', 4),
#  ('Aileen', 'Blackberry Playbook 64GB', 3),
#  ('Aileen', 'Huawei P10 Lite ~ Pearl White', 4),
#  ('Aileen', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Terrye', 'Samsung Galaxy A5 Duos', 1),
#  ('Terrye', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Terrye', 'Cat S50', 4),
#  ('Terrye', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Diandra', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Meryl', 'Sony Xperia J', 1),
#  ('Meryl', 'Sony Ericsson Xperia Arc S', 2),
#  ('Meryl', 'Blackberry Curve 9320', 4),
#  ('Meryl', 'Huawei P8 Lite', 3),
#  ('Meryl', 'Nokia E6', 2),
#  ('Meryl', 'HTC Desire 600 Dual SIM', 2),
#  ('Meryl', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Ardyce', 'Sony Xperia J', 3),
#  ('Ardyce', 'Sony Xperia Go', 2),
#  ('Ardyce', 'Blackberry Playbook 64GB', 3),
#  ('Ardyce', 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Janina', 'Sony Xperia J', 4),
#  ('Janina', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Janina', 'Sony Xperia Z5 32GB', 1),
#  ('Ida', 'Cat S50', 2),
#  ('Lenee', 'Sony Xperia Z5 32GB', 4),
#  ('Hollie', 'Sony Ericsson Xperia Arc S', 4),
#  ('Hollie', 'Blackberry Playbook 64GB', 4),
#  ('Hollie', 'Huawei P8 Lite', 2),
#  ('Hollie', 'Nokia Asha 302', 4),
#  ('Hollie', 'Samsung Galaxy A5 Duos', 3),
#  ('Hollie', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Hollie', 'Cat S50', 2),
#  ('Stefania', 'Sony Xperia Go', 4),
#  ('Stefania', 'Blackberry Playbook 64GB', 3),
#  ('Stefania', 'Sony Xperia Z5 32GB', 2),
#  ('Elaina', 'Sony Xperia J', 4),
#  ('Elaina', 'Blackberry Playbook 64GB', 2),
#  ('Elaina', 'Blackberry Curve 9320', 4),
#  ('Elaina', 'Nokia E6', 1),
#  ('Elaina', 'Samsung Galaxy A5 Duos', 4),
#  ('Elaina', 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Elaina', 'Sony Xperia Z5 32GB', 4),
#  ('Tessi', 'Blackberry Curve 9320', 1),
#  ('Trisha', 'Sony Xperia Go', 2),
#  ('Trisha', 'Blackberry Playbook 64GB', 2),
#  ('Trisha', 'Huawei P8 Lite', 2),
#  ('Trisha', 'Samsung Galaxy J5 8GB', 2),
#  ('Trisha', 'Nokia Asha 302', 1),
#  ('Trisha', 'Nokia E6', 1),
#  ('Trisha', 'HTC Desire 600 Dual SIM', 1),
#  ('Trisha', 'Sony Xperia Z5 32GB', 2),
#  ('Willie', 'Sony Ericsson Xperia Arc S', 3),
#  ('Willie', 'HTC Desire 600 Dual SIM', 3),
#  ('Willie', 'Sony Xperia Z5 32GB', 1),
#  ('Allis', 'Sony Xperia J', 1),
#  ('Allis', 'Sony Xperia Go', 1),
#  ('Allis', 'Blackberry Playbook 64GB', 2),
#  ('Allis', 'Huawei P8 Lite', 2),
#  ('Allis', 'HTC Desire 600 Dual SIM', 4),
#  ('Allis', 'Cat S50', 1),
#  ('Allis', 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  ('Allis', 'Sony Xperia Z5 32GB', 2),
#  ('Kira', 'Blackberry Curve 9320', 2),
#  ('Kira', 'Nokia Asha 302', 1),
#  ('Kira', 'HTC Desire 600 Dual SIM', 4),
#  ('Kira', 'Cat S50', 4),
#  ('Kira', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Ruthie', 'Sony Xperia J', 1),
#  ('Ruthie', 'Blackberry Curve 9320', 2),
#  ('Ruthie', 'Huawei P8 Lite', 4),
#  ('Ruthie', 'Samsung Galaxy J5 8GB', 2),
#  ('Ruthie', 'HTC Desire 600 Dual SIM', 4),
#  ('Ruthie', 'Samsung Galaxy A5 Duos', 3),
#  ('Ruthie', 'Cat S50', 2),
#  ('Antonietta', 'Huawei P8 Lite', 4),
#  ('Antonietta', 'Samsung Galaxy J5 8GB', 2),
#  ('Antonietta', 'Nokia Asha 302', 2),
#  ('Antonietta', 'HTC Desire 600 Dual SIM', 2),
#  ('Antonietta', 'Huawei P10 Lite ~ Pearl White', 3),
#  ('Antonietta', 'Cat S50', 1),
#  ('Antonietta', 'Sony Xperia Z5 32GB', 1),
#  ('Minnie', 'Sony Xperia J', 4),
#  ('Minnie', 'Sony Xperia Go', 4),
#  ('Minnie', 'Huawei P8 Lite', 2),
#  ('Benoite', 'Blackberry Playbook 64GB', 2),
#  ('Benoite', 'Nokia Asha 302', 3),
#  ('Benoite', 'Nokia E6', 1),
#  ('Benoite', 'HTC Desire 600 Dual SIM', 3),
#  ('Benoite', 'Samsung Galaxy A5 Duos', 1),
#  ('Benoite', 'Cat S50', 1),
#  ('Benoite', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Janeva', 'Sony Xperia J', 3),
#  ('Janeva', 'Blackberry Playbook 64GB', 2),
#  ('Janeva', 'Blackberry Curve 9320', 1),
#  ('Janeva', 'Samsung Galaxy A5 Duos', 4),
#  ('Janeva', 'Cat S50', 2),
#  ('Tobe', 'Blackberry Playbook 64GB', 1),
#  ('Tobe', 'Nokia Asha 302', 1),
#  ('Tobe', 'HTC Desire 600 Dual SIM', 2),
#  ('Tomasina', 'Sony Xperia J', 3),
#  ('Tomasina', 'Sony Xperia Go', 4),
#  ('Tomasina', 'Blackberry Curve 9320', 2),
#  ('Tomasina', 'HTC Desire 600 Dual SIM', 3),
#  ('Tomasina', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Tomasina', 'Cat S50', 2),
#  ('Molly', 'Sony Ericsson Xperia Arc S', 4),
#  ('Molly', 'HTC Desire 600 Dual SIM', 3),
#  ('Molly', 'HTC Desire 600 Dual SIM', 1),
#  ('Molly', 'Cat S50', 4),
#  ('Melli', 'Sony Xperia J', 4),
#  ('Melli', 'Huawei P8 Lite', 2),
#  ('Melli', 'Samsung Galaxy J5 8GB', 2),
#  ('Melli', 'Nokia Asha 302', 3),
#  ('Melli', 'HTC Desire 600 Dual SIM', 1),
#  ('Melli', 'Huawei P10 Lite ~ Pearl White', 1),
#  ('Melli', 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  ('Melli', 'Sony Xperia Z5 32GB', 4),
#  ('Glory', 'Blackberry Playbook 64GB', 1),
#  ('Glory', 'Huawei P8 Lite', 3),
#  ('Glory', 'Samsung Galaxy J5 8GB', 2),
#  ('Glory', 'HTC Desire 600 Dual SIM', 2),
#  ('Tania', 'Sony Xperia J', 2),
#  ('Tania', 'Sony Ericsson Xperia Arc S', 2),
#  ('Tania', 'Nokia E6', 4),
#  ('Tania', 'HTC Desire 600 Dual SIM', 3),
#  ('Tania', 'Samsung Galaxy A5 Duos', 2),
#  ('Tania', 'Cat S50', 2),
#  ('Tania', 'Sony Xperia Z5 32GB', 1),
#  ('Drusilla', 'Sony Xperia J', 1),
#  ('Drusilla', 'Sony Xperia Go', 1),
#  ('Drusilla', 'Sony Ericsson Xperia Arc S', 4),
#  ('Drusilla', 'Samsung Galaxy J5 8GB', 2),
#  ('Drusilla', 'Nokia Asha 302', 2),
#  ('Drusilla', 'Huawei P10 Lite ~ Pearl White', 4),
#  ('Drusilla', 'Cat S50', 1),
#  ('Allianora', 'Sony Ericsson Xperia Arc S', 1),
#  ('Allianora', 'Blackberry Curve 9320', 4),
#  ('Allianora', 'Samsung Galaxy A5 Duos', 3),
#  ('Allianora', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Allianora', 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  ('Teriann', 'Sony Xperia Go', 4),
#  ('Teriann', 'Sony Ericsson Xperia Arc S', 4),
#  ('Teriann', 'Blackberry Playbook 64GB', 4),
#  ('Teriann', 'HTC Desire 600 Dual SIM', 3),
#  ('Teriann', 'Cat S50', 2),
#  ('Teriann', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Teriann', 'Sony Xperia Z5 32GB', 1),
#  ('Kissee', 'Sony Ericsson Xperia Arc S', 1),
#  ('Kissee', 'Blackberry Curve 9320', 4),
#  ('Kissee', 'Nokia E6', 2),
#  ('Kissee', 'HTC Desire 600 Dual SIM', 3),
#  ('Kissee', 'Samsung Galaxy A5 Duos', 4),
#  ('Kissee', 'Cat S50', 1),
#  ('Renate', 'Sony Xperia Go', 3),
#  ('Renate', 'Blackberry Playbook 64GB', 3),
#  ('Renate', 'Blackberry Curve 9320', 2),
#  ('Renate', 'Samsung Galaxy A5 Duos', 2),
#  ('Renate', 'HTC Desire 600 Dual SIM', 2),
#  ('Renate', 'Huawei P10 Lite ~ Pearl White', 2),
#  ('Renate', 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  ('Renate', 'Sony Xperia Z5 32GB', 3),
#  ('Dixie', 'HTC Desire 600 Dual SIM', 2),
#  ('Candie', 'Huawei P8 Lite', 1),
#  ('Candie', 'Nokia E6', 1),
#  ('Candie', 'HTC Desire 600 Dual SIM', 4),
#  ('Candie', 'Cat S50', 1),
#  ('Candie', 'Sony Xperia Z5 32GB', 4),
#  ('Val', 'Sony Xperia J', 1)]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
# SELECT customer_list.name, prd_list.name AS product_name, invoice_details.qty
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id
# INNER JOIN invoice_details ON invoice.invoice_id = invoice_details.inv_id
# INNER JOIN prd_list ON prd_list.id = invoice_details.prd_id;
#
#
#
#
# </details>

# %% [markdown]
# <b>Question 5 </b><br/><br/>
# Use EXCEPT to find customers who have not placed any orders

# %%
# %%sql
# SELECT name, surname
# FROM customer_list
# EXCEPT
# SELECT customer_list.name, customer_list.surname
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id;
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#
# SELECT name, surname
# FROM customer_list
# EXCEPT
# SELECT customer_list.name, customer_list.surname
# FROM customer_list
# INNER JOIN invoice ON customer_list.id = invoice.cust_id;
#
#
#
#
#
# </details>

# %% [markdown]
# <b>Question 6 </b><br/><br/>
# Use LEFT JOIN to find customers who have not placed any orders

# %% [markdown]
# <h2>II. Views</h2>

# %% [markdown]
# <b>Question 1</b><br/><br/>
# Create a view named invoice_details_summary that includes invoice_id, product_name, and quantity

# %%
# %%sql
#
# CREATE VIEW invoice_details_summary AS
# SELECT i.invoice_id, p.name AS product_name, id.qty
# FROM invoice_details id
# INNER JOIN prd_list p ON id.prd_id = p.id
# INNER JOIN invoice i ON id.inv_id = i.invoice_id;
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM invoice_details_summary
# Out:
#  * sqlite:///sales_db.db
# Done.
# [(1, 'Sony Xperia J', 3),
#  (1, 'Sony Xperia Go', 3),
#  (1, 'Sony Ericsson Xperia Arc S', 4),
#  (1, 'Blackberry Playbook 64GB', 1),
#  (1, 'Huawei P10 Lite ~ Pearl White', 2),
#  (1, 'Cat S50', 2),
#  (1, 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  (2, 'Blackberry Playbook 64GB', 1),
#  (2, 'HTC Desire 600 Dual SIM', 4),
#  (3, 'Sony Ericsson Xperia Arc S', 3),
#  (3, 'Blackberry Playbook 64GB', 1),
#  (3, 'HTC Desire 600 Dual SIM', 2),
#  (4, 'Blackberry Curve 9320', 4),
#  (5, 'Samsung Galaxy A5 Duos', 1),
#  (6, 'Nokia E6', 4),
#  (6, 'HTC Desire 600 Dual SIM', 3),
#  (6, 'Huawei P10 Lite ~ Pearl White', 3),
#  (7, 'Sony Xperia J', 1),
#  (7, 'Sony Xperia Go', 1),
#  (7, 'Blackberry Playbook 64GB', 3),
#  (7, 'Blackberry Curve 9320', 4),
#  (7, 'Nokia E6', 1),
#  (7, 'HTC Desire 600 Dual SIM', 4),
#  (7, 'Huawei P10 Lite ~ Pearl White', 1),
#  (7, 'Sony Xperia Z5 32GB', 3),
#  (8, 'Sony Ericsson Xperia Arc S', 1),
#  (8, 'Blackberry Curve 9320', 1),
#  (8, 'Samsung Galaxy J5 8GB', 2),
#  (8, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (9, 'Sony Xperia Go', 1),
#  (9, 'Huawei P8 Lite', 3),
#  (9, 'Samsung Galaxy J5 8GB', 4),
#  (9, 'Samsung Galaxy A5 Duos', 1),
#  (9, 'Cat S50', 4),
#  (9, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (9, 'Sony Xperia Z5 32GB', 1),
#  (10, 'Sony Ericsson Xperia Arc S', 4),
#  (10, 'Blackberry Curve 9320', 4),
#  (10, 'Nokia E6', 4),
#  (11, 'Sony Ericsson Xperia Arc S', 4),
#  (12, 'Sony Xperia J', 4),
#  (12, 'Nokia Asha 302', 4),
#  (12, 'Samsung Galaxy A5 Duos', 2),
#  (13, 'Huawei P8 Lite', 1),
#  (14, 'Blackberry Playbook 64GB', 2),
#  (14, 'Blackberry Curve 9320', 4),
#  (15, 'Huawei P8 Lite', 1),
#  (16, 'Sony Xperia Go', 3),
#  (16, 'Samsung Galaxy J5 8GB', 3),
#  (16, 'Samsung Galaxy A5 Duos', 2),
#  (16, 'HTC Desire 600 Dual SIM', 2),
#  (16, 'Sony Xperia Z5 32GB', 3),
#  (17, 'Huawei P8 Lite', 3),
#  (17, 'Samsung Galaxy J5 8GB', 1),
#  (17, 'HTC Desire 600 Dual SIM', 4),
#  (17, 'Samsung Galaxy A5 Duos', 3),
#  (17, 'HTC Desire 600 Dual SIM', 4),
#  (17, 'Huawei P10 Lite ~ Pearl White', 3),
#  (17, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (18, 'Sony Xperia J', 4),
#  (18, 'Sony Ericsson Xperia Arc S', 3),
#  (18, 'Blackberry Curve 9320', 4),
#  (19, 'Sony Ericsson Xperia Arc S', 2),
#  (19, 'Blackberry Curve 9320', 4),
#  (19, 'Huawei P8 Lite', 4),
#  (19, 'Nokia E6', 2),
#  (19, 'Samsung Galaxy A5 Duos', 2),
#  (19, 'Huawei P10 Lite ~ Pearl White', 2),
#  (20, 'Sony Xperia Go', 3),
#  (20, 'Sony Ericsson Xperia Arc S', 2),
#  (20, 'HTC Desire 600 Dual SIM', 3),
#  (20, 'HTC Desire 600 Dual SIM', 4),
#  (20, 'Huawei P10 Lite ~ Pearl White', 2),
#  (20, 'Cat S50', 2),
#  (20, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (21, 'Samsung Galaxy J5 8GB', 2),
#  (21, 'Cat S50', 4),
#  (21, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (22, 'Sony Xperia J', 2),
#  (22, 'Sony Ericsson Xperia Arc S', 4),
#  (22, 'Cat S50', 4),
#  (23, 'Nokia E6', 2),
#  (23, 'HTC Desire 600 Dual SIM', 2),
#  (23, 'HTC Desire 600 Dual SIM', 2),
#  (23, 'Huawei P10 Lite ~ Pearl White', 3),
#  (24, 'Nokia Asha 302', 4),
#  (24, 'Huawei P10 Lite ~ Pearl White', 1),
#  (25, 'Sony Xperia J', 3),
#  (25, 'Sony Xperia Go', 3),
#  (25, 'Nokia Asha 302', 4),
#  (25, 'HTC Desire 600 Dual SIM', 4),
#  (25, 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  (25, 'Sony Xperia Z5 32GB', 4),
#  (26, 'Sony Xperia J', 3),
#  (26, 'Sony Xperia Go', 2),
#  (26, 'Blackberry Playbook 64GB', 4),
#  (26, 'HTC Desire 600 Dual SIM', 4),
#  (26, 'HTC Desire 600 Dual SIM', 3),
#  (26, 'Huawei P10 Lite ~ Pearl White', 3),
#  (26, 'Cat S50', 3),
#  (26, 'Sony Xperia Z5 32GB', 2),
#  (27, 'Sony Xperia Go', 3),
#  (27, 'Samsung Galaxy J5 8GB', 4),
#  (27, 'Nokia E6', 2),
#  (27, 'HTC Desire 600 Dual SIM', 3),
#  (27, 'Samsung Galaxy A5 Duos', 4),
#  (27, 'HTC Desire 600 Dual SIM', 3),
#  (27, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (27, 'Sony Xperia Z5 32GB', 4),
#  (28, 'Sony Xperia Go', 2),
#  (28, 'Sony Ericsson Xperia Arc S', 3),
#  (28, 'Blackberry Playbook 64GB', 2),
#  (28, 'Samsung Galaxy J5 8GB', 1),
#  (28, 'HTC Desire 600 Dual SIM', 4),
#  (28, 'HTC Desire 600 Dual SIM', 4),
#  (28, 'Cat S50', 4),
#  (28, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (29, 'Sony Xperia J', 3),
#  (29, 'Blackberry Curve 9320', 1),
#  (30, 'Sony Ericsson Xperia Arc S', 4),
#  (30, 'Huawei P8 Lite', 1),
#  (30, 'Samsung Galaxy J5 8GB', 1),
#  (30, 'Nokia Asha 302', 3),
#  (30, 'Huawei P10 Lite ~ Pearl White', 2),
#  (30, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (31, 'Sony Xperia J', 1),
#  (31, 'Sony Xperia Go', 2),
#  (31, 'Sony Ericsson Xperia Arc S', 3),
#  (31, 'Huawei P8 Lite', 1),
#  (31, 'Cat S50', 1),
#  (32, 'Sony Ericsson Xperia Arc S', 1),
#  (32, 'Nokia Asha 302', 1),
#  (33, 'Sony Xperia Go', 3),
#  (33, 'Sony Ericsson Xperia Arc S', 2),
#  (33, 'Blackberry Playbook 64GB', 1),
#  (33, 'Blackberry Curve 9320', 4),
#  (33, 'Nokia E6', 2),
#  (33, 'HTC Desire 600 Dual SIM', 1),
#  (33, 'Huawei P10 Lite ~ Pearl White', 2),
#  (33, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (34, 'Blackberry Playbook 64GB', 4),
#  (35, 'HTC Desire 600 Dual SIM', 1),
#  (35, 'HTC Desire 600 Dual SIM', 3),
#  (36, 'Nokia Asha 302', 1),
#  (36, 'Samsung Galaxy A5 Duos', 2),
#  (36, 'HTC Desire 600 Dual SIM', 2),
#  (36, 'Sony Xperia Z5 32GB', 1),
#  (37, 'Sony Ericsson Xperia Arc S', 2),
#  (37, 'Blackberry Curve 9320', 4),
#  (37, 'HTC Desire 600 Dual SIM', 2),
#  (37, 'Samsung Galaxy A5 Duos', 4),
#  (37, 'HTC Desire 600 Dual SIM', 3),
#  (37, 'Cat S50', 1),
#  (38, 'Sony Xperia J', 1),
#  (38, 'Blackberry Playbook 64GB', 2),
#  (38, 'Blackberry Curve 9320', 1),
#  (38, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (39, 'Sony Xperia J', 2),
#  (39, 'Nokia Asha 302', 4),
#  (39, 'HTC Desire 600 Dual SIM', 3),
#  (39, 'Huawei P10 Lite ~ Pearl White', 1),
#  (40, 'Sony Ericsson Xperia Arc S', 4),
#  (40, 'Blackberry Curve 9320', 1),
#  (40, 'HTC Desire 600 Dual SIM', 2),
#  (40, 'Huawei P10 Lite ~ Pearl White', 1),
#  (40, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (40, 'Sony Xperia Z5 32GB', 2),
#  (41, 'Sony Ericsson Xperia Arc S', 3),
#  (41, 'Blackberry Playbook 64GB', 1),
#  (41, 'Huawei P8 Lite', 3),
#  (41, 'Nokia Asha 302', 1),
#  (41, 'Samsung Galaxy A5 Duos', 4),
#  (41, 'Cat S50', 2),
#  (42, 'Sony Xperia Go', 4),
#  (42, 'Huawei P8 Lite', 4),
#  (43, 'Samsung Galaxy A5 Duos', 1),
#  (44, 'Sony Xperia J', 1),
#  (44, 'Sony Xperia Go', 1),
#  (44, 'Sony Ericsson Xperia Arc S', 3),
#  (44, 'Huawei P8 Lite', 2),
#  (44, 'Samsung Galaxy J5 8GB', 3),
#  (44, 'Nokia E6', 2),
#  (44, 'HTC Desire 600 Dual SIM', 3),
#  (45, 'Sony Xperia J', 3),
#  (45, 'HTC Desire 600 Dual SIM', 1),
#  (45, 'Huawei P10 Lite ~ Pearl White', 1),
#  (46, 'Huawei P8 Lite', 2),
#  (47, 'Huawei P10 Lite ~ Pearl White', 1),
#  (48, 'Sony Xperia Go', 4),
#  (48, 'Blackberry Playbook 64GB', 1),
#  (48, 'Huawei P8 Lite', 4),
#  (48, 'Samsung Galaxy J5 8GB', 3),
#  (48, 'Nokia E6', 3),
#  (48, 'HTC Desire 600 Dual SIM', 1),
#  (48, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (48, 'Sony Xperia Z5 32GB', 1),
#  (49, 'Huawei P10 Lite ~ Pearl White', 3),
#  (50, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (51, 'HTC Desire 600 Dual SIM', 4),
#  (52, 'Huawei P10 Lite ~ Pearl White', 1),
#  (52, 'Cat S50', 1),
#  (53, 'Sony Xperia J', 4),
#  (53, 'Sony Xperia Go', 1),
#  (53, 'Samsung Galaxy J5 8GB', 2),
#  (53, 'HTC Desire 600 Dual SIM', 3),
#  (53, 'Samsung Galaxy A5 Duos', 1),
#  (53, 'Sony Xperia Z5 32GB', 1),
#  (54, 'Sony Ericsson Xperia Arc S', 2),
#  (54, 'Blackberry Curve 9320', 1),
#  (54, 'Nokia E6', 1),
#  (54, 'HTC Desire 600 Dual SIM', 3),
#  (55, 'Huawei P8 Lite', 3),
#  (55, 'Nokia E6', 2),
#  (55, 'Samsung Galaxy A5 Duos', 4),
#  (55, 'HTC Desire 600 Dual SIM', 2),
#  (55, 'Huawei P10 Lite ~ Pearl White', 1),
#  (56, 'Sony Xperia J', 1),
#  (56, 'Blackberry Playbook 64GB', 1),
#  (56, 'Sony Xperia Z5 32GB', 3),
#  (57, 'Sony Ericsson Xperia Arc S', 2),
#  (57, 'Blackberry Playbook 64GB', 4),
#  (57, 'Blackberry Curve 9320', 4),
#  (57, 'Nokia E6', 3),
#  (57, 'HTC Desire 600 Dual SIM', 3),
#  (57, 'Cat S50', 3),
#  (58, 'Sony Xperia Z5 32GB', 4),
#  (59, 'Sony Xperia Go', 3),
#  (59, 'Sony Ericsson Xperia Arc S', 3),
#  (59, 'Blackberry Playbook 64GB', 3),
#  (59, 'Nokia E6', 3),
#  (59, 'Samsung Galaxy A5 Duos', 4),
#  (59, 'HTC Desire 600 Dual SIM', 1),
#  (59, 'Sony Xperia Z5 32GB', 1),
#  (60, 'Sony Xperia J', 1),
#  (60, 'Blackberry Curve 9320', 1),
#  (60, 'Huawei P8 Lite', 4),
#  (60, 'Huawei P10 Lite ~ Pearl White', 1),
#  (60, 'Cat S50', 2),
#  (60, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (61, 'Sony Xperia Go', 1),
#  (61, 'Blackberry Playbook 64GB', 1),
#  (61, 'Nokia E6', 4),
#  (62, 'Blackberry Playbook 64GB', 2),
#  (62, 'Blackberry Curve 9320', 4),
#  (62, 'Huawei P8 Lite', 3),
#  (62, 'Samsung Galaxy J5 8GB', 4),
#  (62, 'HTC Desire 600 Dual SIM', 4),
#  (62, 'HTC Desire 600 Dual SIM', 2),
#  (62, 'Sony Xperia Z5 32GB', 4),
#  (63, 'Sony Xperia J', 3),
#  (63, 'Sony Ericsson Xperia Arc S', 1),
#  (63, 'Huawei P8 Lite', 2),
#  (63, 'Nokia E6', 2),
#  (63, 'Samsung Galaxy A5 Duos', 4),
#  (63, 'Huawei P10 Lite ~ Pearl White', 3),
#  (64, 'Cat S50', 2),
#  (64, 'Sony Xperia Z5 32GB', 1),
#  (65, 'HTC Desire 600 Dual SIM', 4),
#  (66, 'Blackberry Playbook 64GB', 3),
#  (66, 'Huawei P10 Lite ~ Pearl White', 4),
#  (66, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (67, 'Samsung Galaxy A5 Duos', 1),
#  (67, 'Huawei P10 Lite ~ Pearl White', 1),
#  (67, 'Cat S50', 4),
#  (67, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (68, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (69, 'Sony Xperia J', 1),
#  (69, 'Sony Ericsson Xperia Arc S', 2),
#  (69, 'Blackberry Curve 9320', 4),
#  (69, 'Huawei P8 Lite', 3),
#  (69, 'Nokia E6', 2),
#  (69, 'HTC Desire 600 Dual SIM', 2),
#  (69, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (70, 'Sony Xperia J', 3),
#  (70, 'Sony Xperia Go', 2),
#  (70, 'Blackberry Playbook 64GB', 3),
#  (70, 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  (71, 'Sony Xperia J', 4),
#  (71, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (71, 'Sony Xperia Z5 32GB', 1),
#  (72, 'Cat S50', 2),
#  (73, 'Sony Xperia Z5 32GB', 4),
#  (74, 'Sony Ericsson Xperia Arc S', 4),
#  (74, 'Blackberry Playbook 64GB', 4),
#  (74, 'Huawei P8 Lite', 2),
#  (74, 'Nokia Asha 302', 4),
#  (74, 'Samsung Galaxy A5 Duos', 3),
#  (74, 'Huawei P10 Lite ~ Pearl White', 1),
#  (74, 'Cat S50', 2),
#  (75, 'Sony Xperia Go', 4),
#  (75, 'Blackberry Playbook 64GB', 3),
#  (75, 'Sony Xperia Z5 32GB', 2),
#  (76, 'Sony Xperia J', 4),
#  (76, 'Blackberry Playbook 64GB', 2),
#  (76, 'Blackberry Curve 9320', 4),
#  (76, 'Nokia E6', 1),
#  (76, 'Samsung Galaxy A5 Duos', 4),
#  (76, 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  (76, 'Sony Xperia Z5 32GB', 4),
#  (77, 'Blackberry Curve 9320', 1),
#  (78, 'Sony Xperia Go', 2),
#  (78, 'Blackberry Playbook 64GB', 2),
#  (78, 'Huawei P8 Lite', 2),
#  (78, 'Samsung Galaxy J5 8GB', 2),
#  (78, 'Nokia Asha 302', 1),
#  (78, 'Nokia E6', 1),
#  (78, 'HTC Desire 600 Dual SIM', 1),
#  (78, 'Sony Xperia Z5 32GB', 2),
#  (79, 'Sony Ericsson Xperia Arc S', 3),
#  (79, 'HTC Desire 600 Dual SIM', 3),
#  (79, 'Sony Xperia Z5 32GB', 1),
#  (80, 'Sony Xperia J', 1),
#  (80, 'Sony Xperia Go', 1),
#  (80, 'Blackberry Playbook 64GB', 2),
#  (80, 'Huawei P8 Lite', 2),
#  (80, 'HTC Desire 600 Dual SIM', 4),
#  (80, 'Cat S50', 1),
#  (80, 'Apple iPad Air 2 16GB WiFi Cellular', 2),
#  (80, 'Sony Xperia Z5 32GB', 2),
#  (81, 'Blackberry Curve 9320', 2),
#  (81, 'Nokia Asha 302', 1),
#  (81, 'HTC Desire 600 Dual SIM', 4),
#  (81, 'Cat S50', 4),
#  (81, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (82, 'Sony Xperia J', 1),
#  (82, 'Blackberry Curve 9320', 2),
#  (82, 'Huawei P8 Lite', 4),
#  (82, 'Samsung Galaxy J5 8GB', 2),
#  (82, 'HTC Desire 600 Dual SIM', 4),
#  (82, 'Samsung Galaxy A5 Duos', 3),
#  (82, 'Cat S50', 2),
#  (83, 'Huawei P8 Lite', 4),
#  (83, 'Samsung Galaxy J5 8GB', 2),
#  (83, 'Nokia Asha 302', 2),
#  (83, 'HTC Desire 600 Dual SIM', 2),
#  (83, 'Huawei P10 Lite ~ Pearl White', 3),
#  (83, 'Cat S50', 1),
#  (83, 'Sony Xperia Z5 32GB', 1),
#  (84, 'Sony Xperia J', 4),
#  (84, 'Sony Xperia Go', 4),
#  (84, 'Huawei P8 Lite', 2),
#  (85, 'Blackberry Playbook 64GB', 2),
#  (85, 'Nokia Asha 302', 3),
#  (85, 'Nokia E6', 1),
#  (85, 'HTC Desire 600 Dual SIM', 3),
#  (85, 'Samsung Galaxy A5 Duos', 1),
#  (85, 'Cat S50', 1),
#  (85, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (86, 'Sony Xperia J', 3),
#  (86, 'Blackberry Playbook 64GB', 2),
#  (86, 'Blackberry Curve 9320', 1),
#  (86, 'Samsung Galaxy A5 Duos', 4),
#  (86, 'Cat S50', 2),
#  (87, 'Blackberry Playbook 64GB', 1),
#  (87, 'Nokia Asha 302', 1),
#  (87, 'HTC Desire 600 Dual SIM', 2),
#  (88, 'Sony Xperia J', 3),
#  (88, 'Sony Xperia Go', 4),
#  (88, 'Blackberry Curve 9320', 2),
#  (88, 'HTC Desire 600 Dual SIM', 3),
#  (88, 'Huawei P10 Lite ~ Pearl White', 1),
#  (88, 'Cat S50', 2),
#  (89, 'Sony Ericsson Xperia Arc S', 4),
#  (89, 'HTC Desire 600 Dual SIM', 3),
#  (89, 'HTC Desire 600 Dual SIM', 1),
#  (89, 'Cat S50', 4),
#  (90, 'Sony Xperia J', 4),
#  (90, 'Huawei P8 Lite', 2),
#  (90, 'Samsung Galaxy J5 8GB', 2),
#  (90, 'Nokia Asha 302', 3),
#  (90, 'HTC Desire 600 Dual SIM', 1),
#  (90, 'Huawei P10 Lite ~ Pearl White', 1),
#  (90, 'Apple iPad Air 2 16GB WiFi Cellular', 3),
#  (90, 'Sony Xperia Z5 32GB', 4),
#  (91, 'Blackberry Playbook 64GB', 1),
#  (91, 'Huawei P8 Lite', 3),
#  (91, 'Samsung Galaxy J5 8GB', 2),
#  (91, 'HTC Desire 600 Dual SIM', 2),
#  (92, 'Sony Xperia J', 2),
#  (92, 'Sony Ericsson Xperia Arc S', 2),
#  (92, 'Nokia E6', 4),
#  (92, 'HTC Desire 600 Dual SIM', 3),
#  (92, 'Samsung Galaxy A5 Duos', 2),
#  (92, 'Cat S50', 2),
#  (92, 'Sony Xperia Z5 32GB', 1),
#  (93, 'Sony Xperia J', 1),
#  (93, 'Sony Xperia Go', 1),
#  (93, 'Sony Ericsson Xperia Arc S', 4),
#  (93, 'Samsung Galaxy J5 8GB', 2),
#  (93, 'Nokia Asha 302', 2),
#  (93, 'Huawei P10 Lite ~ Pearl White', 4),
#  (93, 'Cat S50', 1),
#  (94, 'Sony Ericsson Xperia Arc S', 1),
#  (94, 'Blackberry Curve 9320', 4),
#  (94, 'Samsung Galaxy A5 Duos', 3),
#  (94, 'Huawei P10 Lite ~ Pearl White', 2),
#  (94, 'Apple iPad Air 2 16GB WiFi Cellular', 4),
#  (95, 'Sony Xperia Go', 4),
#  (95, 'Sony Ericsson Xperia Arc S', 4),
#  (95, 'Blackberry Playbook 64GB', 4),
#  (95, 'HTC Desire 600 Dual SIM', 3),
#  (95, 'Cat S50', 2),
#  (95, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (95, 'Sony Xperia Z5 32GB', 1),
#  (96, 'Sony Ericsson Xperia Arc S', 1),
#  (96, 'Blackberry Curve 9320', 4),
#  (96, 'Nokia E6', 2),
#  (96, 'HTC Desire 600 Dual SIM', 3),
#  (96, 'Samsung Galaxy A5 Duos', 4),
#  (96, 'Cat S50', 1),
#  (97, 'Sony Xperia Go', 3),
#  (97, 'Blackberry Playbook 64GB', 3),
#  (97, 'Blackberry Curve 9320', 2),
#  (97, 'Samsung Galaxy A5 Duos', 2),
#  (97, 'HTC Desire 600 Dual SIM', 2),
#  (97, 'Huawei P10 Lite ~ Pearl White', 2),
#  (97, 'Apple iPad Air 2 16GB WiFi Cellular', 1),
#  (97, 'Sony Xperia Z5 32GB', 3),
#  (98, 'HTC Desire 600 Dual SIM', 2),
#  (99, 'Huawei P8 Lite', 1),
#  (99, 'Nokia E6', 1),
#  (99, 'HTC Desire 600 Dual SIM', 4),
#  (99, 'Cat S50', 1),
#  (99, 'Sony Xperia Z5 32GB', 4),
#  (100, 'Sony Xperia J', 1)]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    CREATE VIEW invoice_details_summary AS
# SELECT i.invoice_id, p.name AS product_name, id.qty
# FROM invoice_details id
# INNER JOIN prd_list p ON id.prd_id = p.id
# INNER JOIN invoice i ON id.inv_id = i.invoice_id;
#
# </details>

# %% [markdown]
# <b>Question 2</b><br/><br/>
# Create a view named high_priced_products that includes the names of products with a price greater than the average

# %%
# %%sql
# DROP VIEW IF EXISTS high_priced_product;
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %%
# %%sql
# CREATE VIEW IF NOT EXISTS high_priced_products AS
# SELECT name, price FROM prd_list WHERE price > (SELECT AVG(price) FROM prd_list);
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM high_priced_products
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('Sony Ericsson Xperia Arc S',),
#  ('Blackberry Playbook 64GB',),
#  ('Nokia E6',),
#  ('HTC Desire 600 Dual SIM',),
#  ('Samsung Galaxy A5 Duos',),
#  ('HTC Desire 600 Dual SIM',),
#  ('Cat S50',),
#  ('Apple iPad Air 2 16GB WiFi Cellular',),
#  ('Sony Xperia Z5 32GB',)]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    CREATE VIEW high_priced_products AS
# SELECT name FROM prd_list WHERE price > 100;
#
# </details>

# %% [markdown]
# <b>Question 3</b><br/><br/>
# Create a view named customer_invoices that displays customer names along with the total number of invoices they have.

# %%
# %%sql
# CREATE VIEW customer_invoices AS SELECT c.name, COUNT(i.invoice_id) AS total_invoices
# FROM customer_list c LEFT JOIN invoice i ON c.id = i.cust_id GROUP BY c.name
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %%
# %%sql
# SELECT * FROM customer_invoices
# Out:
#  * sqlite:///sales_db.db
# Done.
# [('Adi', 1),
#  ('Adriena', 1),
#  ('Aileen', 1),
#  ('Alethea', 1),
#  ('Allianora', 1),
#  ('Allis', 1),
#  ('Antonietta', 1),
#  ('Ardyce', 1),
#  ('Atalanta', 1),
#  ('Audra', 1),
#  ('Avivah', 1),
#  ('Benoite', 1),
#  ('Bettye', 1),
#  ('Brina', 1),
#  ('Candie', 1),
#  ('Carolina', 1),
#  ('Charlean', 1),
#  ('Corliss', 1),
#  ('Correna', 1),
#  ('Cyndia', 1),
#  ('Cyndie', 1),
#  ('Danila', 1),
#  ('Davina', 1),
#  ('Diandra', 1),
#  ('Dixie', 1),
#  ('Drusilla', 1),
#  ('Eada', 1),
#  ('Elaina', 1),
#  ('Elsey', 1),
#  ('Etti', 1),
#  ('Florencia', 1),
#  ('Florry', 1),
#  ('Fredrika', 1),
#  ('Gilbertina', 1),
#  ('Glory', 1),
#  ('Harlie', 1),
#  ('Hollie', 1),
#  ('Ibby', 1),
#  ('Ida', 1),
#  ('Janeva', 1),
#  ('Janina', 1),
#  ('Jeannine', 1),
#  ('Jennee', 1),
#  ('Joan', 1),
#  ('Jocelyne', 1),
#  ('Jolynn', 1),
#  ('Kalinda', 1),
#  ('Karee', 1),
#  ('Karie', 1),
#  ('Karlotta', 1),
#  ('Kial', 1),
#  ('Kira', 1),
#  ('Kissee', 1),
#  ('Kristen', 1),
#  ('Lacey', 1),
#  ('Laurena', 1),
#  ('Leanna', 1),
#  ('Lenee', 1),
#  ('Lesya', 1),
#  ('Leta', 1),
#  ('Lotte', 1),
#  ('Luelle', 1),
#  ('Madelene', 1),
#  ('Madlen', 1),
#  ('Maritsa', 1),
#  ('Maureene', 1),
#  ('Melli', 1),
#  ('Meryl', 1),
#  ('Michaelina', 1),
#  ('Michele', 1),
#  ('Minnie', 1),
#  ('Molly', 1),
#  ('Morgan', 1),
#  ('Nissa', 1),
#  ('Odelle', 1),
#  ('Petra', 1),
#  ('Rebecka', 1),
#  ('Renate', 1),
#  ('Retha', 1),
#  ('Rosemary', 1),
#  ('Rozanna', 1),
#  ('Ruthie', 1),
#  ('Selma', 1),
#  ('Sherill', 1),
#  ('Sissie', 1),
#  ('Stefania', 1),
#  ('Tandi', 1),
#  ('Tania', 1),
#  ('Teriann', 1),
#  ('Terrye', 1),
#  ('Tessi', 1),
#  ('Tiertza', 1),
#  ('Tobe', 1),
#  ('Tomasina', 1),
#  ('Trisha', 1),
#  ('Val', 1),
#  ('Vivian', 1),
#  ('Willamina', 1),
#  ('Willie', 1),
#  ('Zarla', 1)]

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    CREATE VIEW customer_invoices AS
# SELECT c.name, COUNT(i.invoice_id) AS total_invoices
# FROM customer_list c
# LEFT JOIN invoice i ON c.id = i.cust_id
# GROUP BY c.name;
# </details>

# %% [markdown]
# <b>Question 4</b><br/><br/>
# Create a view named product_sales_monthly that shows product names and the total quantity sold each month

# %%
# %%sql
# SELECT * FROM invoice
# Out:
#  * sqlite:///sales_db.db
# Done.
# [(1, 1, '2018-02-18 00:00:00'),
#  (2, 2, '2018-09-21 00:00:00'),
#  (3, 3, '2018-01-08 00:00:00'),
#  (4, 4, '2018-09-04 00:00:00'),
#  (5, 5, '2018-06-01 00:00:00'),
#  (6, 6, '2018-03-15 00:00:00'),
#  (7, 7, '2018-08-13 00:00:00'),
#  (8, 8, '2018-03-06 00:00:00'),
#  (9, 9, '2018-11-01 00:00:00'),
#  (10, 10, '2018-01-01 00:00:00'),
#  (11, 11, '2018-06-21 00:00:00'),
#  (12, 12, '2018-08-04 00:00:00'),
#  (13, 13, '2018-06-25 00:00:00'),
#  (14, 14, '2018-11-06 00:00:00'),
#  (15, 15, '2018-10-15 00:00:00'),
#  (16, 16, '2018-10-17 00:00:00'),
#  (17, 17, '2018-04-03 00:00:00'),
#  (18, 18, '2018-10-22 00:00:00'),
#  (19, 19, '2018-02-02 00:00:00'),
#  (20, 20, '2018-02-13 00:00:00'),
#  (21, 21, '2018-02-11 00:00:00'),
#  (22, 22, '2018-04-08 00:00:00'),
#  (23, 23, '2018-07-09 00:00:00'),
#  (24, 24, '2018-04-01 00:00:00'),
#  (25, 25, '2018-06-11 00:00:00'),
#  (26, 26, '2018-07-18 00:00:00'),
#  (27, 27, '2018-10-06 00:00:00'),
#  (28, 28, '2018-07-01 00:00:00'),
#  (29, 29, '2018-01-11 00:00:00'),
#  (30, 30, '2018-07-16 00:00:00'),
#  (31, 31, '2018-01-21 00:00:00'),
#  (32, 32, '2018-10-20 00:00:00'),
#  (33, 33, '2018-08-02 00:00:00'),
#  (34, 34, '2018-07-19 00:00:00'),
#  (35, 35, '2018-12-22 00:00:00'),
#  (36, 36, '2018-02-04 00:00:00'),
#  (37, 37, '2018-10-01 00:00:00'),
#  (38, 38, '2018-12-21 00:00:00'),
#  (39, 39, '2018-08-13 00:00:00'),
#  (40, 40, '2018-07-20 00:00:00'),
#  (41, 41, '2018-01-21 00:00:00'),
#  (42, 42, '2018-04-15 00:00:00'),
#  (43, 43, '2018-12-20 00:00:00'),
#  (44, 44, '2018-11-10 00:00:00'),
#  (45, 45, '2018-02-15 00:00:00'),
#  (46, 46, '2018-06-11 00:00:00'),
#  (47, 47, '2018-01-16 00:00:00'),
#  (48, 48, '2018-04-09 00:00:00'),
#  (49, 49, '2018-02-19 00:00:00'),
#  (50, 50, '2018-04-21 00:00:00'),
#  (51, 51, '2018-10-03 00:00:00'),
#  (52, 52, '2018-11-23 00:00:00'),
#  (53, 53, '2018-04-18 00:00:00'),
#  (54, 54, '2018-10-09 00:00:00'),
#  (55, 55, '2018-06-07 00:00:00'),
#  (56, 56, '2018-06-08 00:00:00'),
#  (57, 57, '2018-12-03 00:00:00'),
#  (58, 58, '2018-05-21 00:00:00'),
#  (59, 59, '2018-03-17 00:00:00'),
#  (60, 60, '2018-09-20 00:00:00'),
#  (61, 61, '2018-04-25 00:00:00'),
#  (62, 62, '2018-11-04 00:00:00'),
#  (63, 63, '2018-07-12 00:00:00'),
#  (64, 64, '2018-12-19 00:00:00'),
#  (65, 65, '2018-05-18 00:00:00'),
#  (66, 66, '2018-04-19 00:00:00'),
#  (67, 67, '2018-06-04 00:00:00'),
#  (68, 68, '2018-11-16 00:00:00'),
#  (69, 69, '2018-11-07 00:00:00'),
#  (70, 70, '2018-10-26 00:00:00'),
#  (71, 71, '2018-07-25 00:00:00'),
#  (72, 72, '2018-12-22 00:00:00'),
#  (73, 73, '2018-08-14 00:00:00'),
#  (74, 74, '2018-05-26 00:00:00'),
#  (75, 75, '2018-12-21 00:00:00'),
#  (76, 76, '2018-06-22 00:00:00'),
#  (77, 77, '2018-01-18 00:00:00'),
#  (78, 78, '2018-07-03 00:00:00'),
#  (79, 79, '2018-01-18 00:00:00'),
#  (80, 80, '2018-09-17 00:00:00'),
#  (81, 81, '2018-10-22 00:00:00'),
#  (82, 82, '2018-07-06 00:00:00'),
#  (83, 83, '2018-12-17 00:00:00'),
#  (84, 84, '2018-02-08 00:00:00'),
#  (85, 85, '2018-01-10 00:00:00'),
#  (86, 86, '2018-01-26 00:00:00'),
#  (87, 87, '2018-04-11 00:00:00'),
#  (88, 88, '2018-08-18 00:00:00'),
#  (89, 89, '2018-05-16 00:00:00'),
#  (90, 90, '2018-09-21 00:00:00'),
#  (91, 91, '2018-02-04 00:00:00'),
#  (92, 92, '2018-04-19 00:00:00'),
#  (93, 93, '2018-04-09 00:00:00'),
#  (94, 94, '2018-04-13 00:00:00'),
#  (95, 95, '2018-12-18 00:00:00'),
#  (96, 96, '2018-12-19 00:00:00'),
#  (97, 97, '2018-11-23 00:00:00'),
#  (98, 98, '2018-12-16 00:00:00'),
#  (99, 99, '2018-02-18 00:00:00'),
#  (100, 100, '2018-08-10 00:00:00')]

# %%
# %%sql
# CREATE VIEW product_sales_monthly AS
# SELECT p.name, MONTH(i.date) AS month, SUM(id.qty) AS total_quantity_sold
# FROM prd_list p
# LEFT JOIN invoice_details id ON p.id = id.prd_id
# LEFT JOIN invoice i ON id.inv_id = i.invoice_id
# GROUP BY p.name, MONTH(i.date);
# Out:
#  * sqlite:///sales_db.db
# Done.
# []

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
#    CREATE VIEW product_sales_monthly AS
# SELECT p.name, MONTH(i.date) AS month, SUM(id.qty) AS total_quantity_sold
# FROM prd_list p
# LEFT JOIN invoice_details id ON p.id = id.prd_id
# LEFT JOIN invoice i ON id.inv_id = i.invoice_id
# GROUP BY p.name, MONTH(i.date);
#
# </details>

# %%
# %%sql
# SELECT * FROM product_sales_monthly
# Out:
#  * sqlite:///sales_db.db
# (sqlite3.OperationalError) no such function: MONTH
# [SQL: SELECT * FROM product_sales_monthly]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# <h2>III. CTEs</h2>

# %% [markdown]
# <b>Question 1</b><br/><br/>
#  Create a CTE to list all customers along with their total number of invoices

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# WITH CTE_CustomerInvoices AS (
#   SELECT cust_id, COUNT(invoice_id) AS Total_Invoices
#   FROM invoice
#   GROUP BY cust_id
# )
# SELECT customer_list.name, customer_list.surname, CTE_CustomerInvoices.Total_Invoices
# FROM CTE_CustomerInvoices
# INNER JOIN customer_list ON customer_list.id = CTE_CustomerInvoices.cust_id;
#
#
# </details>

# %% [markdown]
# <b>Question 2</b><br/><br/>
#  Create a CTE to show customers who have spent more than a specified amount (i.e. R1000) on invoices.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# WITH CTE_CustomerSpending AS (
#   SELECT invoice.cust_id, SUM(invoice_details.qty * prd_list.price) AS Total_Spent
#   FROM invoice
#   INNER JOIN invoice_details ON invoice.invoice_id = invoice_details.inv_id
#   INNER JOIN prd_list ON invoice_details.prd_id = prd_list.id
#   GROUP BY invoice.cust_id
# )
# SELECT customer_list.name, customer_list.surname, CTE_CustomerSpending.Total_Spent
# FROM CTE_CustomerSpending
# INNER JOIN customer_list ON customer_list.id = CTE_CustomerSpending.cust_id
# WHERE CTE_CustomerSpending.Total_Spent > 1000;
#
#
#
# </details>

# %% [markdown]
# <b>Question 3</b><br/><br/>
# Create a CTE to show all products that have never been ordered

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# WITH OrderedProducts AS (
#   SELECT DISTINCT prd_id
#   FROM invoice_details
# )
# SELECT prd_list.name, prd_list.price
# FROM prd_list
# LEFT JOIN OrderedProducts ON prd_list.id = OrderedProducts.prd_id
# WHERE OrderedProducts.prd_id IS NULL;
#
#
#
#
# </details>

# %% [markdown]
# <b>Question 4</b><br/><br/>
# Use a CTE to find products that have been ordered by at least 3 different customers.

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# WITH ProductCustomerCount AS (
#   SELECT invoice_details.prd_id, COUNT(DISTINCT invoice.cust_id) AS Customer_Count
#   FROM invoice_details
#   INNER JOIN invoice ON invoice_details.inv_id = invoice.invoice_id
#   GROUP BY invoice_details.prd_id
# )
# SELECT prd_list.name, prd_list.price, ProductCustomerCount.Customer_Count
# FROM ProductCustomerCount
# INNER JOIN prd_list ON prd_list.id = ProductCustomerCount.prd_id
# WHERE ProductCustomerCount.Customer_Count >= 3;
#
#
#
#
#
# </details>

# %% [markdown]
# <b>Question 5</b><br/><br/>
# Use nested CTEs to find customers who have ordered at least 5 different products and display their total order value.

# %% [markdown]
# Hint: CTE1 - CustomerProduct (i.e. customer and number of distinct product purchases), CTE2 Qualified customer (filter CTE1), write final query

# %% [markdown]
# <details style="color:blue">
#     <summary>Click to reveal the <b>answer<b/></summary>
#
#   **Answer:**
# WITH CustomerProductCount AS (
#   SELECT invoice.cust_id, COUNT(DISTINCT invoice_details.prd_id) AS Unique_Product_Count
#   FROM invoice
#   INNER JOIN invoice_details ON invoice.invoice_id = invoice_details.inv_id
#   GROUP BY invoice.cust_id
# ),
# QualifiedCustomers AS (
#   SELECT cust_id
#   FROM CustomerProductCount
#   WHERE Unique_Product_Count >= 5
# ),
# CustomerOrderValue AS (
#   SELECT invoice.cust_id, SUM(invoice_details.qty * prd_list.price) AS Total_Value
#   FROM invoice
#   INNER JOIN invoice_details ON invoice.invoice_id = invoice_details.inv_id
#   INNER JOIN prd_list ON prd_list.id = invoice_details.prd_id
#   GROUP BY invoice.cust_id
# )
# SELECT customer_list.name, customer_list.surname, CustomerOrderValue.Total_Value
# FROM CustomerOrderValue
# INNER JOIN QualifiedCustomers ON CustomerOrderValue.cust_id = QualifiedCustomers.cust_id
# INNER JOIN customer_list ON customer_list.id = CustomerOrderValue.cust_id;
#
# </details>
