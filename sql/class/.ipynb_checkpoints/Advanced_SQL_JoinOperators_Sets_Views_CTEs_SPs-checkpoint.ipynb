# %% [markdown]
# <h1>Webinar Structure</h1>
# <ol>
#     <li>Join operators</li>
#     <li>Set Theory</li>
# </ol>

# %% [markdown]
# <h2>Database structure</h2>

# %% [markdown]
# <img src="../media/db_structure.jpg" width="500"/>

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# sqlite:///chinook.db

# %%
# %%sql
#
# SELECT * FROM albums
# Out:
#    sqlite:///Northwind_small.sqlite
#  * sqlite:///chinook.db
# Done.
# [(1, 'For Those About To Rock We Salute You', 1),
#  (2, 'Balls to the Wall', 2),
#  (3, 'Restless and Wild', 2),
#  (4, 'Let There Be Rock', 1),
#  (5, 'Big Ones', 3),
#  (6, 'Jagged Little Pill', 4),
#  (7, 'Facelift', 5),
#  (8, 'Warner 25 Anos', 6),
#  (9, 'Plays Metallica By Four Cellos', 7),
#  (10, 'Audioslave', 8),
#  (11, 'Out Of Exile', 8),
#  (12, 'BackBeat Soundtrack', 9),
#  (13, 'The Best Of Billy Cobham', 10),
#  (14, 'Alcohol Fueled Brewtality Live! [Disc 1]', 11),
#  (15, 'Alcohol Fueled Brewtality Live! [Disc 2]', 11),
#  (16, 'Black Sabbath', 12),
#  (17, 'Black Sabbath Vol. 4 (Remaster)', 12),
#  (18, 'Body Count', 13),
#  (19, 'Chemical Wedding', 14),
#  (20, 'The Best Of Buddy Guy - The Millenium Collection', 15),
#  (21, 'Prenda Minha', 16),
#  (22, 'Sozinho Remix Ao Vivo', 16),
#  (23, 'Minha Historia', 17),
#  (24, 'Afrociberdelia', 18),
#  (25, 'Da Lama Ao Caos', 18),
#  (26, 'Acústico MTV [Live]', 19),
#  (27, 'Cidade Negra - Hits', 19),
#  (28, 'Na Pista', 20),
#  (29, 'Axé Bahia 2001', 21),
#  (30, 'BBC Sessions [Disc 1] [Live]', 22),
#  (31, 'Bongo Fury', 23),
#  (32, 'Carnaval 2001', 21),
#  (33, 'Chill: Brazil (Disc 1)', 24),
#  (34, 'Chill: Brazil (Disc 2)', 6),
#  (35, 'Garage Inc. (Disc 1)', 50),
#  (36, 'Greatest Hits II', 51),
#  (37, 'Greatest Kiss', 52),
#  (38, 'Heart of the Night', 53),
#  (39, 'International Superhits', 54),
#  (40, 'Into The Light', 55),
#  (41, 'Meus Momentos', 56),
#  (42, 'Minha História', 57),
#  (43, 'MK III The Final Concerts [Disc 1]', 58),
#  (44, 'Physical Graffiti [Disc 1]', 22),
#  (45, 'Sambas De Enredo 2001', 21),
#  (46, 'Supernatural', 59),
#  (47, 'The Best of Ed Motta', 37),
#  (48, 'The Essential Miles Davis [Disc 1]', 68),
#  (49, 'The Essential Miles Davis [Disc 2]', 68),
#  (50, 'The Final Concerts (Disc 2)', 58),
#  (51, "Up An' Atom", 69),
#  (52, 'Vinícius De Moraes - Sem Limite', 70),
#  (53, 'Vozes do MPB', 21),
#  (54, 'Chronicle, Vol. 1', 76),
#  (55, 'Chronicle, Vol. 2', 76),
#  (56, 'Cássia Eller - Coleção Sem Limite [Disc 2]', 77),
#  (57, 'Cássia Eller - Sem Limite [Disc 1]', 77),
#  (58, 'Come Taste The Band', 58),
#  (59, 'Deep Purple In Rock', 58),
#  (60, 'Fireball', 58),
#  (61, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 58),
#  (62, 'Machine Head', 58),
#  (63, 'Purpendicular', 58),
#  (64, 'Slaves And Masters', 58),
#  (65, 'Stormbringer', 58),
#  (66, 'The Battle Rages On', 58),
#  (67, "Vault: Def Leppard's Greatest Hits", 78),
#  (68, 'Outbreak', 79),
#  (69, 'Djavan Ao Vivo - Vol. 02', 80),
#  (70, 'Djavan Ao Vivo - Vol. 1', 80),
#  (71, 'Elis Regina-Minha História', 41),
#  (72, 'The Cream Of Clapton', 81),
#  (73, 'Unplugged', 81),
#  (74, 'Album Of The Year', 82),
#  (75, 'Angel Dust', 82),
#  (76, 'King For A Day Fool For A Lifetime', 82),
#  (77, 'The Real Thing', 82),
#  (78, 'Deixa Entrar', 83),
#  (79, 'In Your Honor [Disc 1]', 84),
#  (80, 'In Your Honor [Disc 2]', 84),
#  (81, 'One By One', 84),
#  (82, 'The Colour And The Shape', 84),
#  (83, 'My Way: The Best Of Frank Sinatra [Disc 1]', 85),
#  (84, 'Roda De Funk', 86),
#  (85, 'As Canções de Eu Tu Eles', 27),
#  (86, 'Quanta Gente Veio Ver (Live)', 27),
#  (87, 'Quanta Gente Veio ver--Bônus De Carnaval', 27),
#  (88, 'Faceless', 87),
#  (89, 'American Idiot', 54),
#  (90, 'Appetite for Destruction', 88),
#  (91, 'Use Your Illusion I', 88),
#  (92, 'Use Your Illusion II', 88),
#  (93, 'Blue Moods', 89),
#  (94, 'A Matter of Life and Death', 90),
#  (95, 'A Real Dead One', 90),
#  (96, 'A Real Live One', 90),
#  (97, 'Brave New World', 90),
#  (98, 'Dance Of Death', 90),
#  (99, 'Fear Of The Dark', 90),
#  (100, 'Iron Maiden', 90),
#  (101, 'Killers', 90),
#  (102, 'Live After Death', 90),
#  (103, 'Live At Donington 1992 (Disc 1)', 90),
#  (104, 'Live At Donington 1992 (Disc 2)', 90),
#  (105, 'No Prayer For The Dying', 90),
#  (106, 'Piece Of Mind', 90),
#  (107, 'Powerslave', 90),
#  (108, 'Rock In Rio [CD1]', 90),
#  (109, 'Rock In Rio [CD2]', 90),
#  (110, 'Seventh Son of a Seventh Son', 90),
#  (111, 'Somewhere in Time', 90),
#  (112, 'The Number of The Beast', 90),
#  (113, 'The X Factor', 90),
#  (114, 'Virtual XI', 90),
#  (115, 'Sex Machine', 91),
#  (116, 'Emergency On Planet Earth', 92),
#  (117, 'Synkronized', 92),
#  (118, 'The Return Of The Space Cowboy', 92),
#  (119, 'Get Born', 93),
#  (120, 'Are You Experienced?', 94),
#  (121, 'Surfing with the Alien (Remastered)', 95),
#  (122, 'Jorge Ben Jor 25 Anos', 46),
#  (123, 'Jota Quest-1995', 96),
#  (124, 'Cafezinho', 97),
#  (125, 'Living After Midnight', 98),
#  (126, 'Unplugged [Live]', 52),
#  (127, 'BBC Sessions [Disc 2] [Live]', 22),
#  (128, 'Coda', 22),
#  (129, 'Houses Of The Holy', 22),
#  (130, 'In Through The Out Door', 22),
#  (131, 'IV', 22),
#  (132, 'Led Zeppelin I', 22),
#  (133, 'Led Zeppelin II', 22),
#  (134, 'Led Zeppelin III', 22),
#  (135, 'Physical Graffiti [Disc 2]', 22),
#  (136, 'Presence', 22),
#  (137, 'The Song Remains The Same (Disc 1)', 22),
#  (138, 'The Song Remains The Same (Disc 2)', 22),
#  (139, 'A TempestadeTempestade Ou O Livro Dos Dias', 99),
#  (140, 'Mais Do Mesmo', 99),
#  (141, 'Greatest Hits', 100),
#  (142, 'Lulu Santos - RCA 100 Anos De Música - Álbum 01', 101),
#  (143, 'Lulu Santos - RCA 100 Anos De Música - Álbum 02', 101),
#  (144, 'Misplaced Childhood', 102),
#  (145, 'Barulhinho Bom', 103),
#  (146, 'Seek And Shall Find: More Of The Best (1963-1981)', 104),
#  (147, 'The Best Of Men At Work', 105),
#  (148, 'Black Album', 50),
#  (149, 'Garage Inc. (Disc 2)', 50),
#  (150, "Kill 'Em All", 50),
#  (151, 'Load', 50),
#  (152, 'Master Of Puppets', 50),
#  (153, 'ReLoad', 50),
#  (154, 'Ride The Lightning', 50),
#  (155, 'St. Anger', 50),
#  (156, '...And Justice For All', 50),
#  (157, 'Miles Ahead', 68),
#  (158, 'Milton Nascimento Ao Vivo', 42),
#  (159, 'Minas', 42),
#  (160, 'Ace Of Spades', 106),
#  (161, 'Demorou...', 108),
#  (162, 'Motley Crue Greatest Hits', 109),
#  (163, 'From The Muddy Banks Of The Wishkah [Live]', 110),
#  (164, 'Nevermind', 110),
#  (165, 'Compositores', 111),
#  (166, 'Olodum', 112),
#  (167, 'Acústico MTV', 113),
#  (168, 'Arquivo II', 113),
#  (169, 'Arquivo Os Paralamas Do Sucesso', 113),
#  (170, 'Bark at the Moon (Remastered)', 114),
#  (171, 'Blizzard of Ozz', 114),
#  (172, 'Diary of a Madman (Remastered)', 114),
#  (173, 'No More Tears (Remastered)', 114),
#  (174, 'Tribute', 114),
#  (175, 'Walking Into Clarksdale', 115),
#  (176, 'Original Soundtracks 1', 116),
#  (177, 'The Beast Live', 117),
#  (178, 'Live On Two Legs [Live]', 118),
#  (179, 'Pearl Jam', 118),
#  (180, 'Riot Act', 118),
#  (181, 'Ten', 118),
#  (182, 'Vs.', 118),
#  (183, 'Dark Side Of The Moon', 120),
#  (184, 'Os Cães Ladram Mas A Caravana Não Pára', 121),
#  (185, 'Greatest Hits I', 51),
#  (186, 'News Of The World', 51),
#  (187, 'Out Of Time', 122),
#  (188, 'Green', 124),
#  (189, 'New Adventures In Hi-Fi', 124),
#  (190, 'The Best Of R.E.M.: The IRS Years', 124),
#  (191, 'Cesta Básica', 125),
#  (192, 'Raul Seixas', 126),
#  (193, 'Blood Sugar Sex Magik', 127),
#  (194, 'By The Way', 127),
#  (195, 'Californication', 127),
#  (196, 'Retrospective I (1974-1980)', 128),
#  (197, 'Santana - As Years Go By', 59),
#  (198, 'Santana Live', 59),
#  (199, 'Maquinarama', 130),
#  (200, 'O Samba Poconé', 130),
#  (201, 'Judas 0: B-Sides and Rarities', 131),
#  (202, 'Rotten Apples: Greatest Hits', 131),
#  (203, 'A-Sides', 132),
#  (204, 'Morning Dance', 53),
#  (205, 'In Step', 133),
#  (206, 'Core', 134),
#  (207, 'Mezmerize', 135),
#  (208, '[1997] Black Light Syndrome', 136),
#  (209, 'Live [Disc 1]', 137),
#  (210, 'Live [Disc 2]', 137),
#  (211, 'The Singles', 138),
#  (212, 'Beyond Good And Evil', 139),
#  (213, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]', 139),
#  (214, 'The Doors', 140),
#  (215, 'The Police Greatest Hits', 141),
#  (216, 'Hot Rocks, 1964-1971 (Disc 1)', 142),
#  (217, 'No Security', 142),
#  (218, 'Voodoo Lounge', 142),
#  (219, 'Tangents', 143),
#  (220, 'Transmission', 143),
#  (221, 'My Generation - The Very Best Of The Who', 144),
#  (222, 'Serie Sem Limite (Disc 1)', 145),
#  (223, 'Serie Sem Limite (Disc 2)', 145),
#  (224, 'Acústico', 146),
#  (225, 'Volume Dois', 146),
#  (226, 'Battlestar Galactica: The Story So Far', 147),
#  (227, 'Battlestar Galactica, Season 3', 147),
#  (228, 'Heroes, Season 1', 148),
#  (229, 'Lost, Season 3', 149),
#  (230, 'Lost, Season 1', 149),
#  (231, 'Lost, Season 2', 149),
#  (232, 'Achtung Baby', 150),
#  (233, "All That You Can't Leave Behind", 150),
#  (234, 'B-Sides 1980-1990', 150),
#  (235, 'How To Dismantle An Atomic Bomb', 150),
#  (236, 'Pop', 150),
#  (237, 'Rattle And Hum', 150),
#  (238, 'The Best Of 1980-1990', 150),
#  (239, 'War', 150),
#  (240, 'Zooropa', 150),
#  (241, 'UB40 The Best Of - Volume Two [UK]', 151),
#  (242, 'Diver Down', 152),
#  (243, 'The Best Of Van Halen, Vol. I', 152),
#  (244, 'Van Halen', 152),
#  (245, 'Van Halen III', 152),
#  (246, 'Contraband', 153),
#  (247, 'Vinicius De Moraes', 72),
#  (248, 'Ao Vivo [IMPORT]', 155),
#  (249, 'The Office, Season 1', 156),
#  (250, 'The Office, Season 2', 156),
#  (251, 'The Office, Season 3', 156),
#  (252, 'Un-Led-Ed', 157),
#  (253, 'Battlestar Galactica (Classic), Season 1', 158),
#  (254, 'Aquaman', 159),
#  (255, 'Instant Karma: The Amnesty International Campaign to Save Darfur', 150),
#  (256, 'Speak of the Devil', 114),
#  (257, '20th Century Masters - The Millennium Collection: The Best of Scorpions', 179),
#  (258, 'House of Pain', 180),
#  (259, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 36),
#  (260, 'Cake: B-Sides and Rarities', 196),
#  (261, 'LOST, Season 4', 149),
#  (262, 'Quiet Songs', 197),
#  (263, 'Muso Ko', 198),
#  (264, 'Realize', 199),
#  (265, 'Every Kind of Light', 200),
#  (266, 'Duos II', 201),
#  (267, 'Worlds', 202),
#  (268, 'The Best of Beethoven', 203),
#  (269, 'Temple of the Dog', 204),
#  (270, 'Carry On', 205),
#  (271, 'Revelations', 8),
#  (272, 'Adorate Deum: Gregorian Chant from the Proper of the Mass', 206),
#  (273, 'Allegri: Miserere', 207),
#  (274, 'Pachelbel: Canon & Gigue', 208),
#  (275, 'Vivaldi: The Four Seasons', 209),
#  (276, 'Bach: Violin Concertos', 210),
#  (277, 'Bach: Goldberg Variations', 211),
#  (278, 'Bach: The Cello Suites', 212),
#  (279, 'Handel: The Messiah (Highlights)', 213),
#  (280, 'The World of Classical Favourites', 214),
#  (281, 'Sir Neville Marriner: A Celebration', 215),
#  (282, 'Mozart: Wind Concertos', 216),
#  (283, 'Haydn: Symphonies 99 - 104', 217),
#  (284, 'Beethoven: Symhonies Nos. 5 & 6', 218),
#  (285, 'A Soprano Inspired', 219),
#  (286, 'Great Opera Choruses', 220),
#  (287, 'Wagner: Favourite Overtures', 221),
#  (288, 'Fauré: Requiem, Ravel: Pavane & Others', 222),
#  (289, 'Tchaikovsky: The Nutcracker', 223),
#  (290, 'The Last Night of the Proms', 224),
#  (291, 'Puccini: Madama Butterfly - Highlights', 225),
#  (292, 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 226),
#  (293, "Pavarotti's Opera Made Easy", 227),
#  (294, "Great Performances - Barber's Adagio and Other Romantic Favorites for Strings", 228),
#  (295, 'Carmina Burana', 229),
#  (296, 'A Copland Celebration, Vol. I', 230),
#  (297, 'Bach: Toccata & Fugue in D Minor', 231),
#  (298, 'Prokofiev: Symphony No.1', 232),
#  (299, 'Scheherazade', 233),
#  (300, 'Bach: The Brandenburg Concertos', 234),
#  (301, 'Chopin: Piano Concertos Nos. 1 & 2', 235),
#  (302, 'Mascagni: Cavalleria Rusticana', 236),
#  (303, 'Sibelius: Finlandia', 237),
#  (304, 'Beethoven Piano Sonatas: Moonlight & Pastorale', 238),
#  (305, 'Great Recordings of the Century - Mahler: Das Lied von der Erde', 240),
#  (306, 'Elgar: Cello Concerto & Vaughan Williams: Fantasias', 241),
#  (307, 'Adams, John: The Chairman Dances', 242),
#  (308, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 243),
#  (309, 'Palestrina: Missa Papae Marcelli & Allegri: Miserere', 244),
#  (310, 'Prokofiev: Romeo & Juliet', 245),
#  (311, 'Strauss: Waltzes', 226),
#  (312, 'Berlioz: Symphonie Fantastique', 245),
#  (313, 'Bizet: Carmen Highlights', 246),
#  (314, 'English Renaissance', 247),
#  (315, 'Handel: Music for the Royal Fireworks (Original Version 1749)', 208),
#  (316, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 248),
#  (317, 'Mozart Gala: Famous Arias', 249),
#  (318, 'SCRIABIN: Vers la flamme', 250),
#  (319, 'Armada: Music from the Courts of England and Spain', 251),
#  (320, 'Mozart: Symphonies Nos. 40 & 41', 248),
#  (321, 'Back to Black', 252),
#  (322, 'Frank', 252),
#  (323, 'Carried to Dust (Bonus Track Version)', 253),
#  (324, "Beethoven: Symphony No. 6 'Pastoral' Etc.", 254),
#  (325, 'Bartok: Violin & Viola Concertos', 255),
#  (326, "Mendelssohn: A Midsummer Night's Dream", 256),
#  (327, 'Bach: Orchestral Suites Nos. 1 - 4', 257),
#  (328, 'Charpentier: Divertissements, Airs & Concerts', 258),
#  (329, 'South American Getaway', 259),
#  (330, 'Górecki: Symphony No. 3', 260),
#  (331, 'Purcell: The Fairy Queen', 261),
#  (332, 'The Ultimate Relexation Album', 262),
#  (333, 'Purcell: Music for the Queen Mary', 263),
#  (334, 'Weill: The Seven Deadly Sins', 264),
#  (335, 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 265),
#  (336, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 248),
#  (337, 'Szymanowski: Piano Works, Vol. 1', 266),
#  (338, 'Nielsen: The Six Symphonies', 267),
#  (339, "Great Recordings of the Century: Paganini's 24 Caprices", 268),
#  (340, "Liszt - 12 Études D'Execution Transcendante", 269),
#  (341, 'Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder', 270),
#  (342, 'Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3', 271),
#  (343, 'Respighi:Pines of Rome', 226),
#  (344, "Schubert: The Late String Quartets & String Quintet (3 CD's)", 272),
#  (345, "Monteverdi: L'Orfeo", 273),
#  (346, 'Mozart: Chamber Music', 274),
#  (347, 'Koyaanisqatsi (Soundtrack from the Motion Picture)', 275)]

# %% [markdown]
# <h2>Join Operators</h2>

# %% [markdown]
# <h3>Inner Join</h3>
# <img src="../media/inner_join.png" width="500"/>

# %%
# %%sql
#
# SELECT Title, AlbumId, artists.ArtistId, albums.ArtistId, Name FROM
# albums INNER JOIN artists ON albums.ArtistID = artists.ArtistID
# Out:
#    sqlite:///Northwind_small.sqlite
#  * sqlite:///chinook.db
# Done.
# [('For Those About To Rock We Salute You', 1, 1, 1, 'AC/DC'),
#  ('Balls to the Wall', 2, 2, 2, 'Accept'),
#  ('Restless and Wild', 3, 2, 2, 'Accept'),
#  ('Let There Be Rock', 4, 1, 1, 'AC/DC'),
#  ('Big Ones', 5, 3, 3, 'Aerosmith'),
#  ('Jagged Little Pill', 6, 4, 4, 'Alanis Morissette'),
#  ('Facelift', 7, 5, 5, 'Alice In Chains'),
#  ('Warner 25 Anos', 8, 6, 6, 'Antônio Carlos Jobim'),
#  ('Plays Metallica By Four Cellos', 9, 7, 7, 'Apocalyptica'),
#  ('Audioslave', 10, 8, 8, 'Audioslave'),
#  ('Out Of Exile', 11, 8, 8, 'Audioslave'),
#  ('BackBeat Soundtrack', 12, 9, 9, 'BackBeat'),
#  ('The Best Of Billy Cobham', 13, 10, 10, 'Billy Cobham'),
#  ('Alcohol Fueled Brewtality Live! [Disc 1]', 14, 11, 11, 'Black Label Society'),
#  ('Alcohol Fueled Brewtality Live! [Disc 2]', 15, 11, 11, 'Black Label Society'),
#  ('Black Sabbath', 16, 12, 12, 'Black Sabbath'),
#  ('Black Sabbath Vol. 4 (Remaster)', 17, 12, 12, 'Black Sabbath'),
#  ('Body Count', 18, 13, 13, 'Body Count'),
#  ('Chemical Wedding', 19, 14, 14, 'Bruce Dickinson'),
#  ('The Best Of Buddy Guy - The Millenium Collection', 20, 15, 15, 'Buddy Guy'),
#  ('Prenda Minha', 21, 16, 16, 'Caetano Veloso'),
#  ('Sozinho Remix Ao Vivo', 22, 16, 16, 'Caetano Veloso'),
#  ('Minha Historia', 23, 17, 17, 'Chico Buarque'),
#  ('Afrociberdelia', 24, 18, 18, 'Chico Science & Nação Zumbi'),
#  ('Da Lama Ao Caos', 25, 18, 18, 'Chico Science & Nação Zumbi'),
#  ('Acústico MTV [Live]', 26, 19, 19, 'Cidade Negra'),
#  ('Cidade Negra - Hits', 27, 19, 19, 'Cidade Negra'),
#  ('Na Pista', 28, 20, 20, 'Cláudio Zoli'),
#  ('Axé Bahia 2001', 29, 21, 21, 'Various Artists'),
#  ('BBC Sessions [Disc 1] [Live]', 30, 22, 22, 'Led Zeppelin'),
#  ('Bongo Fury', 31, 23, 23, 'Frank Zappa & Captain Beefheart'),
#  ('Carnaval 2001', 32, 21, 21, 'Various Artists'),
#  ('Chill: Brazil (Disc 1)', 33, 24, 24, 'Marcos Valle'),
#  ('Chill: Brazil (Disc 2)', 34, 6, 6, 'Antônio Carlos Jobim'),
#  ('Garage Inc. (Disc 1)', 35, 50, 50, 'Metallica'),
#  ('Greatest Hits II', 36, 51, 51, 'Queen'),
#  ('Greatest Kiss', 37, 52, 52, 'Kiss'),
#  ('Heart of the Night', 38, 53, 53, 'Spyro Gyra'),
#  ('International Superhits', 39, 54, 54, 'Green Day'),
#  ('Into The Light', 40, 55, 55, 'David Coverdale'),
#  ('Meus Momentos', 41, 56, 56, 'Gonzaguinha'),
#  ('Minha História', 42, 57, 57, 'Os Mutantes'),
#  ('MK III The Final Concerts [Disc 1]', 43, 58, 58, 'Deep Purple'),
#  ('Physical Graffiti [Disc 1]', 44, 22, 22, 'Led Zeppelin'),
#  ('Sambas De Enredo 2001', 45, 21, 21, 'Various Artists'),
#  ('Supernatural', 46, 59, 59, 'Santana'),
#  ('The Best of Ed Motta', 47, 37, 37, 'Ed Motta'),
#  ('The Essential Miles Davis [Disc 1]', 48, 68, 68, 'Miles Davis'),
#  ('The Essential Miles Davis [Disc 2]', 49, 68, 68, 'Miles Davis'),
#  ('The Final Concerts (Disc 2)', 50, 58, 58, 'Deep Purple'),
#  ("Up An' Atom", 51, 69, 69, 'Gene Krupa'),
#  ('Vinícius De Moraes - Sem Limite', 52, 70, 70, 'Toquinho & Vinícius'),
#  ('Vozes do MPB', 53, 21, 21, 'Various Artists'),
#  ('Chronicle, Vol. 1', 54, 76, 76, 'Creedence Clearwater Revival'),
#  ('Chronicle, Vol. 2', 55, 76, 76, 'Creedence Clearwater Revival'),
#  ('Cássia Eller - Coleção Sem Limite [Disc 2]', 56, 77, 77, 'Cássia Eller'),
#  ('Cássia Eller - Sem Limite [Disc 1]', 57, 77, 77, 'Cássia Eller'),
#  ('Come Taste The Band', 58, 58, 58, 'Deep Purple'),
#  ('Deep Purple In Rock', 59, 58, 58, 'Deep Purple'),
#  ('Fireball', 60, 58, 58, 'Deep Purple'),
#  ("Knocking at Your Back Door: The Best Of Deep Purple in the 80's", 61, 58, 58, 'Deep Purple'),
#  ('Machine Head', 62, 58, 58, 'Deep Purple'),
#  ('Purpendicular', 63, 58, 58, 'Deep Purple'),
#  ('Slaves And Masters', 64, 58, 58, 'Deep Purple'),
#  ('Stormbringer', 65, 58, 58, 'Deep Purple'),
#  ('The Battle Rages On', 66, 58, 58, 'Deep Purple'),
#  ("Vault: Def Leppard's Greatest Hits", 67, 78, 78, 'Def Leppard'),
#  ('Outbreak', 68, 79, 79, 'Dennis Chambers'),
#  ('Djavan Ao Vivo - Vol. 02', 69, 80, 80, 'Djavan'),
#  ('Djavan Ao Vivo - Vol. 1', 70, 80, 80, 'Djavan'),
#  ('Elis Regina-Minha História', 71, 41, 41, 'Elis Regina'),
#  ('The Cream Of Clapton', 72, 81, 81, 'Eric Clapton'),
#  ('Unplugged', 73, 81, 81, 'Eric Clapton'),
#  ('Album Of The Year', 74, 82, 82, 'Faith No More'),
#  ('Angel Dust', 75, 82, 82, 'Faith No More'),
#  ('King For A Day Fool For A Lifetime', 76, 82, 82, 'Faith No More'),
#  ('The Real Thing', 77, 82, 82, 'Faith No More'),
#  ('Deixa Entrar', 78, 83, 83, 'Falamansa'),
#  ('In Your Honor [Disc 1]', 79, 84, 84, 'Foo Fighters'),
#  ('In Your Honor [Disc 2]', 80, 84, 84, 'Foo Fighters'),
#  ('One By One', 81, 84, 84, 'Foo Fighters'),
#  ('The Colour And The Shape', 82, 84, 84, 'Foo Fighters'),
#  ('My Way: The Best Of Frank Sinatra [Disc 1]', 83, 85, 85, 'Frank Sinatra'),
#  ('Roda De Funk', 84, 86, 86, 'Funk Como Le Gusta'),
#  ('As Canções de Eu Tu Eles', 85, 27, 27, 'Gilberto Gil'),
#  ('Quanta Gente Veio Ver (Live)', 86, 27, 27, 'Gilberto Gil'),
#  ('Quanta Gente Veio ver--Bônus De Carnaval', 87, 27, 27, 'Gilberto Gil'),
#  ('Faceless', 88, 87, 87, 'Godsmack'),
#  ('American Idiot', 89, 54, 54, 'Green Day'),
#  ('Appetite for Destruction', 90, 88, 88, "Guns N' Roses"),
#  ('Use Your Illusion I', 91, 88, 88, "Guns N' Roses"),
#  ('Use Your Illusion II', 92, 88, 88, "Guns N' Roses"),
#  ('Blue Moods', 93, 89, 89, 'Incognito'),
#  ('A Matter of Life and Death', 94, 90, 90, 'Iron Maiden'),
#  ('A Real Dead One', 95, 90, 90, 'Iron Maiden'),
#  ('A Real Live One', 96, 90, 90, 'Iron Maiden'),
#  ('Brave New World', 97, 90, 90, 'Iron Maiden'),
#  ('Dance Of Death', 98, 90, 90, 'Iron Maiden'),
#  ('Fear Of The Dark', 99, 90, 90, 'Iron Maiden'),
#  ('Iron Maiden', 100, 90, 90, 'Iron Maiden'),
#  ('Killers', 101, 90, 90, 'Iron Maiden'),
#  ('Live After Death', 102, 90, 90, 'Iron Maiden'),
#  ('Live At Donington 1992 (Disc 1)', 103, 90, 90, 'Iron Maiden'),
#  ('Live At Donington 1992 (Disc 2)', 104, 90, 90, 'Iron Maiden'),
#  ('No Prayer For The Dying', 105, 90, 90, 'Iron Maiden'),
#  ('Piece Of Mind', 106, 90, 90, 'Iron Maiden'),
#  ('Powerslave', 107, 90, 90, 'Iron Maiden'),
#  ('Rock In Rio [CD1]', 108, 90, 90, 'Iron Maiden'),
#  ('Rock In Rio [CD2]', 109, 90, 90, 'Iron Maiden'),
#  ('Seventh Son of a Seventh Son', 110, 90, 90, 'Iron Maiden'),
#  ('Somewhere in Time', 111, 90, 90, 'Iron Maiden'),
#  ('The Number of The Beast', 112, 90, 90, 'Iron Maiden'),
#  ('The X Factor', 113, 90, 90, 'Iron Maiden'),
#  ('Virtual XI', 114, 90, 90, 'Iron Maiden'),
#  ('Sex Machine', 115, 91, 91, 'James Brown'),
#  ('Emergency On Planet Earth', 116, 92, 92, 'Jamiroquai'),
#  ('Synkronized', 117, 92, 92, 'Jamiroquai'),
#  ('The Return Of The Space Cowboy', 118, 92, 92, 'Jamiroquai'),
#  ('Get Born', 119, 93, 93, 'JET'),
#  ('Are You Experienced?', 120, 94, 94, 'Jimi Hendrix'),
#  ('Surfing with the Alien (Remastered)', 121, 95, 95, 'Joe Satriani'),
#  ('Jorge Ben Jor 25 Anos', 122, 46, 46, 'Jorge Ben'),
#  ('Jota Quest-1995', 123, 96, 96, 'Jota Quest'),
#  ('Cafezinho', 124, 97, 97, 'João Suplicy'),
#  ('Living After Midnight', 125, 98, 98, 'Judas Priest'),
#  ('Unplugged [Live]', 126, 52, 52, 'Kiss'),
#  ('BBC Sessions [Disc 2] [Live]', 127, 22, 22, 'Led Zeppelin'),
#  ('Coda', 128, 22, 22, 'Led Zeppelin'),
#  ('Houses Of The Holy', 129, 22, 22, 'Led Zeppelin'),
#  ('In Through The Out Door', 130, 22, 22, 'Led Zeppelin'),
#  ('IV', 131, 22, 22, 'Led Zeppelin'),
#  ('Led Zeppelin I', 132, 22, 22, 'Led Zeppelin'),
#  ('Led Zeppelin II', 133, 22, 22, 'Led Zeppelin'),
#  ('Led Zeppelin III', 134, 22, 22, 'Led Zeppelin'),
#  ('Physical Graffiti [Disc 2]', 135, 22, 22, 'Led Zeppelin'),
#  ('Presence', 136, 22, 22, 'Led Zeppelin'),
#  ('The Song Remains The Same (Disc 1)', 137, 22, 22, 'Led Zeppelin'),
#  ('The Song Remains The Same (Disc 2)', 138, 22, 22, 'Led Zeppelin'),
#  ('A TempestadeTempestade Ou O Livro Dos Dias', 139, 99, 99, 'Legião Urbana'),
#  ('Mais Do Mesmo', 140, 99, 99, 'Legião Urbana'),
#  ('Greatest Hits', 141, 100, 100, 'Lenny Kravitz'),
#  ('Lulu Santos - RCA 100 Anos De Música - Álbum 01', 142, 101, 101, 'Lulu Santos'),
#  ('Lulu Santos - RCA 100 Anos De Música - Álbum 02', 143, 101, 101, 'Lulu Santos'),
#  ('Misplaced Childhood', 144, 102, 102, 'Marillion'),
#  ('Barulhinho Bom', 145, 103, 103, 'Marisa Monte'),
#  ('Seek And Shall Find: More Of The Best (1963-1981)', 146, 104, 104, 'Marvin Gaye'),
#  ('The Best Of Men At Work', 147, 105, 105, 'Men At Work'),
#  ('Black Album', 148, 50, 50, 'Metallica'),
#  ('Garage Inc. (Disc 2)', 149, 50, 50, 'Metallica'),
#  ("Kill 'Em All", 150, 50, 50, 'Metallica'),
#  ('Load', 151, 50, 50, 'Metallica'),
#  ('Master Of Puppets', 152, 50, 50, 'Metallica'),
#  ('ReLoad', 153, 50, 50, 'Metallica'),
#  ('Ride The Lightning', 154, 50, 50, 'Metallica'),
#  ('St. Anger', 155, 50, 50, 'Metallica'),
#  ('...And Justice For All', 156, 50, 50, 'Metallica'),
#  ('Miles Ahead', 157, 68, 68, 'Miles Davis'),
#  ('Milton Nascimento Ao Vivo', 158, 42, 42, 'Milton Nascimento'),
#  ('Minas', 159, 42, 42, 'Milton Nascimento'),
#  ('Ace Of Spades', 160, 106, 106, 'Motörhead'),
#  ('Demorou...', 161, 108, 108, 'Mônica Marianno'),
#  ('Motley Crue Greatest Hits', 162, 109, 109, 'Mötley Crüe'),
#  ('From The Muddy Banks Of The Wishkah [Live]', 163, 110, 110, 'Nirvana'),
#  ('Nevermind', 164, 110, 110, 'Nirvana'),
#  ('Compositores', 165, 111, 111, 'O Terço'),
#  ('Olodum', 166, 112, 112, 'Olodum'),
#  ('Acústico MTV', 167, 113, 113, 'Os Paralamas Do Sucesso'),
#  ('Arquivo II', 168, 113, 113, 'Os Paralamas Do Sucesso'),
#  ('Arquivo Os Paralamas Do Sucesso', 169, 113, 113, 'Os Paralamas Do Sucesso'),
#  ('Bark at the Moon (Remastered)', 170, 114, 114, 'Ozzy Osbourne'),
#  ('Blizzard of Ozz', 171, 114, 114, 'Ozzy Osbourne'),
#  ('Diary of a Madman (Remastered)', 172, 114, 114, 'Ozzy Osbourne'),
#  ('No More Tears (Remastered)', 173, 114, 114, 'Ozzy Osbourne'),
#  ('Tribute', 174, 114, 114, 'Ozzy Osbourne'),
#  ('Walking Into Clarksdale', 175, 115, 115, 'Page & Plant'),
#  ('Original Soundtracks 1', 176, 116, 116, 'Passengers'),
#  ('The Beast Live', 177, 117, 117, "Paul D'Ianno"),
#  ('Live On Two Legs [Live]', 178, 118, 118, 'Pearl Jam'),
#  ('Pearl Jam', 179, 118, 118, 'Pearl Jam'),
#  ('Riot Act', 180, 118, 118, 'Pearl Jam'),
#  ('Ten', 181, 118, 118, 'Pearl Jam'),
#  ('Vs.', 182, 118, 118, 'Pearl Jam'),
#  ('Dark Side Of The Moon', 183, 120, 120, 'Pink Floyd'),
#  ('Os Cães Ladram Mas A Caravana Não Pára', 184, 121, 121, 'Planet Hemp'),
#  ('Greatest Hits I', 185, 51, 51, 'Queen'),
#  ('News Of The World', 186, 51, 51, 'Queen'),
#  ('Out Of Time', 187, 122, 122, 'R.E.M. Feat. Kate Pearson'),
#  ('Green', 188, 124, 124, 'R.E.M.'),
#  ('New Adventures In Hi-Fi', 189, 124, 124, 'R.E.M.'),
#  ('The Best Of R.E.M.: The IRS Years', 190, 124, 124, 'R.E.M.'),
#  ('Cesta Básica', 191, 125, 125, 'Raimundos'),
#  ('Raul Seixas', 192, 126, 126, 'Raul Seixas'),
#  ('Blood Sugar Sex Magik', 193, 127, 127, 'Red Hot Chili Peppers'),
#  ('By The Way', 194, 127, 127, 'Red Hot Chili Peppers'),
#  ('Californication', 195, 127, 127, 'Red Hot Chili Peppers'),
#  ('Retrospective I (1974-1980)', 196, 128, 128, 'Rush'),
#  ('Santana - As Years Go By', 197, 59, 59, 'Santana'),
#  ('Santana Live', 198, 59, 59, 'Santana'),
#  ('Maquinarama', 199, 130, 130, 'Skank'),
#  ('O Samba Poconé', 200, 130, 130, 'Skank'),
#  ('Judas 0: B-Sides and Rarities', 201, 131, 131, 'Smashing Pumpkins'),
#  ('Rotten Apples: Greatest Hits', 202, 131, 131, 'Smashing Pumpkins'),
#  ('A-Sides', 203, 132, 132, 'Soundgarden'),
#  ('Morning Dance', 204, 53, 53, 'Spyro Gyra'),
#  ('In Step', 205, 133, 133, 'Stevie Ray Vaughan & Double Trouble'),
#  ('Core', 206, 134, 134, 'Stone Temple Pilots'),
#  ('Mezmerize', 207, 135, 135, 'System Of A Down'),
#  ('[1997] Black Light Syndrome', 208, 136, 136, 'Terry Bozzio, Tony Levin & Steve Stevens'),
#  ('Live [Disc 1]', 209, 137, 137, 'The Black Crowes'),
#  ('Live [Disc 2]', 210, 137, 137, 'The Black Crowes'),
#  ('The Singles', 211, 138, 138, 'The Clash'),
#  ('Beyond Good And Evil', 212, 139, 139, 'The Cult'),
#  ('Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]', 213, 139, 139, 'The Cult'),
#  ('The Doors', 214, 140, 140, 'The Doors'),
#  ('The Police Greatest Hits', 215, 141, 141, 'The Police'),
#  ('Hot Rocks, 1964-1971 (Disc 1)', 216, 142, 142, 'The Rolling Stones'),
#  ('No Security', 217, 142, 142, 'The Rolling Stones'),
#  ('Voodoo Lounge', 218, 142, 142, 'The Rolling Stones'),
#  ('Tangents', 219, 143, 143, 'The Tea Party'),
#  ('Transmission', 220, 143, 143, 'The Tea Party'),
#  ('My Generation - The Very Best Of The Who', 221, 144, 144, 'The Who'),
#  ('Serie Sem Limite (Disc 1)', 222, 145, 145, 'Tim Maia'),
#  ('Serie Sem Limite (Disc 2)', 223, 145, 145, 'Tim Maia'),
#  ('Acústico', 224, 146, 146, 'Titãs'),
#  ('Volume Dois', 225, 146, 146, 'Titãs'),
#  ('Battlestar Galactica: The Story So Far', 226, 147, 147, 'Battlestar Galactica'),
#  ('Battlestar Galactica, Season 3', 227, 147, 147, 'Battlestar Galactica'),
#  ('Heroes, Season 1', 228, 148, 148, 'Heroes'),
#  ('Lost, Season 3', 229, 149, 149, 'Lost'),
#  ('Lost, Season 1', 230, 149, 149, 'Lost'),
#  ('Lost, Season 2', 231, 149, 149, 'Lost'),
#  ('Achtung Baby', 232, 150, 150, 'U2'),
#  ("All That You Can't Leave Behind", 233, 150, 150, 'U2'),
#  ('B-Sides 1980-1990', 234, 150, 150, 'U2'),
#  ('How To Dismantle An Atomic Bomb', 235, 150, 150, 'U2'),
#  ('Pop', 236, 150, 150, 'U2'),
#  ('Rattle And Hum', 237, 150, 150, 'U2'),
#  ('The Best Of 1980-1990', 238, 150, 150, 'U2'),
#  ('War', 239, 150, 150, 'U2'),
#  ('Zooropa', 240, 150, 150, 'U2'),
#  ('UB40 The Best Of - Volume Two [UK]', 241, 151, 151, 'UB40'),
#  ('Diver Down', 242, 152, 152, 'Van Halen'),
#  ('The Best Of Van Halen, Vol. I', 243, 152, 152, 'Van Halen'),
#  ('Van Halen', 244, 152, 152, 'Van Halen'),
#  ('Van Halen III', 245, 152, 152, 'Van Halen'),
#  ('Contraband', 246, 153, 153, 'Velvet Revolver'),
#  ('Vinicius De Moraes', 247, 72, 72, 'Vinícius De Moraes'),
#  ('Ao Vivo [IMPORT]', 248, 155, 155, 'Zeca Pagodinho'),
#  ('The Office, Season 1', 249, 156, 156, 'The Office'),
#  ('The Office, Season 2', 250, 156, 156, 'The Office'),
#  ('The Office, Season 3', 251, 156, 156, 'The Office'),
#  ('Un-Led-Ed', 252, 157, 157, 'Dread Zeppelin'),
#  ('Battlestar Galactica (Classic), Season 1', 253, 158, 158, 'Battlestar Galactica (Classic)'),
#  ('Aquaman', 254, 159, 159, 'Aquaman'),
#  ('Instant Karma: The Amnesty International Campaign to Save Darfur', 255, 150, 150, 'U2'),
#  ('Speak of the Devil', 256, 114, 114, 'Ozzy Osbourne'),
#  ('20th Century Masters - The Millennium Collection: The Best of Scorpions', 257, 179, 179, 'Scorpions'),
#  ('House of Pain', 258, 180, 180, 'House Of Pain'),
#  ('Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro', 259, 36, 36, 'O Rappa'),
#  ('Cake: B-Sides and Rarities', 260, 196, 196, 'Cake'),
#  ('LOST, Season 4', 261, 149, 149, 'Lost'),
#  ('Quiet Songs', 262, 197, 197, 'Aisha Duo'),
#  ('Muso Ko', 263, 198, 198, 'Habib Koité and Bamada'),
#  ('Realize', 264, 199, 199, 'Karsh Kale'),
#  ('Every Kind of Light', 265, 200, 200, 'The Posies'),
#  ('Duos II', 266, 201, 201, 'Luciana Souza/Romero Lubambo'),
#  ('Worlds', 267, 202, 202, 'Aaron Goldberg'),
#  ('The Best of Beethoven', 268, 203, 203, 'Nicolaus Esterhazy Sinfonia'),
#  ('Temple of the Dog', 269, 204, 204, 'Temple of the Dog'),
#  ('Carry On', 270, 205, 205, 'Chris Cornell'),
#  ('Revelations', 271, 8, 8, 'Audioslave'),
#  ('Adorate Deum: Gregorian Chant from the Proper of the Mass', 272, 206, 206, 'Alberto Turco & Nova Schola Gregoriana'),
#  ('Allegri: Miserere', 273, 207, 207, 'Richard Marlow & The Choir of Trinity College, Cambridge'),
#  ('Pachelbel: Canon & Gigue', 274, 208, 208, 'English Concert & Trevor Pinnock'),
#  ('Vivaldi: The Four Seasons', 275, 209, 209, 'Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker'),
#  ('Bach: Violin Concertos', 276, 210, 210, 'Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer'),
#  ('Bach: Goldberg Variations', 277, 211, 211, 'Wilhelm Kempff'),
#  ('Bach: The Cello Suites', 278, 212, 212, 'Yo-Yo Ma'),
#  ('Handel: The Messiah (Highlights)', 279, 213, 213, 'Scholars Baroque Ensemble'),
#  ('The World of Classical Favourites', 280, 214, 214, 'Academy of St. Martin in the Fields & Sir Neville Marriner'),
#  ('Sir Neville Marriner: A Celebration', 281, 215, 215, 'Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner'),
#  ('Mozart: Wind Concertos', 282, 216, 216, 'Berliner Philharmoniker, Claudio Abbado & Sabine Meyer'),
#  ('Haydn: Symphonies 99 - 104', 283, 217, 217, 'Royal Philharmonic Orchestra & Sir Thomas Beecham'),
#  ('Beethoven: Symhonies Nos. 5 & 6', 284, 218, 218, 'Orchestre Révolutionnaire et Romantique & John Eliot Gardiner'),
#  ('A Soprano Inspired', 285, 219, 219, 'Britten Sinfonia, Ivor Bolton & Lesley Garrett'),
#  ('Great Opera Choruses', 286, 220, 220, 'Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti'),
#  ('Wagner: Favourite Overtures', 287, 221, 221, 'Sir Georg Solti & Wiener Philharmoniker'),
#  ('Fauré: Requiem, Ravel: Pavane & Others', 288, 222, 222, 'Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair'),
#  ('Tchaikovsky: The Nutcracker', 289, 223, 223, 'London Symphony Orchestra & Sir Charles Mackerras'),
#  ('The Last Night of the Proms', 290, 224, 224, 'Barry Wordsworth & BBC Concert Orchestra'),
#  ('Puccini: Madama Butterfly - Highlights', 291, 225, 225, 'Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker'),
#  ('Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies', 292, 226, 226, 'Eugene Ormandy'),
#  ("Pavarotti's Opera Made Easy", 293, 227, 227, 'Luciano Pavarotti'),
#  ("Great Performances - Barber's Adagio and Other Romantic Favorites for Strings", 294, 228, 228, 'Leonard Bernstein & New York Philharmonic'),
#  ('Carmina Burana', 295, 229, 229, 'Boston Symphony Orchestra & Seiji Ozawa'),
#  ('A Copland Celebration, Vol. I', 296, 230, 230, 'Aaron Copland & London Symphony Orchestra'),
#  ('Bach: Toccata & Fugue in D Minor', 297, 231, 231, 'Ton Koopman'),
#  ('Prokofiev: Symphony No.1', 298, 232, 232, 'Sergei Prokofiev & Yuri Temirkanov'),
#  ('Scheherazade', 299, 233, 233, 'Chicago Symphony Orchestra & Fritz Reiner'),
#  ('Bach: The Brandenburg Concertos', 300, 234, 234, 'Orchestra of The Age of Enlightenment'),
#  ('Chopin: Piano Concertos Nos. 1 & 2', 301, 235, 235, 'Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra'),
#  ('Mascagni: Cavalleria Rusticana', 302, 236, 236, 'James Levine'),
#  ('Sibelius: Finlandia', 303, 237, 237, 'Berliner Philharmoniker & Hans Rosbaud'),
#  ('Beethoven Piano Sonatas: Moonlight & Pastorale', 304, 238, 238, 'Maurizio Pollini'),
#  ('Great Recordings of the Century - Mahler: Das Lied von der Erde', 305, 240, 240, 'Gustav Mahler'),
#  ('Elgar: Cello Concerto & Vaughan Williams: Fantasias', 306, 241, 241, 'Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos'),
#  ('Adams, John: The Chairman Dances', 307, 242, 242, 'Edo de Waart & San Francisco Symphony'),
#  ("Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory", 308, 243, 243, 'Antal Doráti & London Symphony Orchestra'),
#  ('Palestrina: Missa Papae Marcelli & Allegri: Miserere', 309, 244, 244, 'Choir Of Westminster Abbey & Simon Preston'),
#  ('Prokofiev: Romeo & Juliet', 310, 245, 245, 'Michael Tilson Thomas & San Francisco Symphony'),
#  ('Strauss: Waltzes', 311, 226, 226, 'Eugene Ormandy'),
#  ('Berlioz: Symphonie Fantastique', 312, 245, 245, 'Michael Tilson Thomas & San Francisco Symphony'),
#  ('Bizet: Carmen Highlights', 313, 246, 246, 'Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker'),
#  ('English Renaissance', 314, 247, 247, "The King's Singers"),
#  ('Handel: Music for the Royal Fireworks (Original Version 1749)', 315, 208, 208, 'English Concert & Trevor Pinnock'),
#  ('Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande', 316, 248, 248, 'Berliner Philharmoniker & Herbert Von Karajan'),
#  ('Mozart Gala: Famous Arias', 317, 249, 249, 'Sir Georg Solti, Sumi Jo & Wiener Philharmoniker'),
#  ('SCRIABIN: Vers la flamme', 318, 250, 250, "Christopher O'Riley"),
#  ('Armada: Music from the Courts of England and Spain', 319, 251, 251, 'Fretwork'),
#  ('Mozart: Symphonies Nos. 40 & 41', 320, 248, 248, 'Berliner Philharmoniker & Herbert Von Karajan'),
#  ('Back to Black', 321, 252, 252, 'Amy Winehouse'),
#  ('Frank', 322, 252, 252, 'Amy Winehouse'),
#  ('Carried to Dust (Bonus Track Version)', 323, 253, 253, 'Calexico'),
#  ("Beethoven: Symphony No. 6 'Pastoral' Etc.", 324, 254, 254, 'Otto Klemperer & Philharmonia Orchestra'),
#  ('Bartok: Violin & Viola Concertos', 325, 255, 255, 'Yehudi Menuhin'),
#  ("Mendelssohn: A Midsummer Night's Dream", 326, 256, 256, 'Philharmonia Orchestra & Sir Neville Marriner'),
#  ('Bach: Orchestral Suites Nos. 1 - 4', 327, 257, 257, 'Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart'),
#  ('Charpentier: Divertissements, Airs & Concerts', 328, 258, 258, 'Les Arts Florissants & William Christie'),
#  ('South American Getaway', 329, 259, 259, 'The 12 Cellists of The Berlin Philharmonic'),
#  ('Górecki: Symphony No. 3', 330, 260, 260, 'Adrian Leaper & Doreen de Feis'),
#  ('Purcell: The Fairy Queen', 331, 261, 261, 'Roger Norrington, London Classical Players'),
#  ('The Ultimate Relexation Album', 332, 262, 262, "Charles Dutoit & L'Orchestre Symphonique de Montréal"),
#  ('Purcell: Music for the Queen Mary', 333, 263, 263, 'Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir'),
#  ('Weill: The Seven Deadly Sins', 334, 264, 264, "Kent Nagano and Orchestre de l'Opéra de Lyon"),
#  ('J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro', 335, 265, 265, 'Julian Bream'),
#  ('Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps', 336, 248, 248, 'Berliner Philharmoniker & Herbert Von Karajan'),
#  ('Szymanowski: Piano Works, Vol. 1', 337, 266, 266, 'Martin Roscoe'),
#  ('Nielsen: The Six Symphonies', 338, 267, 267, 'Göteborgs Symfoniker & Neeme Järvi'),
#  ("Great Recordings of the Century: Paganini's 24 Caprices", 339, 268, 268, 'Itzhak Perlman'),
#  ("Liszt - 12 Études D'Execution Transcendante", 340, 269, 269, 'Michele Campanella'),
#  ('Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder', 341, 270, 270, 'Gerald Moore'),
#  ('Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3', 342, 271, 271, 'Mela Tenenbaum, Pro Musica Prague & Richard Kapp'),
#  ('Respighi:Pines of Rome', 343, 226, 226, 'Eugene Ormandy'),
#  ("Schubert: The Late String Quartets & String Quintet (3 CD's)", 344, 272, 272, 'Emerson String Quartet'),
#  ("Monteverdi: L'Orfeo", 345, 273, 273, 'C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu'),
#  ('Mozart: Chamber Music', 346, 274, 274, 'Nash Ensemble'),
#  ('Koyaanisqatsi (Soundtrack from the Motion Picture)', 347, 275, 275, 'Philip Glass Ensemble')]

# %% [markdown]
# <h3>Left Join</h3>
# <img src="../media/left_join.png" width="500"/>

# %%
# %%sql
# SELECT artists.Name, artists.ArtistID, AlbumId, Title  FROM artists LEFT JOIN albums ON albums.ArtistId = artists.ArtistID
# Out:
#    sqlite:///Northwind_small.sqlite
#  * sqlite:///chinook.db
# Done.
# [('AC/DC', 1, 1, 'For Those About To Rock We Salute You'),
#  ('AC/DC', 1, 4, 'Let There Be Rock'),
#  ('Accept', 2, 2, 'Balls to the Wall'),
#  ('Accept', 2, 3, 'Restless and Wild'),
#  ('Aerosmith', 3, 5, 'Big Ones'),
#  ('Alanis Morissette', 4, 6, 'Jagged Little Pill'),
#  ('Alice In Chains', 5, 7, 'Facelift'),
#  ('Antônio Carlos Jobim', 6, 8, 'Warner 25 Anos'),
#  ('Antônio Carlos Jobim', 6, 34, 'Chill: Brazil (Disc 2)'),
#  ('Apocalyptica', 7, 9, 'Plays Metallica By Four Cellos'),
#  ('Audioslave', 8, 10, 'Audioslave'),
#  ('Audioslave', 8, 11, 'Out Of Exile'),
#  ('Audioslave', 8, 271, 'Revelations'),
#  ('BackBeat', 9, 12, 'BackBeat Soundtrack'),
#  ('Billy Cobham', 10, 13, 'The Best Of Billy Cobham'),
#  ('Black Label Society', 11, 14, 'Alcohol Fueled Brewtality Live! [Disc 1]'),
#  ('Black Label Society', 11, 15, 'Alcohol Fueled Brewtality Live! [Disc 2]'),
#  ('Black Sabbath', 12, 16, 'Black Sabbath'),
#  ('Black Sabbath', 12, 17, 'Black Sabbath Vol. 4 (Remaster)'),
#  ('Body Count', 13, 18, 'Body Count'),
#  ('Bruce Dickinson', 14, 19, 'Chemical Wedding'),
#  ('Buddy Guy', 15, 20, 'The Best Of Buddy Guy - The Millenium Collection'),
#  ('Caetano Veloso', 16, 21, 'Prenda Minha'),
#  ('Caetano Veloso', 16, 22, 'Sozinho Remix Ao Vivo'),
#  ('Chico Buarque', 17, 23, 'Minha Historia'),
#  ('Chico Science & Nação Zumbi', 18, 24, 'Afrociberdelia'),
#  ('Chico Science & Nação Zumbi', 18, 25, 'Da Lama Ao Caos'),
#  ('Cidade Negra', 19, 26, 'Acústico MTV [Live]'),
#  ('Cidade Negra', 19, 27, 'Cidade Negra - Hits'),
#  ('Cláudio Zoli', 20, 28, 'Na Pista'),
#  ('Various Artists', 21, 29, 'Axé Bahia 2001'),
#  ('Various Artists', 21, 32, 'Carnaval 2001'),
#  ('Various Artists', 21, 45, 'Sambas De Enredo 2001'),
#  ('Various Artists', 21, 53, 'Vozes do MPB'),
#  ('Led Zeppelin', 22, 30, 'BBC Sessions [Disc 1] [Live]'),
#  ('Led Zeppelin', 22, 44, 'Physical Graffiti [Disc 1]'),
#  ('Led Zeppelin', 22, 127, 'BBC Sessions [Disc 2] [Live]'),
#  ('Led Zeppelin', 22, 128, 'Coda'),
#  ('Led Zeppelin', 22, 129, 'Houses Of The Holy'),
#  ('Led Zeppelin', 22, 130, 'In Through The Out Door'),
#  ('Led Zeppelin', 22, 131, 'IV'),
#  ('Led Zeppelin', 22, 132, 'Led Zeppelin I'),
#  ('Led Zeppelin', 22, 133, 'Led Zeppelin II'),
#  ('Led Zeppelin', 22, 134, 'Led Zeppelin III'),
#  ('Led Zeppelin', 22, 135, 'Physical Graffiti [Disc 2]'),
#  ('Led Zeppelin', 22, 136, 'Presence'),
#  ('Led Zeppelin', 22, 137, 'The Song Remains The Same (Disc 1)'),
#  ('Led Zeppelin', 22, 138, 'The Song Remains The Same (Disc 2)'),
#  ('Frank Zappa & Captain Beefheart', 23, 31, 'Bongo Fury'),
#  ('Marcos Valle', 24, 33, 'Chill: Brazil (Disc 1)'),
#  ('Milton Nascimento & Bebeto', 25, None, None),
#  ('Azymuth', 26, None, None),
#  ('Gilberto Gil', 27, 85, 'As Canções de Eu Tu Eles'),
#  ('Gilberto Gil', 27, 86, 'Quanta Gente Veio Ver (Live)'),
#  ('Gilberto Gil', 27, 87, 'Quanta Gente Veio ver--Bônus De Carnaval'),
#  ('João Gilberto', 28, None, None),
#  ('Bebel Gilberto', 29, None, None),
#  ('Jorge Vercilo', 30, None, None),
#  ('Baby Consuelo', 31, None, None),
#  ('Ney Matogrosso', 32, None, None),
#  ('Luiz Melodia', 33, None, None),
#  ('Nando Reis', 34, None, None),
#  ('Pedro Luís & A Parede', 35, None, None),
#  ('O Rappa', 36, 259, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro'),
#  ('Ed Motta', 37, 47, 'The Best of Ed Motta'),
#  ('Banda Black Rio', 38, None, None),
#  ('Fernanda Porto', 39, None, None),
#  ('Os Cariocas', 40, None, None),
#  ('Elis Regina', 41, 71, 'Elis Regina-Minha História'),
#  ('Milton Nascimento', 42, 158, 'Milton Nascimento Ao Vivo'),
#  ('Milton Nascimento', 42, 159, 'Minas'),
#  ('A Cor Do Som', 43, None, None),
#  ('Kid Abelha', 44, None, None),
#  ('Sandra De Sá', 45, None, None),
#  ('Jorge Ben', 46, 122, 'Jorge Ben Jor 25 Anos'),
#  ('Hermeto Pascoal', 47, None, None),
#  ('Barão Vermelho', 48, None, None),
#  ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', 49, None, None),
#  ('Metallica', 50, 35, 'Garage Inc. (Disc 1)'),
#  ('Metallica', 50, 148, 'Black Album'),
#  ('Metallica', 50, 149, 'Garage Inc. (Disc 2)'),
#  ('Metallica', 50, 150, "Kill 'Em All"),
#  ('Metallica', 50, 151, 'Load'),
#  ('Metallica', 50, 152, 'Master Of Puppets'),
#  ('Metallica', 50, 153, 'ReLoad'),
#  ('Metallica', 50, 154, 'Ride The Lightning'),
#  ('Metallica', 50, 155, 'St. Anger'),
#  ('Metallica', 50, 156, '...And Justice For All'),
#  ('Queen', 51, 36, 'Greatest Hits II'),
#  ('Queen', 51, 185, 'Greatest Hits I'),
#  ('Queen', 51, 186, 'News Of The World'),
#  ('Kiss', 52, 37, 'Greatest Kiss'),
#  ('Kiss', 52, 126, 'Unplugged [Live]'),
#  ('Spyro Gyra', 53, 38, 'Heart of the Night'),
#  ('Spyro Gyra', 53, 204, 'Morning Dance'),
#  ('Green Day', 54, 39, 'International Superhits'),
#  ('Green Day', 54, 89, 'American Idiot'),
#  ('David Coverdale', 55, 40, 'Into The Light'),
#  ('Gonzaguinha', 56, 41, 'Meus Momentos'),
#  ('Os Mutantes', 57, 42, 'Minha História'),
#  ('Deep Purple', 58, 43, 'MK III The Final Concerts [Disc 1]'),
#  ('Deep Purple', 58, 50, 'The Final Concerts (Disc 2)'),
#  ('Deep Purple', 58, 58, 'Come Taste The Band'),
#  ('Deep Purple', 58, 59, 'Deep Purple In Rock'),
#  ('Deep Purple', 58, 60, 'Fireball'),
#  ('Deep Purple', 58, 61, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's"),
#  ('Deep Purple', 58, 62, 'Machine Head'),
#  ('Deep Purple', 58, 63, 'Purpendicular'),
#  ('Deep Purple', 58, 64, 'Slaves And Masters'),
#  ('Deep Purple', 58, 65, 'Stormbringer'),
#  ('Deep Purple', 58, 66, 'The Battle Rages On'),
#  ('Santana', 59, 46, 'Supernatural'),
#  ('Santana', 59, 197, 'Santana - As Years Go By'),
#  ('Santana', 59, 198, 'Santana Live'),
#  ('Santana Feat. Dave Matthews', 60, None, None),
#  ('Santana Feat. Everlast', 61, None, None),
#  ('Santana Feat. Rob Thomas', 62, None, None),
#  ('Santana Feat. Lauryn Hill & Cee-Lo', 63, None, None),
#  ('Santana Feat. The Project G&B', 64, None, None),
#  ('Santana Feat. Maná', 65, None, None),
#  ('Santana Feat. Eagle-Eye Cherry', 66, None, None),
#  ('Santana Feat. Eric Clapton', 67, None, None),
#  ('Miles Davis', 68, 48, 'The Essential Miles Davis [Disc 1]'),
#  ('Miles Davis', 68, 49, 'The Essential Miles Davis [Disc 2]'),
#  ('Miles Davis', 68, 157, 'Miles Ahead'),
#  ('Gene Krupa', 69, 51, "Up An' Atom"),
#  ('Toquinho & Vinícius', 70, 52, 'Vinícius De Moraes - Sem Limite'),
#  ('Vinícius De Moraes & Baden Powell', 71, None, None),
#  ('Vinícius De Moraes', 72, 247, 'Vinicius De Moraes'),
#  ('Vinícius E Qurteto Em Cy', 73, None, None),
#  ('Vinícius E Odette Lara', 74, None, None),
#  ('Vinicius, Toquinho & Quarteto Em Cy', 75, None, None),
#  ('Creedence Clearwater Revival', 76, 54, 'Chronicle, Vol. 1'),
#  ('Creedence Clearwater Revival', 76, 55, 'Chronicle, Vol. 2'),
#  ('Cássia Eller', 77, 56, 'Cássia Eller - Coleção Sem Limite [Disc 2]'),
#  ('Cássia Eller', 77, 57, 'Cássia Eller - Sem Limite [Disc 1]'),
#  ('Def Leppard', 78, 67, "Vault: Def Leppard's Greatest Hits"),
#  ('Dennis Chambers', 79, 68, 'Outbreak'),
#  ('Djavan', 80, 69, 'Djavan Ao Vivo - Vol. 02'),
#  ('Djavan', 80, 70, 'Djavan Ao Vivo - Vol. 1'),
#  ('Eric Clapton', 81, 72, 'The Cream Of Clapton'),
#  ('Eric Clapton', 81, 73, 'Unplugged'),
#  ('Faith No More', 82, 74, 'Album Of The Year'),
#  ('Faith No More', 82, 75, 'Angel Dust'),
#  ('Faith No More', 82, 76, 'King For A Day Fool For A Lifetime'),
#  ('Faith No More', 82, 77, 'The Real Thing'),
#  ('Falamansa', 83, 78, 'Deixa Entrar'),
#  ('Foo Fighters', 84, 79, 'In Your Honor [Disc 1]'),
#  ('Foo Fighters', 84, 80, 'In Your Honor [Disc 2]'),
#  ('Foo Fighters', 84, 81, 'One By One'),
#  ('Foo Fighters', 84, 82, 'The Colour And The Shape'),
#  ('Frank Sinatra', 85, 83, 'My Way: The Best Of Frank Sinatra [Disc 1]'),
#  ('Funk Como Le Gusta', 86, 84, 'Roda De Funk'),
#  ('Godsmack', 87, 88, 'Faceless'),
#  ("Guns N' Roses", 88, 90, 'Appetite for Destruction'),
#  ("Guns N' Roses", 88, 91, 'Use Your Illusion I'),
#  ("Guns N' Roses", 88, 92, 'Use Your Illusion II'),
#  ('Incognito', 89, 93, 'Blue Moods'),
#  ('Iron Maiden', 90, 94, 'A Matter of Life and Death'),
#  ('Iron Maiden', 90, 95, 'A Real Dead One'),
#  ('Iron Maiden', 90, 96, 'A Real Live One'),
#  ('Iron Maiden', 90, 97, 'Brave New World'),
#  ('Iron Maiden', 90, 98, 'Dance Of Death'),
#  ('Iron Maiden', 90, 99, 'Fear Of The Dark'),
#  ('Iron Maiden', 90, 100, 'Iron Maiden'),
#  ('Iron Maiden', 90, 101, 'Killers'),
#  ('Iron Maiden', 90, 102, 'Live After Death'),
#  ('Iron Maiden', 90, 103, 'Live At Donington 1992 (Disc 1)'),
#  ('Iron Maiden', 90, 104, 'Live At Donington 1992 (Disc 2)'),
#  ('Iron Maiden', 90, 105, 'No Prayer For The Dying'),
#  ('Iron Maiden', 90, 106, 'Piece Of Mind'),
#  ('Iron Maiden', 90, 107, 'Powerslave'),
#  ('Iron Maiden', 90, 108, 'Rock In Rio [CD1]'),
#  ('Iron Maiden', 90, 109, 'Rock In Rio [CD2]'),
#  ('Iron Maiden', 90, 110, 'Seventh Son of a Seventh Son'),
#  ('Iron Maiden', 90, 111, 'Somewhere in Time'),
#  ('Iron Maiden', 90, 112, 'The Number of The Beast'),
#  ('Iron Maiden', 90, 113, 'The X Factor'),
#  ('Iron Maiden', 90, 114, 'Virtual XI'),
#  ('James Brown', 91, 115, 'Sex Machine'),
#  ('Jamiroquai', 92, 116, 'Emergency On Planet Earth'),
#  ('Jamiroquai', 92, 117, 'Synkronized'),
#  ('Jamiroquai', 92, 118, 'The Return Of The Space Cowboy'),
#  ('JET', 93, 119, 'Get Born'),
#  ('Jimi Hendrix', 94, 120, 'Are You Experienced?'),
#  ('Joe Satriani', 95, 121, 'Surfing with the Alien (Remastered)'),
#  ('Jota Quest', 96, 123, 'Jota Quest-1995'),
#  ('João Suplicy', 97, 124, 'Cafezinho'),
#  ('Judas Priest', 98, 125, 'Living After Midnight'),
#  ('Legião Urbana', 99, 139, 'A TempestadeTempestade Ou O Livro Dos Dias'),
#  ('Legião Urbana', 99, 140, 'Mais Do Mesmo'),
#  ('Lenny Kravitz', 100, 141, 'Greatest Hits'),
#  ('Lulu Santos', 101, 142, 'Lulu Santos - RCA 100 Anos De Música - Álbum 01'),
#  ('Lulu Santos', 101, 143, 'Lulu Santos - RCA 100 Anos De Música - Álbum 02'),
#  ('Marillion', 102, 144, 'Misplaced Childhood'),
#  ('Marisa Monte', 103, 145, 'Barulhinho Bom'),
#  ('Marvin Gaye', 104, 146, 'Seek And Shall Find: More Of The Best (1963-1981)'),
#  ('Men At Work', 105, 147, 'The Best Of Men At Work'),
#  ('Motörhead', 106, 160, 'Ace Of Spades'),
#  ('Motörhead & Girlschool', 107, None, None),
#  ('Mônica Marianno', 108, 161, 'Demorou...'),
#  ('Mötley Crüe', 109, 162, 'Motley Crue Greatest Hits'),
#  ('Nirvana', 110, 163, 'From The Muddy Banks Of The Wishkah [Live]'),
#  ('Nirvana', 110, 164, 'Nevermind'),
#  ('O Terço', 111, 165, 'Compositores'),
#  ('Olodum', 112, 166, 'Olodum'),
#  ('Os Paralamas Do Sucesso', 113, 167, 'Acústico MTV'),
#  ('Os Paralamas Do Sucesso', 113, 168, 'Arquivo II'),
#  ('Os Paralamas Do Sucesso', 113, 169, 'Arquivo Os Paralamas Do Sucesso'),
#  ('Ozzy Osbourne', 114, 170, 'Bark at the Moon (Remastered)'),
#  ('Ozzy Osbourne', 114, 171, 'Blizzard of Ozz'),
#  ('Ozzy Osbourne', 114, 172, 'Diary of a Madman (Remastered)'),
#  ('Ozzy Osbourne', 114, 173, 'No More Tears (Remastered)'),
#  ('Ozzy Osbourne', 114, 174, 'Tribute'),
#  ('Ozzy Osbourne', 114, 256, 'Speak of the Devil'),
#  ('Page & Plant', 115, 175, 'Walking Into Clarksdale'),
#  ('Passengers', 116, 176, 'Original Soundtracks 1'),
#  ("Paul D'Ianno", 117, 177, 'The Beast Live'),
#  ('Pearl Jam', 118, 178, 'Live On Two Legs [Live]'),
#  ('Pearl Jam', 118, 179, 'Pearl Jam'),
#  ('Pearl Jam', 118, 180, 'Riot Act'),
#  ('Pearl Jam', 118, 181, 'Ten'),
#  ('Pearl Jam', 118, 182, 'Vs.'),
#  ('Peter Tosh', 119, None, None),
#  ('Pink Floyd', 120, 183, 'Dark Side Of The Moon'),
#  ('Planet Hemp', 121, 184, 'Os Cães Ladram Mas A Caravana Não Pára'),
#  ('R.E.M. Feat. Kate Pearson', 122, 187, 'Out Of Time'),
#  ('R.E.M. Feat. KRS-One', 123, None, None),
#  ('R.E.M.', 124, 188, 'Green'),
#  ('R.E.M.', 124, 189, 'New Adventures In Hi-Fi'),
#  ('R.E.M.', 124, 190, 'The Best Of R.E.M.: The IRS Years'),
#  ('Raimundos', 125, 191, 'Cesta Básica'),
#  ('Raul Seixas', 126, 192, 'Raul Seixas'),
#  ('Red Hot Chili Peppers', 127, 193, 'Blood Sugar Sex Magik'),
#  ('Red Hot Chili Peppers', 127, 194, 'By The Way'),
#  ('Red Hot Chili Peppers', 127, 195, 'Californication'),
#  ('Rush', 128, 196, 'Retrospective I (1974-1980)'),
#  ('Simply Red', 129, None, None),
#  ('Skank', 130, 199, 'Maquinarama'),
#  ('Skank', 130, 200, 'O Samba Poconé'),
#  ('Smashing Pumpkins', 131, 201, 'Judas 0: B-Sides and Rarities'),
#  ('Smashing Pumpkins', 131, 202, 'Rotten Apples: Greatest Hits'),
#  ('Soundgarden', 132, 203, 'A-Sides'),
#  ('Stevie Ray Vaughan & Double Trouble', 133, 205, 'In Step'),
#  ('Stone Temple Pilots', 134, 206, 'Core'),
#  ('System Of A Down', 135, 207, 'Mezmerize'),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 136, 208, '[1997] Black Light Syndrome'),
#  ('The Black Crowes', 137, 209, 'Live [Disc 1]'),
#  ('The Black Crowes', 137, 210, 'Live [Disc 2]'),
#  ('The Clash', 138, 211, 'The Singles'),
#  ('The Cult', 139, 212, 'Beyond Good And Evil'),
#  ('The Cult', 139, 213, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]'),
#  ('The Doors', 140, 214, 'The Doors'),
#  ('The Police', 141, 215, 'The Police Greatest Hits'),
#  ('The Rolling Stones', 142, 216, 'Hot Rocks, 1964-1971 (Disc 1)'),
#  ('The Rolling Stones', 142, 217, 'No Security'),
#  ('The Rolling Stones', 142, 218, 'Voodoo Lounge'),
#  ('The Tea Party', 143, 219, 'Tangents'),
#  ('The Tea Party', 143, 220, 'Transmission'),
#  ('The Who', 144, 221, 'My Generation - The Very Best Of The Who'),
#  ('Tim Maia', 145, 222, 'Serie Sem Limite (Disc 1)'),
#  ('Tim Maia', 145, 223, 'Serie Sem Limite (Disc 2)'),
#  ('Titãs', 146, 224, 'Acústico'),
#  ('Titãs', 146, 225, 'Volume Dois'),
#  ('Battlestar Galactica', 147, 226, 'Battlestar Galactica: The Story So Far'),
#  ('Battlestar Galactica', 147, 227, 'Battlestar Galactica, Season 3'),
#  ('Heroes', 148, 228, 'Heroes, Season 1'),
#  ('Lost', 149, 229, 'Lost, Season 3'),
#  ('Lost', 149, 230, 'Lost, Season 1'),
#  ('Lost', 149, 231, 'Lost, Season 2'),
#  ('Lost', 149, 261, 'LOST, Season 4'),
#  ('U2', 150, 232, 'Achtung Baby'),
#  ('U2', 150, 233, "All That You Can't Leave Behind"),
#  ('U2', 150, 234, 'B-Sides 1980-1990'),
#  ('U2', 150, 235, 'How To Dismantle An Atomic Bomb'),
#  ('U2', 150, 236, 'Pop'),
#  ('U2', 150, 237, 'Rattle And Hum'),
#  ('U2', 150, 238, 'The Best Of 1980-1990'),
#  ('U2', 150, 239, 'War'),
#  ('U2', 150, 240, 'Zooropa'),
#  ('U2', 150, 255, 'Instant Karma: The Amnesty International Campaign to Save Darfur'),
#  ('UB40', 151, 241, 'UB40 The Best Of - Volume Two [UK]'),
#  ('Van Halen', 152, 242, 'Diver Down'),
#  ('Van Halen', 152, 243, 'The Best Of Van Halen, Vol. I'),
#  ('Van Halen', 152, 244, 'Van Halen'),
#  ('Van Halen', 152, 245, 'Van Halen III'),
#  ('Velvet Revolver', 153, 246, 'Contraband'),
#  ('Whitesnake', 154, None, None),
#  ('Zeca Pagodinho', 155, 248, 'Ao Vivo [IMPORT]'),
#  ('The Office', 156, 249, 'The Office, Season 1'),
#  ('The Office', 156, 250, 'The Office, Season 2'),
#  ('The Office', 156, 251, 'The Office, Season 3'),
#  ('Dread Zeppelin', 157, 252, 'Un-Led-Ed'),
#  ('Battlestar Galactica (Classic)', 158, 253, 'Battlestar Galactica (Classic), Season 1'),
#  ('Aquaman', 159, 254, 'Aquaman'),
#  ('Christina Aguilera featuring BigElf', 160, None, None),
#  ("Aerosmith & Sierra Leone's Refugee Allstars", 161, None, None),
#  ('Los Lonely Boys', 162, None, None),
#  ('Corinne Bailey Rae', 163, None, None),
#  ('Dhani Harrison & Jakob Dylan', 164, None, None),
#  ('Jackson Browne', 165, None, None),
#  ('Avril Lavigne', 166, None, None),
#  ('Big & Rich', 167, None, None),
#  ("Youssou N'Dour", 168, None, None),
#  ('Black Eyed Peas', 169, None, None),
#  ('Jack Johnson', 170, None, None),
#  ('Ben Harper', 171, None, None),
#  ('Snow Patrol', 172, None, None),
#  ('Matisyahu', 173, None, None),
#  ('The Postal Service', 174, None, None),
#  ('Jaguares', 175, None, None),
#  ('The Flaming Lips', 176, None, None),
#  ("Jack's Mannequin & Mick Fleetwood", 177, None, None),
#  ('Regina Spektor', 178, None, None),
#  ('Scorpions', 179, 257, '20th Century Masters - The Millennium Collection: The Best of Scorpions'),
#  ('House Of Pain', 180, 258, 'House of Pain'),
#  ('Xis', 181, None, None),
#  ('Nega Gizza', 182, None, None),
#  ('Gustavo & Andres Veiga & Salazar', 183, None, None),
#  ('Rodox', 184, None, None),
#  ('Charlie Brown Jr.', 185, None, None),
#  ('Pedro Luís E A Parede', 186, None, None),
#  ('Los Hermanos', 187, None, None),
#  ('Mundo Livre S/A', 188, None, None),
#  ('Otto', 189, None, None),
#  ('Instituto', 190, None, None),
#  ('Nação Zumbi', 191, None, None),
#  ('DJ Dolores & Orchestra Santa Massa', 192, None, None),
#  ('Seu Jorge', 193, None, None),
#  ('Sabotage E Instituto', 194, None, None),
#  ('Stereo Maracana', 195, None, None),
#  ('Cake', 196, 260, 'Cake: B-Sides and Rarities'),
#  ('Aisha Duo', 197, 262, 'Quiet Songs'),
#  ('Habib Koité and Bamada', 198, 263, 'Muso Ko'),
#  ('Karsh Kale', 199, 264, 'Realize'),
#  ('The Posies', 200, 265, 'Every Kind of Light'),
#  ('Luciana Souza/Romero Lubambo', 201, 266, 'Duos II'),
#  ('Aaron Goldberg', 202, 267, 'Worlds'),
#  ('Nicolaus Esterhazy Sinfonia', 203, 268, 'The Best of Beethoven'),
#  ('Temple of the Dog', 204, 269, 'Temple of the Dog'),
#  ('Chris Cornell', 205, 270, 'Carry On'),
#  ('Alberto Turco & Nova Schola Gregoriana', 206, 272, 'Adorate Deum: Gregorian Chant from the Proper of the Mass'),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 207, 273, 'Allegri: Miserere'),
#  ('English Concert & Trevor Pinnock', 208, 274, 'Pachelbel: Canon & Gigue'),
#  ('English Concert & Trevor Pinnock', 208, 315, 'Handel: Music for the Royal Fireworks (Original Version 1749)'),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 209, 275, 'Vivaldi: The Four Seasons'),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 210, 276, 'Bach: Violin Concertos'),
#  ('Wilhelm Kempff', 211, 277, 'Bach: Goldberg Variations'),
#  ('Yo-Yo Ma', 212, 278, 'Bach: The Cello Suites'),
#  ('Scholars Baroque Ensemble', 213, 279, 'Handel: The Messiah (Highlights)'),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 214, 280, 'The World of Classical Favourites'),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 215, 281, 'Sir Neville Marriner: A Celebration'),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 216, 282, 'Mozart: Wind Concertos'),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 217, 283, 'Haydn: Symphonies 99 - 104'),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 218, 284, 'Beethoven: Symhonies Nos. 5 & 6'),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 219, 285, 'A Soprano Inspired'),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 220, 286, 'Great Opera Choruses'),
#  ('Sir Georg Solti & Wiener Philharmoniker', 221, 287, 'Wagner: Favourite Overtures'),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 222, 288, 'Fauré: Requiem, Ravel: Pavane & Others'),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 223, 289, 'Tchaikovsky: The Nutcracker'),
#  ('Barry Wordsworth & BBC Concert Orchestra', 224, 290, 'The Last Night of the Proms'),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 225, 291, 'Puccini: Madama Butterfly - Highlights'),
#  ('Eugene Ormandy', 226, 292, 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies'),
#  ('Eugene Ormandy', 226, 311, 'Strauss: Waltzes'),
#  ('Eugene Ormandy', 226, 343, 'Respighi:Pines of Rome'),
#  ('Luciano Pavarotti', 227, 293, "Pavarotti's Opera Made Easy"),
#  ('Leonard Bernstein & New York Philharmonic', 228, 294, "Great Performances - Barber's Adagio and Other Romantic Favorites for Strings"),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 229, 295, 'Carmina Burana'),
#  ('Aaron Copland & London Symphony Orchestra', 230, 296, 'A Copland Celebration, Vol. I'),
#  ('Ton Koopman', 231, 297, 'Bach: Toccata & Fugue in D Minor'),
#  ('Sergei Prokofiev & Yuri Temirkanov', 232, 298, 'Prokofiev: Symphony No.1'),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 233, 299, 'Scheherazade'),
#  ('Orchestra of The Age of Enlightenment', 234, 300, 'Bach: The Brandenburg Concertos'),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 235, 301, 'Chopin: Piano Concertos Nos. 1 & 2'),
#  ('James Levine', 236, 302, 'Mascagni: Cavalleria Rusticana'),
#  ('Berliner Philharmoniker & Hans Rosbaud', 237, 303, 'Sibelius: Finlandia'),
#  ('Maurizio Pollini', 238, 304, 'Beethoven Piano Sonatas: Moonlight & Pastorale'),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', 239, None, None),
#  ('Gustav Mahler', 240, 305, 'Great Recordings of the Century - Mahler: Das Lied von der Erde'),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 241, 306, 'Elgar: Cello Concerto & Vaughan Williams: Fantasias'),
#  ('Edo de Waart & San Francisco Symphony', 242, 307, 'Adams, John: The Chairman Dances'),
#  ('Antal Doráti & London Symphony Orchestra', 243, 308, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory"),
#  ('Choir Of Westminster Abbey & Simon Preston', 244, 309, 'Palestrina: Missa Papae Marcelli & Allegri: Miserere'),
#  ('Michael Tilson Thomas & San Francisco Symphony', 245, 310, 'Prokofiev: Romeo & Juliet'),
#  ('Michael Tilson Thomas & San Francisco Symphony', 245, 312, 'Berlioz: Symphonie Fantastique'),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 246, 313, 'Bizet: Carmen Highlights'),
#  ("The King's Singers", 247, 314, 'English Renaissance'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 316, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 320, 'Mozart: Symphonies Nos. 40 & 41'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 336, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps'),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 249, 317, 'Mozart Gala: Famous Arias'),
#  ("Christopher O'Riley", 250, 318, 'SCRIABIN: Vers la flamme'),
#  ('Fretwork', 251, 319, 'Armada: Music from the Courts of England and Spain'),
#  ('Amy Winehouse', 252, 321, 'Back to Black'),
#  ('Amy Winehouse', 252, 322, 'Frank'),
#  ('Calexico', 253, 323, 'Carried to Dust (Bonus Track Version)'),
#  ('Otto Klemperer & Philharmonia Orchestra', 254, 324, "Beethoven: Symphony No. 6 'Pastoral' Etc."),
#  ('Yehudi Menuhin', 255, 325, 'Bartok: Violin & Viola Concertos'),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 256, 326, "Mendelssohn: A Midsummer Night's Dream"),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 257, 327, 'Bach: Orchestral Suites Nos. 1 - 4'),
#  ('Les Arts Florissants & William Christie', 258, 328, 'Charpentier: Divertissements, Airs & Concerts'),
#  ('The 12 Cellists of The Berlin Philharmonic', 259, 329, 'South American Getaway'),
#  ('Adrian Leaper & Doreen de Feis', 260, 330, 'Górecki: Symphony No. 3'),
#  ('Roger Norrington, London Classical Players', 261, 331, 'Purcell: The Fairy Queen'),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 262, 332, 'The Ultimate Relexation Album'),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 263, 333, 'Purcell: Music for the Queen Mary'),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 264, 334, 'Weill: The Seven Deadly Sins'),
#  ('Julian Bream', 265, 335, 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro'),
#  ('Martin Roscoe', 266, 337, 'Szymanowski: Piano Works, Vol. 1'),
#  ('Göteborgs Symfoniker & Neeme Järvi', 267, 338, 'Nielsen: The Six Symphonies'),
#  ('Itzhak Perlman', 268, 339, "Great Recordings of the Century: Paganini's 24 Caprices"),
#  ('Michele Campanella', 269, 340, "Liszt - 12 Études D'Execution Transcendante"),
#  ('Gerald Moore', 270, 341, 'Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder'),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 271, 342, 'Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3'),
#  ('Emerson String Quartet', 272, 344, "Schubert: The Late String Quartets & String Quintet (3 CD's)"),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 273, 345, "Monteverdi: L'Orfeo"),
#  ('Nash Ensemble', 274, 346, 'Mozart: Chamber Music'),
#  ('Philip Glass Ensemble', 275, 347, 'Koyaanisqatsi (Soundtrack from the Motion Picture)')]

# %%
# %%sql
#
# SELECT artists.Name, artists.ArtistId, AlbumId, Title FROM artists LEFT JOIN albums ON albums.ArtistID = artists.ArtistID
# Out:
#  * sqlite:///chinook.db
# Done.
# [('AC/DC', 1, 1, 'For Those About To Rock We Salute You'),
#  ('AC/DC', 1, 4, 'Let There Be Rock'),
#  ('Accept', 2, 2, 'Balls to the Wall'),
#  ('Accept', 2, 3, 'Restless and Wild'),
#  ('Aerosmith', 3, 5, 'Big Ones'),
#  ('Alanis Morissette', 4, 6, 'Jagged Little Pill'),
#  ('Alice In Chains', 5, 7, 'Facelift'),
#  ('Antônio Carlos Jobim', 6, 8, 'Warner 25 Anos'),
#  ('Antônio Carlos Jobim', 6, 34, 'Chill: Brazil (Disc 2)'),
#  ('Apocalyptica', 7, 9, 'Plays Metallica By Four Cellos'),
#  ('Audioslave', 8, 10, 'Audioslave'),
#  ('Audioslave', 8, 11, 'Out Of Exile'),
#  ('Audioslave', 8, 271, 'Revelations'),
#  ('BackBeat', 9, 12, 'BackBeat Soundtrack'),
#  ('Billy Cobham', 10, 13, 'The Best Of Billy Cobham'),
#  ('Black Label Society', 11, 14, 'Alcohol Fueled Brewtality Live! [Disc 1]'),
#  ('Black Label Society', 11, 15, 'Alcohol Fueled Brewtality Live! [Disc 2]'),
#  ('Black Sabbath', 12, 16, 'Black Sabbath'),
#  ('Black Sabbath', 12, 17, 'Black Sabbath Vol. 4 (Remaster)'),
#  ('Body Count', 13, 18, 'Body Count'),
#  ('Bruce Dickinson', 14, 19, 'Chemical Wedding'),
#  ('Buddy Guy', 15, 20, 'The Best Of Buddy Guy - The Millenium Collection'),
#  ('Caetano Veloso', 16, 21, 'Prenda Minha'),
#  ('Caetano Veloso', 16, 22, 'Sozinho Remix Ao Vivo'),
#  ('Chico Buarque', 17, 23, 'Minha Historia'),
#  ('Chico Science & Nação Zumbi', 18, 24, 'Afrociberdelia'),
#  ('Chico Science & Nação Zumbi', 18, 25, 'Da Lama Ao Caos'),
#  ('Cidade Negra', 19, 26, 'Acústico MTV [Live]'),
#  ('Cidade Negra', 19, 27, 'Cidade Negra - Hits'),
#  ('Cláudio Zoli', 20, 28, 'Na Pista'),
#  ('Various Artists', 21, 29, 'Axé Bahia 2001'),
#  ('Various Artists', 21, 32, 'Carnaval 2001'),
#  ('Various Artists', 21, 45, 'Sambas De Enredo 2001'),
#  ('Various Artists', 21, 53, 'Vozes do MPB'),
#  ('Led Zeppelin', 22, 30, 'BBC Sessions [Disc 1] [Live]'),
#  ('Led Zeppelin', 22, 44, 'Physical Graffiti [Disc 1]'),
#  ('Led Zeppelin', 22, 127, 'BBC Sessions [Disc 2] [Live]'),
#  ('Led Zeppelin', 22, 128, 'Coda'),
#  ('Led Zeppelin', 22, 129, 'Houses Of The Holy'),
#  ('Led Zeppelin', 22, 130, 'In Through The Out Door'),
#  ('Led Zeppelin', 22, 131, 'IV'),
#  ('Led Zeppelin', 22, 132, 'Led Zeppelin I'),
#  ('Led Zeppelin', 22, 133, 'Led Zeppelin II'),
#  ('Led Zeppelin', 22, 134, 'Led Zeppelin III'),
#  ('Led Zeppelin', 22, 135, 'Physical Graffiti [Disc 2]'),
#  ('Led Zeppelin', 22, 136, 'Presence'),
#  ('Led Zeppelin', 22, 137, 'The Song Remains The Same (Disc 1)'),
#  ('Led Zeppelin', 22, 138, 'The Song Remains The Same (Disc 2)'),
#  ('Frank Zappa & Captain Beefheart', 23, 31, 'Bongo Fury'),
#  ('Marcos Valle', 24, 33, 'Chill: Brazil (Disc 1)'),
#  ('Milton Nascimento & Bebeto', 25, None, None),
#  ('Azymuth', 26, None, None),
#  ('Gilberto Gil', 27, 85, 'As Canções de Eu Tu Eles'),
#  ('Gilberto Gil', 27, 86, 'Quanta Gente Veio Ver (Live)'),
#  ('Gilberto Gil', 27, 87, 'Quanta Gente Veio ver--Bônus De Carnaval'),
#  ('João Gilberto', 28, None, None),
#  ('Bebel Gilberto', 29, None, None),
#  ('Jorge Vercilo', 30, None, None),
#  ('Baby Consuelo', 31, None, None),
#  ('Ney Matogrosso', 32, None, None),
#  ('Luiz Melodia', 33, None, None),
#  ('Nando Reis', 34, None, None),
#  ('Pedro Luís & A Parede', 35, None, None),
#  ('O Rappa', 36, 259, 'Radio Brasil (O Som da Jovem Vanguarda) - Seleccao de Henrique Amaro'),
#  ('Ed Motta', 37, 47, 'The Best of Ed Motta'),
#  ('Banda Black Rio', 38, None, None),
#  ('Fernanda Porto', 39, None, None),
#  ('Os Cariocas', 40, None, None),
#  ('Elis Regina', 41, 71, 'Elis Regina-Minha História'),
#  ('Milton Nascimento', 42, 158, 'Milton Nascimento Ao Vivo'),
#  ('Milton Nascimento', 42, 159, 'Minas'),
#  ('A Cor Do Som', 43, None, None),
#  ('Kid Abelha', 44, None, None),
#  ('Sandra De Sá', 45, None, None),
#  ('Jorge Ben', 46, 122, 'Jorge Ben Jor 25 Anos'),
#  ('Hermeto Pascoal', 47, None, None),
#  ('Barão Vermelho', 48, None, None),
#  ('Edson, DJ Marky & DJ Patife Featuring Fernanda Porto', 49, None, None),
#  ('Metallica', 50, 35, 'Garage Inc. (Disc 1)'),
#  ('Metallica', 50, 148, 'Black Album'),
#  ('Metallica', 50, 149, 'Garage Inc. (Disc 2)'),
#  ('Metallica', 50, 150, "Kill 'Em All"),
#  ('Metallica', 50, 151, 'Load'),
#  ('Metallica', 50, 152, 'Master Of Puppets'),
#  ('Metallica', 50, 153, 'ReLoad'),
#  ('Metallica', 50, 154, 'Ride The Lightning'),
#  ('Metallica', 50, 155, 'St. Anger'),
#  ('Metallica', 50, 156, '...And Justice For All'),
#  ('Queen', 51, 36, 'Greatest Hits II'),
#  ('Queen', 51, 185, 'Greatest Hits I'),
#  ('Queen', 51, 186, 'News Of The World'),
#  ('Kiss', 52, 37, 'Greatest Kiss'),
#  ('Kiss', 52, 126, 'Unplugged [Live]'),
#  ('Spyro Gyra', 53, 38, 'Heart of the Night'),
#  ('Spyro Gyra', 53, 204, 'Morning Dance'),
#  ('Green Day', 54, 39, 'International Superhits'),
#  ('Green Day', 54, 89, 'American Idiot'),
#  ('David Coverdale', 55, 40, 'Into The Light'),
#  ('Gonzaguinha', 56, 41, 'Meus Momentos'),
#  ('Os Mutantes', 57, 42, 'Minha História'),
#  ('Deep Purple', 58, 43, 'MK III The Final Concerts [Disc 1]'),
#  ('Deep Purple', 58, 50, 'The Final Concerts (Disc 2)'),
#  ('Deep Purple', 58, 58, 'Come Taste The Band'),
#  ('Deep Purple', 58, 59, 'Deep Purple In Rock'),
#  ('Deep Purple', 58, 60, 'Fireball'),
#  ('Deep Purple', 58, 61, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's"),
#  ('Deep Purple', 58, 62, 'Machine Head'),
#  ('Deep Purple', 58, 63, 'Purpendicular'),
#  ('Deep Purple', 58, 64, 'Slaves And Masters'),
#  ('Deep Purple', 58, 65, 'Stormbringer'),
#  ('Deep Purple', 58, 66, 'The Battle Rages On'),
#  ('Santana', 59, 46, 'Supernatural'),
#  ('Santana', 59, 197, 'Santana - As Years Go By'),
#  ('Santana', 59, 198, 'Santana Live'),
#  ('Santana Feat. Dave Matthews', 60, None, None),
#  ('Santana Feat. Everlast', 61, None, None),
#  ('Santana Feat. Rob Thomas', 62, None, None),
#  ('Santana Feat. Lauryn Hill & Cee-Lo', 63, None, None),
#  ('Santana Feat. The Project G&B', 64, None, None),
#  ('Santana Feat. Maná', 65, None, None),
#  ('Santana Feat. Eagle-Eye Cherry', 66, None, None),
#  ('Santana Feat. Eric Clapton', 67, None, None),
#  ('Miles Davis', 68, 48, 'The Essential Miles Davis [Disc 1]'),
#  ('Miles Davis', 68, 49, 'The Essential Miles Davis [Disc 2]'),
#  ('Miles Davis', 68, 157, 'Miles Ahead'),
#  ('Gene Krupa', 69, 51, "Up An' Atom"),
#  ('Toquinho & Vinícius', 70, 52, 'Vinícius De Moraes - Sem Limite'),
#  ('Vinícius De Moraes & Baden Powell', 71, None, None),
#  ('Vinícius De Moraes', 72, 247, 'Vinicius De Moraes'),
#  ('Vinícius E Qurteto Em Cy', 73, None, None),
#  ('Vinícius E Odette Lara', 74, None, None),
#  ('Vinicius, Toquinho & Quarteto Em Cy', 75, None, None),
#  ('Creedence Clearwater Revival', 76, 54, 'Chronicle, Vol. 1'),
#  ('Creedence Clearwater Revival', 76, 55, 'Chronicle, Vol. 2'),
#  ('Cássia Eller', 77, 56, 'Cássia Eller - Coleção Sem Limite [Disc 2]'),
#  ('Cássia Eller', 77, 57, 'Cássia Eller - Sem Limite [Disc 1]'),
#  ('Def Leppard', 78, 67, "Vault: Def Leppard's Greatest Hits"),
#  ('Dennis Chambers', 79, 68, 'Outbreak'),
#  ('Djavan', 80, 69, 'Djavan Ao Vivo - Vol. 02'),
#  ('Djavan', 80, 70, 'Djavan Ao Vivo - Vol. 1'),
#  ('Eric Clapton', 81, 72, 'The Cream Of Clapton'),
#  ('Eric Clapton', 81, 73, 'Unplugged'),
#  ('Faith No More', 82, 74, 'Album Of The Year'),
#  ('Faith No More', 82, 75, 'Angel Dust'),
#  ('Faith No More', 82, 76, 'King For A Day Fool For A Lifetime'),
#  ('Faith No More', 82, 77, 'The Real Thing'),
#  ('Falamansa', 83, 78, 'Deixa Entrar'),
#  ('Foo Fighters', 84, 79, 'In Your Honor [Disc 1]'),
#  ('Foo Fighters', 84, 80, 'In Your Honor [Disc 2]'),
#  ('Foo Fighters', 84, 81, 'One By One'),
#  ('Foo Fighters', 84, 82, 'The Colour And The Shape'),
#  ('Frank Sinatra', 85, 83, 'My Way: The Best Of Frank Sinatra [Disc 1]'),
#  ('Funk Como Le Gusta', 86, 84, 'Roda De Funk'),
#  ('Godsmack', 87, 88, 'Faceless'),
#  ("Guns N' Roses", 88, 90, 'Appetite for Destruction'),
#  ("Guns N' Roses", 88, 91, 'Use Your Illusion I'),
#  ("Guns N' Roses", 88, 92, 'Use Your Illusion II'),
#  ('Incognito', 89, 93, 'Blue Moods'),
#  ('Iron Maiden', 90, 94, 'A Matter of Life and Death'),
#  ('Iron Maiden', 90, 95, 'A Real Dead One'),
#  ('Iron Maiden', 90, 96, 'A Real Live One'),
#  ('Iron Maiden', 90, 97, 'Brave New World'),
#  ('Iron Maiden', 90, 98, 'Dance Of Death'),
#  ('Iron Maiden', 90, 99, 'Fear Of The Dark'),
#  ('Iron Maiden', 90, 100, 'Iron Maiden'),
#  ('Iron Maiden', 90, 101, 'Killers'),
#  ('Iron Maiden', 90, 102, 'Live After Death'),
#  ('Iron Maiden', 90, 103, 'Live At Donington 1992 (Disc 1)'),
#  ('Iron Maiden', 90, 104, 'Live At Donington 1992 (Disc 2)'),
#  ('Iron Maiden', 90, 105, 'No Prayer For The Dying'),
#  ('Iron Maiden', 90, 106, 'Piece Of Mind'),
#  ('Iron Maiden', 90, 107, 'Powerslave'),
#  ('Iron Maiden', 90, 108, 'Rock In Rio [CD1]'),
#  ('Iron Maiden', 90, 109, 'Rock In Rio [CD2]'),
#  ('Iron Maiden', 90, 110, 'Seventh Son of a Seventh Son'),
#  ('Iron Maiden', 90, 111, 'Somewhere in Time'),
#  ('Iron Maiden', 90, 112, 'The Number of The Beast'),
#  ('Iron Maiden', 90, 113, 'The X Factor'),
#  ('Iron Maiden', 90, 114, 'Virtual XI'),
#  ('James Brown', 91, 115, 'Sex Machine'),
#  ('Jamiroquai', 92, 116, 'Emergency On Planet Earth'),
#  ('Jamiroquai', 92, 117, 'Synkronized'),
#  ('Jamiroquai', 92, 118, 'The Return Of The Space Cowboy'),
#  ('JET', 93, 119, 'Get Born'),
#  ('Jimi Hendrix', 94, 120, 'Are You Experienced?'),
#  ('Joe Satriani', 95, 121, 'Surfing with the Alien (Remastered)'),
#  ('Jota Quest', 96, 123, 'Jota Quest-1995'),
#  ('João Suplicy', 97, 124, 'Cafezinho'),
#  ('Judas Priest', 98, 125, 'Living After Midnight'),
#  ('Legião Urbana', 99, 139, 'A TempestadeTempestade Ou O Livro Dos Dias'),
#  ('Legião Urbana', 99, 140, 'Mais Do Mesmo'),
#  ('Lenny Kravitz', 100, 141, 'Greatest Hits'),
#  ('Lulu Santos', 101, 142, 'Lulu Santos - RCA 100 Anos De Música - Álbum 01'),
#  ('Lulu Santos', 101, 143, 'Lulu Santos - RCA 100 Anos De Música - Álbum 02'),
#  ('Marillion', 102, 144, 'Misplaced Childhood'),
#  ('Marisa Monte', 103, 145, 'Barulhinho Bom'),
#  ('Marvin Gaye', 104, 146, 'Seek And Shall Find: More Of The Best (1963-1981)'),
#  ('Men At Work', 105, 147, 'The Best Of Men At Work'),
#  ('Motörhead', 106, 160, 'Ace Of Spades'),
#  ('Motörhead & Girlschool', 107, None, None),
#  ('Mônica Marianno', 108, 161, 'Demorou...'),
#  ('Mötley Crüe', 109, 162, 'Motley Crue Greatest Hits'),
#  ('Nirvana', 110, 163, 'From The Muddy Banks Of The Wishkah [Live]'),
#  ('Nirvana', 110, 164, 'Nevermind'),
#  ('O Terço', 111, 165, 'Compositores'),
#  ('Olodum', 112, 166, 'Olodum'),
#  ('Os Paralamas Do Sucesso', 113, 167, 'Acústico MTV'),
#  ('Os Paralamas Do Sucesso', 113, 168, 'Arquivo II'),
#  ('Os Paralamas Do Sucesso', 113, 169, 'Arquivo Os Paralamas Do Sucesso'),
#  ('Ozzy Osbourne', 114, 170, 'Bark at the Moon (Remastered)'),
#  ('Ozzy Osbourne', 114, 171, 'Blizzard of Ozz'),
#  ('Ozzy Osbourne', 114, 172, 'Diary of a Madman (Remastered)'),
#  ('Ozzy Osbourne', 114, 173, 'No More Tears (Remastered)'),
#  ('Ozzy Osbourne', 114, 174, 'Tribute'),
#  ('Ozzy Osbourne', 114, 256, 'Speak of the Devil'),
#  ('Page & Plant', 115, 175, 'Walking Into Clarksdale'),
#  ('Passengers', 116, 176, 'Original Soundtracks 1'),
#  ("Paul D'Ianno", 117, 177, 'The Beast Live'),
#  ('Pearl Jam', 118, 178, 'Live On Two Legs [Live]'),
#  ('Pearl Jam', 118, 179, 'Pearl Jam'),
#  ('Pearl Jam', 118, 180, 'Riot Act'),
#  ('Pearl Jam', 118, 181, 'Ten'),
#  ('Pearl Jam', 118, 182, 'Vs.'),
#  ('Peter Tosh', 119, None, None),
#  ('Pink Floyd', 120, 183, 'Dark Side Of The Moon'),
#  ('Planet Hemp', 121, 184, 'Os Cães Ladram Mas A Caravana Não Pára'),
#  ('R.E.M. Feat. Kate Pearson', 122, 187, 'Out Of Time'),
#  ('R.E.M. Feat. KRS-One', 123, None, None),
#  ('R.E.M.', 124, 188, 'Green'),
#  ('R.E.M.', 124, 189, 'New Adventures In Hi-Fi'),
#  ('R.E.M.', 124, 190, 'The Best Of R.E.M.: The IRS Years'),
#  ('Raimundos', 125, 191, 'Cesta Básica'),
#  ('Raul Seixas', 126, 192, 'Raul Seixas'),
#  ('Red Hot Chili Peppers', 127, 193, 'Blood Sugar Sex Magik'),
#  ('Red Hot Chili Peppers', 127, 194, 'By The Way'),
#  ('Red Hot Chili Peppers', 127, 195, 'Californication'),
#  ('Rush', 128, 196, 'Retrospective I (1974-1980)'),
#  ('Simply Red', 129, None, None),
#  ('Skank', 130, 199, 'Maquinarama'),
#  ('Skank', 130, 200, 'O Samba Poconé'),
#  ('Smashing Pumpkins', 131, 201, 'Judas 0: B-Sides and Rarities'),
#  ('Smashing Pumpkins', 131, 202, 'Rotten Apples: Greatest Hits'),
#  ('Soundgarden', 132, 203, 'A-Sides'),
#  ('Stevie Ray Vaughan & Double Trouble', 133, 205, 'In Step'),
#  ('Stone Temple Pilots', 134, 206, 'Core'),
#  ('System Of A Down', 135, 207, 'Mezmerize'),
#  ('Terry Bozzio, Tony Levin & Steve Stevens', 136, 208, '[1997] Black Light Syndrome'),
#  ('The Black Crowes', 137, 209, 'Live [Disc 1]'),
#  ('The Black Crowes', 137, 210, 'Live [Disc 2]'),
#  ('The Clash', 138, 211, 'The Singles'),
#  ('The Cult', 139, 212, 'Beyond Good And Evil'),
#  ('The Cult', 139, 213, 'Pure Cult: The Best Of The Cult (For Rockers, Ravers, Lovers & Sinners) [UK]'),
#  ('The Doors', 140, 214, 'The Doors'),
#  ('The Police', 141, 215, 'The Police Greatest Hits'),
#  ('The Rolling Stones', 142, 216, 'Hot Rocks, 1964-1971 (Disc 1)'),
#  ('The Rolling Stones', 142, 217, 'No Security'),
#  ('The Rolling Stones', 142, 218, 'Voodoo Lounge'),
#  ('The Tea Party', 143, 219, 'Tangents'),
#  ('The Tea Party', 143, 220, 'Transmission'),
#  ('The Who', 144, 221, 'My Generation - The Very Best Of The Who'),
#  ('Tim Maia', 145, 222, 'Serie Sem Limite (Disc 1)'),
#  ('Tim Maia', 145, 223, 'Serie Sem Limite (Disc 2)'),
#  ('Titãs', 146, 224, 'Acústico'),
#  ('Titãs', 146, 225, 'Volume Dois'),
#  ('Battlestar Galactica', 147, 226, 'Battlestar Galactica: The Story So Far'),
#  ('Battlestar Galactica', 147, 227, 'Battlestar Galactica, Season 3'),
#  ('Heroes', 148, 228, 'Heroes, Season 1'),
#  ('Lost', 149, 229, 'Lost, Season 3'),
#  ('Lost', 149, 230, 'Lost, Season 1'),
#  ('Lost', 149, 231, 'Lost, Season 2'),
#  ('Lost', 149, 261, 'LOST, Season 4'),
#  ('U2', 150, 232, 'Achtung Baby'),
#  ('U2', 150, 233, "All That You Can't Leave Behind"),
#  ('U2', 150, 234, 'B-Sides 1980-1990'),
#  ('U2', 150, 235, 'How To Dismantle An Atomic Bomb'),
#  ('U2', 150, 236, 'Pop'),
#  ('U2', 150, 237, 'Rattle And Hum'),
#  ('U2', 150, 238, 'The Best Of 1980-1990'),
#  ('U2', 150, 239, 'War'),
#  ('U2', 150, 240, 'Zooropa'),
#  ('U2', 150, 255, 'Instant Karma: The Amnesty International Campaign to Save Darfur'),
#  ('UB40', 151, 241, 'UB40 The Best Of - Volume Two [UK]'),
#  ('Van Halen', 152, 242, 'Diver Down'),
#  ('Van Halen', 152, 243, 'The Best Of Van Halen, Vol. I'),
#  ('Van Halen', 152, 244, 'Van Halen'),
#  ('Van Halen', 152, 245, 'Van Halen III'),
#  ('Velvet Revolver', 153, 246, 'Contraband'),
#  ('Whitesnake', 154, None, None),
#  ('Zeca Pagodinho', 155, 248, 'Ao Vivo [IMPORT]'),
#  ('The Office', 156, 249, 'The Office, Season 1'),
#  ('The Office', 156, 250, 'The Office, Season 2'),
#  ('The Office', 156, 251, 'The Office, Season 3'),
#  ('Dread Zeppelin', 157, 252, 'Un-Led-Ed'),
#  ('Battlestar Galactica (Classic)', 158, 253, 'Battlestar Galactica (Classic), Season 1'),
#  ('Aquaman', 159, 254, 'Aquaman'),
#  ('Christina Aguilera featuring BigElf', 160, None, None),
#  ("Aerosmith & Sierra Leone's Refugee Allstars", 161, None, None),
#  ('Los Lonely Boys', 162, None, None),
#  ('Corinne Bailey Rae', 163, None, None),
#  ('Dhani Harrison & Jakob Dylan', 164, None, None),
#  ('Jackson Browne', 165, None, None),
#  ('Avril Lavigne', 166, None, None),
#  ('Big & Rich', 167, None, None),
#  ("Youssou N'Dour", 168, None, None),
#  ('Black Eyed Peas', 169, None, None),
#  ('Jack Johnson', 170, None, None),
#  ('Ben Harper', 171, None, None),
#  ('Snow Patrol', 172, None, None),
#  ('Matisyahu', 173, None, None),
#  ('The Postal Service', 174, None, None),
#  ('Jaguares', 175, None, None),
#  ('The Flaming Lips', 176, None, None),
#  ("Jack's Mannequin & Mick Fleetwood", 177, None, None),
#  ('Regina Spektor', 178, None, None),
#  ('Scorpions', 179, 257, '20th Century Masters - The Millennium Collection: The Best of Scorpions'),
#  ('House Of Pain', 180, 258, 'House of Pain'),
#  ('Xis', 181, None, None),
#  ('Nega Gizza', 182, None, None),
#  ('Gustavo & Andres Veiga & Salazar', 183, None, None),
#  ('Rodox', 184, None, None),
#  ('Charlie Brown Jr.', 185, None, None),
#  ('Pedro Luís E A Parede', 186, None, None),
#  ('Los Hermanos', 187, None, None),
#  ('Mundo Livre S/A', 188, None, None),
#  ('Otto', 189, None, None),
#  ('Instituto', 190, None, None),
#  ('Nação Zumbi', 191, None, None),
#  ('DJ Dolores & Orchestra Santa Massa', 192, None, None),
#  ('Seu Jorge', 193, None, None),
#  ('Sabotage E Instituto', 194, None, None),
#  ('Stereo Maracana', 195, None, None),
#  ('Cake', 196, 260, 'Cake: B-Sides and Rarities'),
#  ('Aisha Duo', 197, 262, 'Quiet Songs'),
#  ('Habib Koité and Bamada', 198, 263, 'Muso Ko'),
#  ('Karsh Kale', 199, 264, 'Realize'),
#  ('The Posies', 200, 265, 'Every Kind of Light'),
#  ('Luciana Souza/Romero Lubambo', 201, 266, 'Duos II'),
#  ('Aaron Goldberg', 202, 267, 'Worlds'),
#  ('Nicolaus Esterhazy Sinfonia', 203, 268, 'The Best of Beethoven'),
#  ('Temple of the Dog', 204, 269, 'Temple of the Dog'),
#  ('Chris Cornell', 205, 270, 'Carry On'),
#  ('Alberto Turco & Nova Schola Gregoriana', 206, 272, 'Adorate Deum: Gregorian Chant from the Proper of the Mass'),
#  ('Richard Marlow & The Choir of Trinity College, Cambridge', 207, 273, 'Allegri: Miserere'),
#  ('English Concert & Trevor Pinnock', 208, 274, 'Pachelbel: Canon & Gigue'),
#  ('English Concert & Trevor Pinnock', 208, 315, 'Handel: Music for the Royal Fireworks (Original Version 1749)'),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 209, 275, 'Vivaldi: The Four Seasons'),
#  ('Hilary Hahn, Jeffrey Kahane, Los Angeles Chamber Orchestra & Margaret Batjer', 210, 276, 'Bach: Violin Concertos'),
#  ('Wilhelm Kempff', 211, 277, 'Bach: Goldberg Variations'),
#  ('Yo-Yo Ma', 212, 278, 'Bach: The Cello Suites'),
#  ('Scholars Baroque Ensemble', 213, 279, 'Handel: The Messiah (Highlights)'),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 214, 280, 'The World of Classical Favourites'),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 215, 281, 'Sir Neville Marriner: A Celebration'),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 216, 282, 'Mozart: Wind Concertos'),
#  ('Royal Philharmonic Orchestra & Sir Thomas Beecham', 217, 283, 'Haydn: Symphonies 99 - 104'),
#  ('Orchestre Révolutionnaire et Romantique & John Eliot Gardiner', 218, 284, 'Beethoven: Symhonies Nos. 5 & 6'),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 219, 285, 'A Soprano Inspired'),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 220, 286, 'Great Opera Choruses'),
#  ('Sir Georg Solti & Wiener Philharmoniker', 221, 287, 'Wagner: Favourite Overtures'),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 222, 288, 'Fauré: Requiem, Ravel: Pavane & Others'),
#  ('London Symphony Orchestra & Sir Charles Mackerras', 223, 289, 'Tchaikovsky: The Nutcracker'),
#  ('Barry Wordsworth & BBC Concert Orchestra', 224, 290, 'The Last Night of the Proms'),
#  ('Herbert Von Karajan, Mirella Freni & Wiener Philharmoniker', 225, 291, 'Puccini: Madama Butterfly - Highlights'),
#  ('Eugene Ormandy', 226, 292, 'Holst: The Planets, Op. 32 & Vaughan Williams: Fantasies'),
#  ('Eugene Ormandy', 226, 311, 'Strauss: Waltzes'),
#  ('Eugene Ormandy', 226, 343, 'Respighi:Pines of Rome'),
#  ('Luciano Pavarotti', 227, 293, "Pavarotti's Opera Made Easy"),
#  ('Leonard Bernstein & New York Philharmonic', 228, 294, "Great Performances - Barber's Adagio and Other Romantic Favorites for Strings"),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 229, 295, 'Carmina Burana'),
#  ('Aaron Copland & London Symphony Orchestra', 230, 296, 'A Copland Celebration, Vol. I'),
#  ('Ton Koopman', 231, 297, 'Bach: Toccata & Fugue in D Minor'),
#  ('Sergei Prokofiev & Yuri Temirkanov', 232, 298, 'Prokofiev: Symphony No.1'),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 233, 299, 'Scheherazade'),
#  ('Orchestra of The Age of Enlightenment', 234, 300, 'Bach: The Brandenburg Concertos'),
#  ('Emanuel Ax, Eugene Ormandy & Philadelphia Orchestra', 235, 301, 'Chopin: Piano Concertos Nos. 1 & 2'),
#  ('James Levine', 236, 302, 'Mascagni: Cavalleria Rusticana'),
#  ('Berliner Philharmoniker & Hans Rosbaud', 237, 303, 'Sibelius: Finlandia'),
#  ('Maurizio Pollini', 238, 304, 'Beethoven Piano Sonatas: Moonlight & Pastorale'),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', 239, None, None),
#  ('Gustav Mahler', 240, 305, 'Great Recordings of the Century - Mahler: Das Lied von der Erde'),
#  ('Felix Schmidt, London Symphony Orchestra & Rafael Frühbeck de Burgos', 241, 306, 'Elgar: Cello Concerto & Vaughan Williams: Fantasias'),
#  ('Edo de Waart & San Francisco Symphony', 242, 307, 'Adams, John: The Chairman Dances'),
#  ('Antal Doráti & London Symphony Orchestra', 243, 308, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory"),
#  ('Choir Of Westminster Abbey & Simon Preston', 244, 309, 'Palestrina: Missa Papae Marcelli & Allegri: Miserere'),
#  ('Michael Tilson Thomas & San Francisco Symphony', 245, 310, 'Prokofiev: Romeo & Juliet'),
#  ('Michael Tilson Thomas & San Francisco Symphony', 245, 312, 'Berlioz: Symphonie Fantastique'),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 246, 313, 'Bizet: Carmen Highlights'),
#  ("The King's Singers", 247, 314, 'English Renaissance'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 316, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 320, 'Mozart: Symphonies Nos. 40 & 41'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 336, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps'),
#  ('Sir Georg Solti, Sumi Jo & Wiener Philharmoniker', 249, 317, 'Mozart Gala: Famous Arias'),
#  ("Christopher O'Riley", 250, 318, 'SCRIABIN: Vers la flamme'),
#  ('Fretwork', 251, 319, 'Armada: Music from the Courts of England and Spain'),
#  ('Amy Winehouse', 252, 321, 'Back to Black'),
#  ('Amy Winehouse', 252, 322, 'Frank'),
#  ('Calexico', 253, 323, 'Carried to Dust (Bonus Track Version)'),
#  ('Otto Klemperer & Philharmonia Orchestra', 254, 324, "Beethoven: Symphony No. 6 'Pastoral' Etc."),
#  ('Yehudi Menuhin', 255, 325, 'Bartok: Violin & Viola Concertos'),
#  ('Philharmonia Orchestra & Sir Neville Marriner', 256, 326, "Mendelssohn: A Midsummer Night's Dream"),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 257, 327, 'Bach: Orchestral Suites Nos. 1 - 4'),
#  ('Les Arts Florissants & William Christie', 258, 328, 'Charpentier: Divertissements, Airs & Concerts'),
#  ('The 12 Cellists of The Berlin Philharmonic', 259, 329, 'South American Getaway'),
#  ('Adrian Leaper & Doreen de Feis', 260, 330, 'Górecki: Symphony No. 3'),
#  ('Roger Norrington, London Classical Players', 261, 331, 'Purcell: The Fairy Queen'),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 262, 332, 'The Ultimate Relexation Album'),
#  ('Equale Brass Ensemble, John Eliot Gardiner & Munich Monteverdi Orchestra and Choir', 263, 333, 'Purcell: Music for the Queen Mary'),
#  ("Kent Nagano and Orchestre de l'Opéra de Lyon", 264, 334, 'Weill: The Seven Deadly Sins'),
#  ('Julian Bream', 265, 335, 'J.S. Bach: Chaconne, Suite in E Minor, Partita in E Major & Prelude, Fugue and Allegro'),
#  ('Martin Roscoe', 266, 337, 'Szymanowski: Piano Works, Vol. 1'),
#  ('Göteborgs Symfoniker & Neeme Järvi', 267, 338, 'Nielsen: The Six Symphonies'),
#  ('Itzhak Perlman', 268, 339, "Great Recordings of the Century: Paganini's 24 Caprices"),
#  ('Michele Campanella', 269, 340, "Liszt - 12 Études D'Execution Transcendante"),
#  ('Gerald Moore', 270, 341, 'Great Recordings of the Century - Shubert: Schwanengesang, 4 Lieder'),
#  ('Mela Tenenbaum, Pro Musica Prague & Richard Kapp', 271, 342, 'Locatelli: Concertos for Violin, Strings and Continuo, Vol. 3'),
#  ('Emerson String Quartet', 272, 344, "Schubert: The Late String Quartets & String Quintet (3 CD's)"),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 273, 345, "Monteverdi: L'Orfeo"),
#  ('Nash Ensemble', 274, 346, 'Mozart: Chamber Music'),
#  ('Philip Glass Ensemble', 275, 347, 'Koyaanisqatsi (Soundtrack from the Motion Picture)')]

# %% [markdown]
# <h3>Outer Join</h3>
# <img src="../media/outer_join.png" width="500"/>

# %%
# %%sql
#
# SELECT artists.Name, artists.ArtistId, AlbumId, Title
# FROM artists LEFT JOIN albums ON albums.ArtistID = artists.ArtistID
#
# UNION
#
# SELECT artists.Name, artists.ArtistId, AlbumId, Title
# FROM albums LEFT JOIN artists ON albums.ArtistID = artists.ArtistID
#
# LIMIT 100;  -- Remove this line to see the full query output
# Out:
#    sqlite:///Northwind_small.sqlite
#  * sqlite:///chinook.db
# Done.
# [('A Cor Do Som', 43, None, None),
#  ('AC/DC', 1, 1, 'For Those About To Rock We Salute You'),
#  ('AC/DC', 1, 4, 'Let There Be Rock'),
#  ('Aaron Copland & London Symphony Orchestra', 230, 296, 'A Copland Celebration, Vol. I'),
#  ('Aaron Goldberg', 202, 267, 'Worlds'),
#  ('Academy of St. Martin in the Fields & Sir Neville Marriner', 214, 280, 'The World of Classical Favourites'),
#  ('Academy of St. Martin in the Fields Chamber Ensemble & Sir Neville Marriner', 215, 281, 'Sir Neville Marriner: A Celebration'),
#  ('Academy of St. Martin in the Fields, John Birch, Sir Neville Marriner & Sylvia McNair', 222, 288, 'Fauré: Requiem, Ravel: Pavane & Others'),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & Thurston Dart', 257, 327, 'Bach: Orchestral Suites Nos. 1 - 4'),
#  ('Academy of St. Martin in the Fields, Sir Neville Marriner & William Bennett', 239, None, None),
#  ('Accept', 2, 2, 'Balls to the Wall'),
#  ('Accept', 2, 3, 'Restless and Wild'),
#  ('Adrian Leaper & Doreen de Feis', 260, 330, 'Górecki: Symphony No. 3'),
#  ('Aerosmith', 3, 5, 'Big Ones'),
#  ("Aerosmith & Sierra Leone's Refugee Allstars", 161, None, None),
#  ('Aisha Duo', 197, 262, 'Quiet Songs'),
#  ('Alanis Morissette', 4, 6, 'Jagged Little Pill'),
#  ('Alberto Turco & Nova Schola Gregoriana', 206, 272, 'Adorate Deum: Gregorian Chant from the Proper of the Mass'),
#  ('Alice In Chains', 5, 7, 'Facelift'),
#  ('Amy Winehouse', 252, 321, 'Back to Black'),
#  ('Amy Winehouse', 252, 322, 'Frank'),
#  ('Anne-Sophie Mutter, Herbert Von Karajan & Wiener Philharmoniker', 209, 275, 'Vivaldi: The Four Seasons'),
#  ('Antal Doráti & London Symphony Orchestra', 243, 308, "Tchaikovsky: 1812 Festival Overture, Op.49, Capriccio Italien & Beethoven: Wellington's Victory"),
#  ('Antônio Carlos Jobim', 6, 8, 'Warner 25 Anos'),
#  ('Antônio Carlos Jobim', 6, 34, 'Chill: Brazil (Disc 2)'),
#  ('Apocalyptica', 7, 9, 'Plays Metallica By Four Cellos'),
#  ('Aquaman', 159, 254, 'Aquaman'),
#  ('Audioslave', 8, 10, 'Audioslave'),
#  ('Audioslave', 8, 11, 'Out Of Exile'),
#  ('Audioslave', 8, 271, 'Revelations'),
#  ('Avril Lavigne', 166, None, None),
#  ('Azymuth', 26, None, None),
#  ('Baby Consuelo', 31, None, None),
#  ('BackBeat', 9, 12, 'BackBeat Soundtrack'),
#  ('Banda Black Rio', 38, None, None),
#  ('Barry Wordsworth & BBC Concert Orchestra', 224, 290, 'The Last Night of the Proms'),
#  ('Barão Vermelho', 48, None, None),
#  ('Battlestar Galactica', 147, 226, 'Battlestar Galactica: The Story So Far'),
#  ('Battlestar Galactica', 147, 227, 'Battlestar Galactica, Season 3'),
#  ('Battlestar Galactica (Classic)', 158, 253, 'Battlestar Galactica (Classic), Season 1'),
#  ('Bebel Gilberto', 29, None, None),
#  ('Ben Harper', 171, None, None),
#  ('Berliner Philharmoniker & Hans Rosbaud', 237, 303, 'Sibelius: Finlandia'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 316, 'Grieg: Peer Gynt Suites & Sibelius: Pelléas et Mélisande'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 320, 'Mozart: Symphonies Nos. 40 & 41'),
#  ('Berliner Philharmoniker & Herbert Von Karajan', 248, 336, 'Prokofiev: Symphony No.5 & Stravinksy: Le Sacre Du Printemps'),
#  ('Berliner Philharmoniker, Claudio Abbado & Sabine Meyer', 216, 282, 'Mozart: Wind Concertos'),
#  ('Big & Rich', 167, None, None),
#  ('Billy Cobham', 10, 13, 'The Best Of Billy Cobham'),
#  ('Black Eyed Peas', 169, None, None),
#  ('Black Label Society', 11, 14, 'Alcohol Fueled Brewtality Live! [Disc 1]'),
#  ('Black Label Society', 11, 15, 'Alcohol Fueled Brewtality Live! [Disc 2]'),
#  ('Black Sabbath', 12, 16, 'Black Sabbath'),
#  ('Black Sabbath', 12, 17, 'Black Sabbath Vol. 4 (Remaster)'),
#  ('Body Count', 13, 18, 'Body Count'),
#  ('Boston Symphony Orchestra & Seiji Ozawa', 229, 295, 'Carmina Burana'),
#  ('Britten Sinfonia, Ivor Bolton & Lesley Garrett', 219, 285, 'A Soprano Inspired'),
#  ('Bruce Dickinson', 14, 19, 'Chemical Wedding'),
#  ('Buddy Guy', 15, 20, 'The Best Of Buddy Guy - The Millenium Collection'),
#  ('C. Monteverdi, Nigel Rogers - Chiaroscuro; London Baroque; London Cornett & Sackbu', 273, 345, "Monteverdi: L'Orfeo"),
#  ('Caetano Veloso', 16, 21, 'Prenda Minha'),
#  ('Caetano Veloso', 16, 22, 'Sozinho Remix Ao Vivo'),
#  ('Cake', 196, 260, 'Cake: B-Sides and Rarities'),
#  ('Calexico', 253, 323, 'Carried to Dust (Bonus Track Version)'),
#  ("Charles Dutoit & L'Orchestre Symphonique de Montréal", 262, 332, 'The Ultimate Relexation Album'),
#  ('Charlie Brown Jr.', 185, None, None),
#  ('Chicago Symphony Chorus, Chicago Symphony Orchestra & Sir Georg Solti', 220, 286, 'Great Opera Choruses'),
#  ('Chicago Symphony Orchestra & Fritz Reiner', 233, 299, 'Scheherazade'),
#  ('Chico Buarque', 17, 23, 'Minha Historia'),
#  ('Chico Science & Nação Zumbi', 18, 24, 'Afrociberdelia'),
#  ('Chico Science & Nação Zumbi', 18, 25, 'Da Lama Ao Caos'),
#  ('Choir Of Westminster Abbey & Simon Preston', 244, 309, 'Palestrina: Missa Papae Marcelli & Allegri: Miserere'),
#  ('Chor der Wiener Staatsoper, Herbert Von Karajan & Wiener Philharmoniker', 246, 313, 'Bizet: Carmen Highlights'),
#  ('Chris Cornell', 205, 270, 'Carry On'),
#  ('Christina Aguilera featuring BigElf', 160, None, None),
#  ("Christopher O'Riley", 250, 318, 'SCRIABIN: Vers la flamme'),
#  ('Cidade Negra', 19, 26, 'Acústico MTV [Live]'),
#  ('Cidade Negra', 19, 27, 'Cidade Negra - Hits'),
#  ('Cláudio Zoli', 20, 28, 'Na Pista'),
#  ('Corinne Bailey Rae', 163, None, None),
#  ('Creedence Clearwater Revival', 76, 54, 'Chronicle, Vol. 1'),
#  ('Creedence Clearwater Revival', 76, 55, 'Chronicle, Vol. 2'),
#  ('Cássia Eller', 77, 56, 'Cássia Eller - Coleção Sem Limite [Disc 2]'),
#  ('Cássia Eller', 77, 57, 'Cássia Eller - Sem Limite [Disc 1]'),
#  ('DJ Dolores & Orchestra Santa Massa', 192, None, None),
#  ('David Coverdale', 55, 40, 'Into The Light'),
#  ('Deep Purple', 58, 43, 'MK III The Final Concerts [Disc 1]'),
#  ('Deep Purple', 58, 50, 'The Final Concerts (Disc 2)'),
#  ('Deep Purple', 58, 58, 'Come Taste The Band'),
#  ('Deep Purple', 58, 59, 'Deep Purple In Rock'),
#  ('Deep Purple', 58, 60, 'Fireball'),
#  ('Deep Purple', 58, 61, "Knocking at Your Back Door: The Best Of Deep Purple in the 80's"),
#  ('Deep Purple', 58, 62, 'Machine Head'),
#  ('Deep Purple', 58, 63, 'Purpendicular'),
#  ('Deep Purple', 58, 64, 'Slaves And Masters'),
#  ('Deep Purple', 58, 65, 'Stormbringer'),
#  ('Deep Purple', 58, 66, 'The Battle Rages On'),
#  ('Def Leppard', 78, 67, "Vault: Def Leppard's Greatest Hits"),
#  ('Dennis Chambers', 79, 68, 'Outbreak'),
#  ('Dhani Harrison & Jakob Dylan', 164, None, None)]

# %% [markdown]
# <h3>Cross Join</h3>
# <img src="../media/cross_join.png" width="500"/>

# %%
# %%sql
# SELECT * FROM media_types
# CROSS JOIN genres;
# Out:
#    sqlite:///Northwind_small.sqlite
#  * sqlite:///chinook.db
# Done.
# [(1, 'MPEG audio file', 1, 'Rock'),
#  (1, 'MPEG audio file', 2, 'Jazz'),
#  (1, 'MPEG audio file', 3, 'Metal'),
#  (1, 'MPEG audio file', 4, 'Alternative & Punk'),
#  (1, 'MPEG audio file', 5, 'Rock And Roll'),
#  (1, 'MPEG audio file', 6, 'Blues'),
#  (1, 'MPEG audio file', 7, 'Latin'),
#  (1, 'MPEG audio file', 8, 'Reggae'),
#  (1, 'MPEG audio file', 9, 'Pop'),
#  (1, 'MPEG audio file', 10, 'Soundtrack'),
#  (1, 'MPEG audio file', 11, 'Bossa Nova'),
#  (1, 'MPEG audio file', 12, 'Easy Listening'),
#  (1, 'MPEG audio file', 13, 'Heavy Metal'),
#  (1, 'MPEG audio file', 14, 'R&B/Soul'),
#  (1, 'MPEG audio file', 15, 'Electronica/Dance'),
#  (1, 'MPEG audio file', 16, 'World'),
#  (1, 'MPEG audio file', 17, 'Hip Hop/Rap'),
#  (1, 'MPEG audio file', 18, 'Science Fiction'),
#  (1, 'MPEG audio file', 19, 'TV Shows'),
#  (1, 'MPEG audio file', 20, 'Sci Fi & Fantasy'),
#  (1, 'MPEG audio file', 21, 'Drama'),
#  (1, 'MPEG audio file', 22, 'Comedy'),
#  (1, 'MPEG audio file', 23, 'Alternative'),
#  (1, 'MPEG audio file', 24, 'Classical'),
#  (1, 'MPEG audio file', 25, 'Opera'),
#  (2, 'Protected AAC audio file', 1, 'Rock'),
#  (2, 'Protected AAC audio file', 2, 'Jazz'),
#  (2, 'Protected AAC audio file', 3, 'Metal'),
#  (2, 'Protected AAC audio file', 4, 'Alternative & Punk'),
#  (2, 'Protected AAC audio file', 5, 'Rock And Roll'),
#  (2, 'Protected AAC audio file', 6, 'Blues'),
#  (2, 'Protected AAC audio file', 7, 'Latin'),
#  (2, 'Protected AAC audio file', 8, 'Reggae'),
#  (2, 'Protected AAC audio file', 9, 'Pop'),
#  (2, 'Protected AAC audio file', 10, 'Soundtrack'),
#  (2, 'Protected AAC audio file', 11, 'Bossa Nova'),
#  (2, 'Protected AAC audio file', 12, 'Easy Listening'),
#  (2, 'Protected AAC audio file', 13, 'Heavy Metal'),
#  (2, 'Protected AAC audio file', 14, 'R&B/Soul'),
#  (2, 'Protected AAC audio file', 15, 'Electronica/Dance'),
#  (2, 'Protected AAC audio file', 16, 'World'),
#  (2, 'Protected AAC audio file', 17, 'Hip Hop/Rap'),
#  (2, 'Protected AAC audio file', 18, 'Science Fiction'),
#  (2, 'Protected AAC audio file', 19, 'TV Shows'),
#  (2, 'Protected AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (2, 'Protected AAC audio file', 21, 'Drama'),
#  (2, 'Protected AAC audio file', 22, 'Comedy'),
#  (2, 'Protected AAC audio file', 23, 'Alternative'),
#  (2, 'Protected AAC audio file', 24, 'Classical'),
#  (2, 'Protected AAC audio file', 25, 'Opera'),
#  (3, 'Protected MPEG-4 video file', 1, 'Rock'),
#  (3, 'Protected MPEG-4 video file', 2, 'Jazz'),
#  (3, 'Protected MPEG-4 video file', 3, 'Metal'),
#  (3, 'Protected MPEG-4 video file', 4, 'Alternative & Punk'),
#  (3, 'Protected MPEG-4 video file', 5, 'Rock And Roll'),
#  (3, 'Protected MPEG-4 video file', 6, 'Blues'),
#  (3, 'Protected MPEG-4 video file', 7, 'Latin'),
#  (3, 'Protected MPEG-4 video file', 8, 'Reggae'),
#  (3, 'Protected MPEG-4 video file', 9, 'Pop'),
#  (3, 'Protected MPEG-4 video file', 10, 'Soundtrack'),
#  (3, 'Protected MPEG-4 video file', 11, 'Bossa Nova'),
#  (3, 'Protected MPEG-4 video file', 12, 'Easy Listening'),
#  (3, 'Protected MPEG-4 video file', 13, 'Heavy Metal'),
#  (3, 'Protected MPEG-4 video file', 14, 'R&B/Soul'),
#  (3, 'Protected MPEG-4 video file', 15, 'Electronica/Dance'),
#  (3, 'Protected MPEG-4 video file', 16, 'World'),
#  (3, 'Protected MPEG-4 video file', 17, 'Hip Hop/Rap'),
#  (3, 'Protected MPEG-4 video file', 18, 'Science Fiction'),
#  (3, 'Protected MPEG-4 video file', 19, 'TV Shows'),
#  (3, 'Protected MPEG-4 video file', 20, 'Sci Fi & Fantasy'),
#  (3, 'Protected MPEG-4 video file', 21, 'Drama'),
#  (3, 'Protected MPEG-4 video file', 22, 'Comedy'),
#  (3, 'Protected MPEG-4 video file', 23, 'Alternative'),
#  (3, 'Protected MPEG-4 video file', 24, 'Classical'),
#  (3, 'Protected MPEG-4 video file', 25, 'Opera'),
#  (4, 'Purchased AAC audio file', 1, 'Rock'),
#  (4, 'Purchased AAC audio file', 2, 'Jazz'),
#  (4, 'Purchased AAC audio file', 3, 'Metal'),
#  (4, 'Purchased AAC audio file', 4, 'Alternative & Punk'),
#  (4, 'Purchased AAC audio file', 5, 'Rock And Roll'),
#  (4, 'Purchased AAC audio file', 6, 'Blues'),
#  (4, 'Purchased AAC audio file', 7, 'Latin'),
#  (4, 'Purchased AAC audio file', 8, 'Reggae'),
#  (4, 'Purchased AAC audio file', 9, 'Pop'),
#  (4, 'Purchased AAC audio file', 10, 'Soundtrack'),
#  (4, 'Purchased AAC audio file', 11, 'Bossa Nova'),
#  (4, 'Purchased AAC audio file', 12, 'Easy Listening'),
#  (4, 'Purchased AAC audio file', 13, 'Heavy Metal'),
#  (4, 'Purchased AAC audio file', 14, 'R&B/Soul'),
#  (4, 'Purchased AAC audio file', 15, 'Electronica/Dance'),
#  (4, 'Purchased AAC audio file', 16, 'World'),
#  (4, 'Purchased AAC audio file', 17, 'Hip Hop/Rap'),
#  (4, 'Purchased AAC audio file', 18, 'Science Fiction'),
#  (4, 'Purchased AAC audio file', 19, 'TV Shows'),
#  (4, 'Purchased AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (4, 'Purchased AAC audio file', 21, 'Drama'),
#  (4, 'Purchased AAC audio file', 22, 'Comedy'),
#  (4, 'Purchased AAC audio file', 23, 'Alternative'),
#  (4, 'Purchased AAC audio file', 24, 'Classical'),
#  (4, 'Purchased AAC audio file', 25, 'Opera'),
#  (5, 'AAC audio file', 1, 'Rock'),
#  (5, 'AAC audio file', 2, 'Jazz'),
#  (5, 'AAC audio file', 3, 'Metal'),
#  (5, 'AAC audio file', 4, 'Alternative & Punk'),
#  (5, 'AAC audio file', 5, 'Rock And Roll'),
#  (5, 'AAC audio file', 6, 'Blues'),
#  (5, 'AAC audio file', 7, 'Latin'),
#  (5, 'AAC audio file', 8, 'Reggae'),
#  (5, 'AAC audio file', 9, 'Pop'),
#  (5, 'AAC audio file', 10, 'Soundtrack'),
#  (5, 'AAC audio file', 11, 'Bossa Nova'),
#  (5, 'AAC audio file', 12, 'Easy Listening'),
#  (5, 'AAC audio file', 13, 'Heavy Metal'),
#  (5, 'AAC audio file', 14, 'R&B/Soul'),
#  (5, 'AAC audio file', 15, 'Electronica/Dance'),
#  (5, 'AAC audio file', 16, 'World'),
#  (5, 'AAC audio file', 17, 'Hip Hop/Rap'),
#  (5, 'AAC audio file', 18, 'Science Fiction'),
#  (5, 'AAC audio file', 19, 'TV Shows'),
#  (5, 'AAC audio file', 20, 'Sci Fi & Fantasy'),
#  (5, 'AAC audio file', 21, 'Drama'),
#  (5, 'AAC audio file', 22, 'Comedy'),
#  (5, 'AAC audio file', 23, 'Alternative'),
#  (5, 'AAC audio file', 24, 'Classical'),
#  (5, 'AAC audio file', 25, 'Opera')]

# %%
# %%sql
#
# SELECT g.Name AS "Genre", m.Name AS "Media Type"
# FROM genres AS g
# CROSS JOIN media_types AS m
# LIMIT 10;  -- Remove this line to see the full query output
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Rock', 'MPEG audio file'),
#  ('Rock', 'Protected AAC audio file'),
#  ('Rock', 'Protected MPEG-4 video file'),
#  ('Rock', 'Purchased AAC audio file'),
#  ('Rock', 'AAC audio file'),
#  ('Jazz', 'MPEG audio file'),
#  ('Jazz', 'Protected AAC audio file'),
#  ('Jazz', 'Protected MPEG-4 video file'),
#  ('Jazz', 'Purchased AAC audio file'),
#  ('Jazz', 'AAC audio file')]

# %% [markdown]
# <h3>Join operators</h3>
# <ul>
#     <li>Inner Join</li>
#     <li>Left/Right Join</li>
#     <li>Outer Join</li>
#     <li>Cross Join</li>
#     </ul>

# %% [markdown]
# <h2>Set Theory</h2>

# %% [markdown]
# <img src="../media/Northwind_ERD.png" width="500"/>

# %%
# %%sql
#
# sqlite:///Northwind_small.sqlite

# %% [markdown]
# <h3>Set Operator Rules</h3>
#
# <ul>
#     <li>The number of columns in both tables needs to be equal.</li>
#     <li>The columns from each table that we want to combine must contain compatible datatypes.</li>
#     <li>We can only apply the ORDER BY clause to the combined (i.e. UNIONised) table and not to the individual tables</li>
#     <li>The GROUP BY clause can only be applied the individual tables (i.e. before the UNION operation) and not the combined result</li>
# </ul>

# %% [markdown]
# <h2>Union Operator</h2>

# %% [markdown]
# <img src="../media/set_union.png" width="500"/>

# %%
# %%sql
#
# SELECT ID, address, region, country, ContactTitle, ContactName  FROM Customer
# LIMIT 3
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [('ALFKI', 'Obere Str. 57', 'Western Europe', 'Germany', 'Sales Representative', 'Maria Anders'),
#  ('ANATR', 'Avda. de la Constitución 2222', 'Central America', 'Mexico', 'Owner', 'Ana Trujillo'),
#  ('ANTON', 'Mataderos  2312', 'Central America', 'Mexico', 'Owner', 'Antonio Moreno')]

# %%
# %%sql
#
# SELECT ID, address, region, country, ContactTitle, ContactName  FROM Supplier
# LIMIT 3
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [(1, '49 Gilbert St.', 'British Isles', 'UK', 'Purchasing Manager', 'Charlotte Cooper'),
#  (2, 'P.O. Box 78934', 'North America', 'USA', 'Order Administrator', 'Shelley Burke'),
#  (3, '707 Oxford Rd.', 'North America', 'USA', 'Sales Representative', 'Regina Murphy')]

# %%
# %%sql
#
# SELECT ID, address, region, country, ContactTitle, ContactName  FROM Customer
#
# UNION
#
# SELECT ID, address, region, country, ContactTitle, ContactName FROM Supplier
#
# LIMIT 100; -- Remove this line to see the full query output
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [(1, '49 Gilbert St.', 'British Isles', 'UK', 'Purchasing Manager', 'Charlotte Cooper'),
#  (2, 'P.O. Box 78934', 'North America', 'USA', 'Order Administrator', 'Shelley Burke'),
#  (3, '707 Oxford Rd.', 'North America', 'USA', 'Sales Representative', 'Regina Murphy'),
#  (4, '9-8 Sekimai Musashino-shi', 'Eastern Asia', 'Japan', 'Marketing Manager', 'Yoshi Nagase'),
#  (5, 'Calle del Rosal 4', 'Southern Europe', 'Spain', 'Export Administrator', 'Antonio del Valle Saavedra'),
#  (6, '92 Setsuko Chuo-ku', 'Eastern Asia', 'Japan', 'Marketing Representative', 'Mayumi Ohno'),
#  (7, '74 Rose St. Moonie Ponds', 'Victoria', 'Australia', 'Marketing Manager', 'Ian Devling'),
#  (8, "29 King's Way", 'British Isles', 'UK', 'Sales Representative', 'Peter Wilson'),
#  (9, 'Kaloadagatan 13', 'Northern Europe', 'Sweden', 'Sales Agent', 'Lars Peterson'),
#  (10, 'Av. das Americanas 12.890', 'South America', 'Brazil', 'Marketing Manager', 'Carlos Diaz'),
#  (11, 'Tiergartenstraße 5', 'Western Europe', 'Germany', 'Sales Manager', 'Petra Winkler'),
#  (12, 'Bogenallee 51', 'Western Europe', 'Germany', 'International Marketing Mgr.', 'Martin Bein'),
#  (13, 'Frahmredder 112a', 'Western Europe', 'Germany', 'Coordinator Foreign Markets', 'Sven Petersen'),
#  (14, 'Viale Dante, 75', 'Southern Europe', 'Italy', 'Sales Representative', 'Elio Rossi'),
#  (15, 'Hatlevegen 5', 'Scandinavia', 'Norway', 'Marketing Manager', 'Beate Vileid'),
#  (16, '3400 - 8th Avenue Suite 210', 'North America', 'USA', 'Regional Account Rep.', 'Cheryl Saylor'),
#  (17, 'Brovallavägen 231', 'Northern Europe', 'Sweden', 'Sales Representative', 'Michael Björn'),
#  (18, '203, Rue des Francs-Bourgeois', 'Western Europe', 'France', 'Sales Manager', 'Guylène Nodier'),
#  (19, 'Order Processing Dept. 2100 Paul Revere Blvd.', 'North America', 'USA', 'Wholesale Account Agent', 'Robb Merchant'),
#  (20, '471 Serangoon Loop, Suite #402', 'South-East Asia', 'Singapore', 'Owner', 'Chandra Leka'),
#  (21, 'Lyngbysild Fiskebakken 10', 'Northern Europe', 'Denmark', 'Sales Manager', 'Niels Petersen'),
#  (22, 'Verkoop Rijnweg 22', 'Northern Europe', 'Netherlands', 'Accounting Manager', 'Dirk Luchte'),
#  (23, 'Valtakatu 12', 'Scandinavia', 'Finland', 'Product Manager', 'Anne Heikkonen'),
#  (24, "170 Prince Edward Parade Hunter's Hill", 'NSW', 'Australia', 'Sales Representative', 'Wendy Mackenzie'),
#  (25, '2960 Rue St. Laurent', 'North America', 'Canada', 'Marketing Manager', 'Jean-Guy Lauzon'),
#  (26, 'Via dei Gelsomini, 153', 'Southern Europe', 'Italy', 'Order Administrator', 'Giovanni Giudici'),
#  (27, '22, rue H. Voiron', 'Western Europe', 'France', 'Sales Manager', 'Marie Delamare'),
#  (28, 'Bat. B 3, rue des Alpes', 'Western Europe', 'France', 'Sales Representative', 'Eliane Noz'),
#  (29, '148 rue Chasseur', 'North America', 'Canada', 'Accounting Manager', 'Chantal Goulet'),
#  ('ALFKI', 'Obere Str. 57', 'Western Europe', 'Germany', 'Sales Representative', 'Maria Anders'),
#  ('ANATR', 'Avda. de la Constitución 2222', 'Central America', 'Mexico', 'Owner', 'Ana Trujillo'),
#  ('ANTON', 'Mataderos  2312', 'Central America', 'Mexico', 'Owner', 'Antonio Moreno'),
#  ('AROUT', '120 Hanover Sq.', 'British Isles', 'UK', 'Sales Representative', 'Thomas Hardy'),
#  ('BERGS', 'Berguvsvägen  8', 'Northern Europe', 'Sweden', 'Order Administrator', 'Christina Berglund'),
#  ('BLAUS', 'Forsterstr. 57', 'Western Europe', 'Germany', 'Sales Representative', 'Hanna Moos'),
#  ('BLONP', '24, place Kléber', 'Western Europe', 'France', 'Marketing Manager', 'Frédérique Citeaux'),
#  ('BOLID', 'C/ Araquil, 67', 'Southern Europe', 'Spain', 'Owner', 'Martín Sommer'),
#  ('BONAP', '12, rue des Bouchers', 'Western Europe', 'France', 'Owner', 'Laurence Lebihan'),
#  ('BOTTM', '23 Tsawassen Blvd.', 'North America', 'Canada', 'Accounting Manager', 'Elizabeth Lincoln'),
#  ('BSBEV', 'Fauntleroy Circus', 'British Isles', 'UK', 'Sales Representative', 'Victoria Ashworth'),
#  ('CACTU', 'Cerrito 333', 'South America', 'Argentina', 'Sales Agent', 'Patricio Simpson'),
#  ('CENTC', 'Sierras de Granada 9993', 'Central America', 'Mexico', 'Marketing Manager', 'Francisco Chang'),
#  ('CHOPS', 'Hauptstr. 29', 'Western Europe', 'Switzerland', 'Owner', 'Yang Wang'),
#  ('COMMI', 'Av. dos Lusíadas, 23', 'South America', 'Brazil', 'Sales Associate', 'Pedro Afonso'),
#  ('CONSH', 'Berkeley Gardens 12  Brewery', 'British Isles', 'UK', 'Sales Representative', 'Elizabeth Brown'),
#  ('DRACD', 'Walserweg 21', 'Western Europe', 'Germany', 'Order Administrator', 'Sven Ottlieb'),
#  ('DUMON', '67, rue des Cinquante Otages', 'Western Europe', 'France', 'Owner', 'Janine Labrune'),
#  ('EASTC', '35 King George', 'British Isles', 'UK', 'Sales Agent', 'Ann Devon'),
#  ('ERNSH', 'Kirchgasse 6', 'Western Europe', 'Austria', 'Sales Manager', 'Roland Mendel'),
#  ('FAMIA', 'Rua Orós, 92', 'South America', 'Brazil', 'Marketing Assistant', 'Aria Cruz'),
#  ('FISSA', 'C/ Moralzarzal, 86', 'Southern Europe', 'Spain', 'Accounting Manager', 'Diego Roel'),
#  ('FOLIG', '184, chaussée de Tournai', 'Western Europe', 'France', 'Assistant Sales Agent', 'Martine Rancé'),
#  ('FOLKO', 'Åkergatan 24', 'Northern Europe', 'Sweden', 'Owner', 'Maria Larsson'),
#  ('FRANK', 'Berliner Platz 43', 'Western Europe', 'Germany', 'Marketing Manager', 'Peter Franken'),
#  ('FRANR', '54, rue Royale', 'Western Europe', 'France', 'Marketing Manager', 'Carine Schmitt'),
#  ('FRANS', 'Via Monte Bianco 34', 'Southern Europe', 'Italy', 'Sales Representative', 'Paolo Accorti'),
#  ('FURIB', 'Jardim das rosas n. 32', 'Southern Europe', 'Portugal', 'Sales Manager', 'Lino Rodriguez'),
#  ('GALED', 'Rambla de Cataluña, 23', 'Southern Europe', 'Spain', 'Marketing Manager', 'Eduardo Saavedra'),
#  ('GODOS', 'C/ Romero, 33', 'Southern Europe', 'Spain', 'Sales Manager', 'José Pedro Freyre'),
#  ('GOURL', 'Av. Brasil, 442', 'South America', 'Brazil', 'Sales Associate', 'André Fonseca'),
#  ('GREAL', '2732 Baker Blvd.', 'North America', 'USA', 'Marketing Manager', 'Howard Snyder'),
#  ('GROSR', '5ª Ave. Los Palos Grandes', 'South America', 'Venezuela', 'Owner', 'Manuel Pereira'),
#  ('HANAR', 'Rua do Paço, 67', 'South America', 'Brazil', 'Accounting Manager', 'Mario Pontes'),
#  ('HILAA', 'Carrera 22 con Ave. Carlos Soublette #8-35', 'South America', 'Venezuela', 'Sales Representative', 'Carlos Hernández'),
#  ('HUNGC', 'City Center Plaza 516 Main St.', 'North America', 'USA', 'Sales Representative', 'Yoshi Latimer'),
#  ('HUNGO', '8 Johnstown Road', 'British Isles', 'Ireland', 'Sales Associate', 'Patricia McKenna'),
#  ('ISLAT', 'Garden House Crowther Way', 'British Isles', 'UK', 'Marketing Manager', 'Helen Bennett'),
#  ('KOENE', 'Maubelstr. 90', 'Western Europe', 'Germany', 'Sales Associate', 'Philip Cramer'),
#  ('LACOR', "67, avenue de l'Europe", 'Western Europe', 'France', 'Sales Representative', 'Daniel Tonini'),
#  ('LAMAI', '1 rue Alsace-Lorraine', 'Western Europe', 'France', 'Sales Manager', 'Annette Roulet'),
#  ('LAUGB', '1900 Oak St.', 'North America', 'Canada', 'Marketing Assistant', 'Yoshi Tannamuri'),
#  ('LAZYK', '12 Orchestra Terrace', 'North America', 'USA', 'Marketing Manager', 'John Steel'),
#  ('LEHMS', 'Magazinweg 7', 'Western Europe', 'Germany', 'Sales Representative', 'Renate Messner'),
#  ('LETSS', '87 Polk St. Suite 5', 'North America', 'USA', 'Owner', 'Jaime Yorres'),
#  ('LILAS', 'Carrera 52 con Ave. Bolívar #65-98 Llano Largo', 'South America', 'Venezuela', 'Accounting Manager', 'Carlos González'),
#  ('LINOD', 'Ave. 5 de Mayo Porlamar', 'South America', 'Venezuela', 'Owner', 'Felipe Izquierdo'),
#  ('LONEP', '89 Chiaroscuro Rd.', 'North America', 'USA', 'Sales Manager', 'Fran Wilson'),
#  ('MAGAA', 'Via Ludovico il Moro 22', 'Southern Europe', 'Italy', 'Marketing Manager', 'Giovanni Rovelli'),
#  ('MAISD', 'Rue Joseph-Bens 532', 'Western Europe', 'Belgium', 'Sales Agent', 'Catherine Dewey'),
#  ('MEREP', '43 rue St. Laurent', 'North America', 'Canada', 'Marketing Assistant', 'Jean Fresnière'),
#  ('MORGK', 'Heerstr. 22', 'Western Europe', 'Germany', 'Marketing Assistant', 'Alexander Feuer'),
#  ('NORTS', 'South House 300 Queensbridge', 'British Isles', 'UK', 'Sales Associate', 'Simon Crowther'),
#  ('OCEAN', 'Ing. Gustavo Moncada 8585 Piso 20-A', 'South America', 'Argentina', 'Sales Agent', 'Yvonne Moncada'),
#  ('OLDWO', '2743 Bering St.', 'North America', 'USA', 'Sales Representative', 'Rene Phillips'),
#  ('OTTIK', 'Mehrheimerstr. 369', 'Western Europe', 'Germany', 'Owner', 'Henriette Pfalzheim'),
#  ('PARIS', '265, boulevard Charonne', 'Western Europe', 'France', 'Owner', 'Marie Bertrand'),
#  ('PERIC', 'Calle Dr. Jorge Cash 321', 'Central America', 'Mexico', 'Sales Representative', 'Guillermo Fernández'),
#  ('PICCO', 'Geislweg 14', 'Western Europe', 'Austria', 'Sales Manager', 'Georg Pipps'),
#  ('PRINI', 'Estrada da saúde n. 58', 'Southern Europe', 'Portugal', 'Sales Representative', 'Isabel de Castro'),
#  ('QUEDE', 'Rua da Panificadora, 12', 'South America', 'Brazil', 'Accounting Manager', 'Bernardo Batista'),
#  ('QUEEN', 'Alameda dos Canàrios, 891', 'South America', 'Brazil', 'Marketing Assistant', 'Lúcia Carvalho'),
#  ('QUICK', 'Taucherstraße 10', 'Western Europe', 'Germany', 'Accounting Manager', 'Horst Kloss'),
#  ('RANCH', 'Av. del Libertador 900', 'South America', 'Argentina', 'Sales Representative', 'Sergio Gutiérrez'),
#  ('RATTC', '2817 Milton Dr.', 'North America', 'USA', 'Assistant Sales Representative', 'Paula Wilson'),
#  ('REGGC', 'Strada Provinciale 124', 'Southern Europe', 'Italy', 'Sales Associate', 'Maurizio Moroni'),
#  ('RICAR', 'Av. Copacabana, 267', 'South America', 'Brazil', 'Assistant Sales Agent', 'Janete Limeira'),
#  ('RICSU', 'Grenzacherweg 237', 'Western Europe', 'Switzerland', 'Sales Manager', 'Michael Holz'),
#  ('ROMEY', 'Gran Vía, 1', 'Southern Europe', 'Spain', 'Accounting Manager', 'Alejandra Camino'),
#  ('SANTG', 'Erling Skakkes gate 78', 'Scandinavia', 'Norway', 'Owner', 'Jonas Bergulfsen'),
#  ('SAVEA', '187 Suffolk Ln.', 'North America', 'USA', 'Sales Representative', 'Jose Pavarotti')]

# %% [markdown]
# <h2>Intersection Operator</h2>

# %% [markdown]
# <img src="../media/intersect.png" width="500"/>

# %%
# %%sql
#
# SELECT * FROM Employee
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [(1, 'Davolio', 'Nancy', 'Sales Representative', 'Ms.', '1980-12-08', '2024-05-01', '507 - 20th Ave. E. Apt. 2A', 'Seattle', 'North America', '98122', 'USA', '(206) 555-9857', '5467', None, "Education includes a BA in psychology from Colorado State University in 1970.  She also completed 'The Art of the Cold Call.'  Nancy is a member of Toastmasters International.", 2, 'http://accweb/emmployees/davolio.bmp'),
#  (2, 'Fuller', 'Andrew', 'Vice President, Sales', 'Dr.', '1984-02-19', '2024-08-14', '908 W. Capital Way', 'Tacoma', 'North America', '98401', 'USA', '(206) 555-9482', '3457', None, 'Andrew received his BTS commercial in 1974 and a Ph.D. in international marketing from the University of Dallas in 1981.  He is fluent in French and  ... (150 characters truncated) ... es in March 1993.  Andrew is a member of the Sales Management Roundtable, the Seattle Chamber of Commerce, and the Pacific Rim Importers Association.', None, 'http://accweb/emmployees/fuller.bmp'),
#  (3, 'Leverling', 'Janet', 'Sales Representative', 'Ms.', '1995-08-30', '2024-04-01', '722 Moss Bay Blvd.', 'Kirkland', 'North America', '98033', 'USA', '(206) 555-3412', '3355', None, 'Janet has a BS degree in chemistry from Boston College (1984).  She has also completed a certificate program in food retailing management.  Janet was hired as a sales associate in 1991 and promoted to sales representative in February 1992.', 2, 'http://accweb/emmployees/leverling.bmp'),
#  (4, 'Peacock', 'Margaret', 'Sales Representative', 'Mrs.', '1969-09-19', '2025-05-03', '4110 Old Redmond Rd.', 'Redmond', 'North America', '98052', 'USA', '(206) 555-8122', '5176', None, 'Margaret holds a BA in English literature from Concordia College (1958) and an MA from the American Institute of Culinary Arts (1966).  She was assigned to the London office temporarily from July through November 1992.', 2, 'http://accweb/emmployees/peacock.bmp'),
#  (5, 'Buchanan', 'Steven', 'Sales Manager', 'Mr.', '1987-03-04', '2025-10-17', '14 Garrett Hill', 'London', 'British Isles', 'SW1 8JR', 'UK', '(71) 555-4848', '3453', None, "Steven Buchanan graduated from St. Andrews University, Scotland, with a BSC degree in 1976.  Upon joining the company as a sales representative in 19 ... (150 characters truncated) ... ager in March 1993.  Mr. Buchanan has completed the courses 'Successful Telemarketing' and 'International Sales Management.'  He is fluent in French.", 2, 'http://accweb/emmployees/buchanan.bmp'),
#  (6, 'Suyama', 'Michael', 'Sales Representative', 'Mr.', '1995-07-02', '2025-10-17', 'Coventry House Miner Rd.', 'London', 'British Isles', 'EC2 7JR', 'UK', '(71) 555-7773', '428', None, "Michael is a graduate of Sussex University (MA, economics, 1983) and the University of California at Los Angeles (MBA, marketing, 1986).  He has also ... (26 characters truncated) ... Cultural Selling' and 'Time Management for the Sales Professional.'  He is fluent in Japanese and can read and write French, Portuguese, and Spanish.", 5, 'http://accweb/emmployees/davolio.bmp'),
#  (7, 'King', 'Robert', 'Sales Representative', 'Mr.', '1992-05-29', '2026-01-02', 'Edgeham Hollow Winchester Way', 'London', 'British Isles', 'RG1 9SP', 'UK', '(71) 555-5598', '465', None, "Robert King served in the Peace Corps and traveled extensively before completing his degree in English at the University of Michigan in 1992, the year he joined the company.  After completing a course entitled 'Selling in Europe,' he was transferred to the London office in March 1993.", 5, 'http://accweb/emmployees/davolio.bmp'),
#  (8, 'Callahan', 'Laura', 'Inside Sales Coordinator', 'Ms.', '1990-01-09', '2026-03-05', '4726 - 11th Ave. N.E.', 'Seattle', 'North America', '98105', 'USA', '(206) 555-1189', '2344', None, 'Laura received a BA in psychology from the University of Washington.  She has also completed a course in business French.  She reads and writes French.', 2, 'http://accweb/emmployees/davolio.bmp'),
#  (9, 'Dodsworth', 'Anne', 'Sales Representative', 'Ms.', '1998-01-27', '2026-11-15', '7 Houndstooth Rd.', 'London', 'British Isles', 'WG2 7LT', 'UK', '(71) 555-4444', '452', None, 'Anne has a BA degree in English from St. Lawrence College.  She is fluent in French and German.', 5, 'http://accweb/emmployees/davolio.bmp')]

# %%
# %%sql
# SELECT Region, City
# FROM Employee
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [('North America', 'Seattle'),
#  ('North America', 'Tacoma'),
#  ('North America', 'Kirkland'),
#  ('North America', 'Redmond'),
#  ('British Isles', 'London'),
#  ('British Isles', 'London'),
#  ('British Isles', 'London'),
#  ('North America', 'Seattle'),
#  ('British Isles', 'London')]

# %%
# %%sql
#
# SELECT Region, City
# FROM Customer
#
# INTERSECT
#
# SELECT Region, City
# FROM Employee
#
# ORDER BY City
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [('North America', 'Kirkland'),
#  ('British Isles', 'London'),
#  ('North America', 'Seattle')]

# %% [markdown]
# <h2>Except Operator</h2>

# %% [markdown]
# <img src="../media/Except.png" width="500"/>

# %%
# %%sql
#
# SELECT CompanyName FROM Shipper LIMIT 5
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [('Speedy Express',), ('United Package',), ('Federal Shipping',)]

# %%
# %%sql
# SELECT CompanyName AS 'Company' FROM Supplier
#
# EXCEPT
#
# SELECT CompanyName FROM Shipper
# LIMIT 10; -- Remove this line to see the full query output
# Out:
#  * sqlite:///Northwind_small.sqlite
#    sqlite:///chinook.db
# Done.
# [('Aux joyeux ecclésiastiques',),
#  ('Bigfoot Breweries',),
#  ("Cooperativa de Quesos 'Las Cabras'",),
#  ('Escargots Nouveaux',),
#  ('Exotic Liquids',),
#  ('Formaggi Fortini s.r.l.',),
#  ("Forêts d'érables",),
#  ("G'day, Mate",),
#  ('Gai pâturage',),
#  ("Grandma Kelly's Homestead",)]
