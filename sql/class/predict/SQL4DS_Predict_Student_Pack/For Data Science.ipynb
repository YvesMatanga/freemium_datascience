# %% [markdown]
# <h1>Tips for Data Science</h1>

# %% [markdown]
# <ol>
#     <li>Python for Data Science: <b>Core Python, Pandas, Numpy, Matplotlib, Seaborn</b> </li>
#     <li>Linear Algebra: Matrices and Matrix calculations, Vectors, Eigenvalues</li>
#     <li>Basic Statistics: Descriptive, Statiscal measures (mean, std, variance), <b>Hypothesis Testing</b></li>
#     <li><b>Homework</b>: Nonlinear continuous optimisation, Gradient descent algorithm</li>
# </ol>
